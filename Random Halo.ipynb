# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 66)

# %%
name = ['The Pillar of Autumn', 'Halo', 'The Truth and Reconciliation', 'The Silent Cartographer',
       'Assault on the Control Room', '343 Guilty Spark', 'The Library', 'Two Betrayals', 'Keyes'
       , 'The Maw', 'The Heretic', 'The Armory', 'Cairo Station', 'Outskirts', 'Metropolis', 'The Arbiter', 
       'The Oracle', 'Delta Halo', 'Regret', 'Sacred Icon', 'Quarantine Zone', 'Gravemind', 
       'Uprising', 'High Charity', 'The Great Journey', 'Arrival', 'Sierra 117', 'Crow\'s Nest', 'Tsavo Highway'
       ,'The Storm', 'Floodgate', 'The Ark', 'The Covenant','Cortano', 'Halo',
       'Noble Actual', 'Winter Contingency', 'ONI: Sword Base', 'Nightfall', 'Tip of The Spear', 
       'Long Night of Solace', 'Exodus', 'New Alexandria', 'The Package', 'The Pillar of Autumn', 'Lone Wolf',
       'Prepare To Drop', 'Mombasa Streets', 'Tayari Plaza', 'Uplift Reserve', 'Kizingo Boulevard',
       'ONI Alpha Site', 'NMPD HQ', 'Kikowani Station', 'Data Hive', 'Coastal Highway',
       'Prologue', 'Dawn', 'Requiem', 'Forerunner', 'Infinity', 'Reclaimer', 'Shutdown', 'Composer',
       'Midnight', 'Epilogue']
halo1 = np.array([['Halo CE']*10]).flatten()
halo2 = np.array([['Halo 2']*15]).flatten()
halo3 = np.array([['Halo 3']*10]).flatten()
haloR = np.array([['Halo Reach']*11]).flatten()
haloodst = np.array([['Halo ODST']*10]).flatten()
halo4 = np.array([['Halo 4']*10]).flatten()
haloall = np.concatenate((halo1, halo2, halo3, haloR, haloodst, halo4))

# %%
halo2
# Out:
# array(['Halo 2', 'Halo 2', 'Halo 2', 'Halo 2', 'Halo 2', 'Halo 2',
#        'Halo 2', 'Halo 2', 'Halo 2', 'Halo 2', 'Halo 2', 'Halo 2',
#        'Halo 2', 'Halo 2', 'Halo 2'], dtype='<U6')

# %%
random_halo = pd.DataFrame({
    'level': name, 
    'game': haloall
})
random_halo
# Out:
#                            level        game
# 0           The Pillar of Autumn     Halo CE
# 1                           Halo     Halo CE
# 2   The Truth and Reconciliation     Halo CE
# 3        The Silent Cartographer     Halo CE
# 4    Assault on the Control Room     Halo CE
# 5               343 Guilty Spark     Halo CE
# 6                    The Library     Halo CE
# 7                  Two Betrayals     Halo CE
# 8                          Keyes     Halo CE
# 9                        The Maw     Halo CE
# 10                   The Heretic      Halo 2
# 11                    The Armory      Halo 2
# 12                 Cairo Station      Halo 2
# 13                     Outskirts      Halo 2
# 14                    Metropolis      Halo 2
# 15                   The Arbiter      Halo 2
# 16                    The Oracle      Halo 2
# 17                    Delta Halo      Halo 2
# 18                        Regret      Halo 2
# 19                   Sacred Icon      Halo 2
# ...

# %%
random_halo.sample(frac=1)
# Out:
#                            level        game
# 45                     Lone Wolf  Halo Reach
# 57                          Dawn      Halo 4
# 44          The Pillar of Autumn  Halo Reach
# 3        The Silent Cartographer     Halo CE
# 12                 Cairo Station      Halo 2
# 29                     The Storm      Halo 3
# 21                     Gravemind      Halo 2
# 32                  The Covenant      Halo 3
# 16                    The Oracle      Halo 2
# 28                 Tsavo Highway      Halo 3
# 24             The Great Journey      Halo 2
# 51                ONI Alpha Site   Halo ODST
# 50             Kizingo Boulevard   Halo ODST
# 47               Mombasa Streets   Halo ODST
# 59                    Forerunner      Halo 4
# 27                   Crow's Nest      Halo 3
# 65                      Epilogue      Halo 4
# 8                          Keyes     Halo CE
# 7                  Two Betrayals     Halo CE
# 26                    Sierra 117      Halo 3
# ...
