# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"D:\EOY Datasets\Full Datasets"+'\\'+'Full_dataset.csv',index_col=[0])
# Out:
# C:\Users\ellio\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#                                             Crime ID  Year    Month  \
# 0  e9a50727f2189e0c50f704e3661bc1a8ae3a39aece4866...  2019  2019-01
# 1  fb06f54e9d633a961109ef74171e4beb40b2fe44e57a10...  2019  2019-01
# 2  4655ba031d5c8d00b247577a22472fbb8f9130d98b7d95...  2019  2019-01
# 3  2830f28a4a93138717182d1cc51b6d77cfaf3c27398934...  2019  2019-01
# 4  ca01d599d45f6e1d1bc5b05ddc6a1b559870fc831baa8e...  2019  2019-01
#
#        Region                     Reported by                    Crime type  \
# 0  South West  Avon and Somerset Constabulary  Violence and sexual offences
# 1  South West  Avon and Somerset Constabulary  Violence and sexual offences
# 2  South West  Avon and Somerset Constabulary  Violence and sexual offences
# 3  South West  Avon and Somerset Constabulary                Theft offences
# 4  South West  Avon and Somerset Constabulary                Theft offences
#
#                                     Outcome type Level_of_Lockdown
# ...

# %%
grouped = df.groupby(['Year','Outcome type'])['Crime ID'].count().reset_index()

# %%
plt.figure(figsize=(12,10))
sns.barplot(data=grouped,x='Year',y='Crime ID',hue='Outcome type')
plt.show()

# %%
grouped2 = df.groupby(['Crime type','Outcome type'])['Crime ID'].count().reset_index()

# %%
plt.figure(figsize=(12,10))
sns.barplot(data=grouped2,x='Crime type',y='Crime ID',hue='Outcome type')
plt.show()

# %%
grouped3 = df.groupby(['Year','Crime type'])['Crime ID'].count().reset_index()

# %%
plt.figure(figsize=(12,10))
sns.barplot(data=grouped3,x='Year',y='Crime ID',hue='Crime type')
plt.show()

# %%
tab = pd.crosstab(df['Crime type'],df['Outcome type'],normalize=0)*100

# %%
tab
# Out:
# Outcome type                  Investigation complete. No suspect identified  \
# Crime type
# Criminal damage and arson                                         73.057804
# Drug offences                                                      4.903912
# Public order offences                                             39.368623
# Theft offences                                                    78.843061
# Violence and sexual offences                                      22.059302
#
# Outcome type                  Other Outcome  Suspect charged  \
# Crime type
# Criminal damage and arson          3.848334         4.534008
# Drug offences                     65.317058        23.759624
# Public order offences              7.766706         8.532209
# Theft offences                     3.426828         6.327161
# Violence and sexual offences       8.355264         6.410687
#
# Outcome type                  Unable to prosecute suspect
# Crime type
# ...

# %%
grouped4 = df.groupby(['Year','Crime type','Outcome type'])['Crime ID'].count().reset_index()
grouped4
# Out:
#     Year                    Crime type  \
# 0   2019     Criminal damage and arson
# 1   2019     Criminal damage and arson
# 2   2019     Criminal damage and arson
# 3   2019     Criminal damage and arson
# 4   2019                 Drug offences
# 5   2019                 Drug offences
# 6   2019                 Drug offences
# 7   2019                 Drug offences
# 8   2019         Public order offences
# 9   2019         Public order offences
# 10  2019         Public order offences
# 11  2019         Public order offences
# 12  2019                Theft offences
# 13  2019                Theft offences
# 14  2019                Theft offences
# 15  2019                Theft offences
# 16  2019  Violence and sexual offences
# 17  2019  Violence and sexual offences
# 18  2019  Violence and sexual offences
# 19  2019  Violence and sexual offences
# 20  2020     Criminal damage and arson
# 21  2020     Criminal damage and arson
# 22  2020     Criminal damage and arson
# ...

# %%
pivot = pd.pivot_table(grouped4,values='Crime ID',columns=['Year','Crime type'],index='Outcome type')

# %%
pivot
# Out:
# Year                                                               2019  \
# Crime type                                    Criminal damage and arson
# Outcome type
# Investigation complete. No suspect identified                     72141
# Other Outcome                                                      3929
# Suspect charged                                                    4696
# Unable to prosecute suspect                                       16765
#
# Year                                                         \
# Crime type                                    Drug offences
# Outcome type
# Investigation complete. No suspect identified          1742
# Other Outcome                                         15537
# Suspect charged                                        6816
# Unable to prosecute suspect                            1487
#
# Year                                                                 \
# Crime type                                    Public order offences
# ...

# %% [markdown]
# Normalised by column, e.g in 2019, for every criminal damage case 74% had no suspect identified, 4% had an other outcome etc.

# %%
pivot2 = pivot/pivot.sum()
pivot2.applymap(lambda x: "{0:.0f}%".format(100*x))
# Out:
# Year                                                               2019  \
# Crime type                                    Criminal damage and arson
# Outcome type
# Investigation complete. No suspect identified                       74%
# Other Outcome                                                        4%
# Suspect charged                                                      5%
# Unable to prosecute suspect                                         17%
#
# Year                                                         \
# Crime type                                    Drug offences
# Outcome type
# Investigation complete. No suspect identified            7%
# Other Outcome                                           61%
# Suspect charged                                         27%
# Unable to prosecute suspect                              6%
#
# Year                                                                 \
# Crime type                                    Public order offences
# ...

# %%
pivot3 = pivot/pivot.sum()*100
pivot3
# Out:
# Year                                                               2019  \
# Crime type                                    Criminal damage and arson
# Outcome type
# Investigation complete. No suspect identified                 73.967251
# Other Outcome                                                  4.028463
# Suspect charged                                                4.814879
# Unable to prosecute suspect                                   17.189406
#
# Year                                                         \
# Crime type                                    Drug offences
# Outcome type
# Investigation complete. No suspect identified      6.809475
# Other Outcome                                     60.734110
# Suspect charged                                   26.643734
# Unable to prosecute suspect                        5.812681
#
# Year                                                                 \
# Crime type                                    Public order offences
# ...

# %%
pivot3.columns
# Out:
# MultiIndex([(2019,    'Criminal damage and arson'),
#             (2019,                'Drug offences'),
#             (2019,        'Public order offences'),
#             (2019,               'Theft offences'),
#             (2019, 'Violence and sexual offences'),
#             (2020,    'Criminal damage and arson'),
#             (2020,                'Drug offences'),
#             (2020,        'Public order offences'),
#             (2020,               'Theft offences'),
#             (2020, 'Violence and sexual offences'),
#             (2021,    'Criminal damage and arson'),
#             (2021,                'Drug offences'),
#             (2021,        'Public order offences'),
#             (2021,               'Theft offences'),
#             (2021, 'Violence and sexual offences')],
#            names=['Year', 'Crime type'])

# %%
pivot4 = pd.pivot_table(grouped4,values='Crime ID',columns=['Year','Outcome type'],index='Crime type')
pivot4
# Out:
# Year                                                                  2019  \
# Outcome type                 Investigation complete. No suspect identified
# Crime type
# Criminal damage and arson                                            72141
# Drug offences                                                         1742
# Public order offences                                                25564
# Theft offences                                                      188031
# Violence and sexual offences                                         61765
#
# Year                                                        \
# Outcome type                 Other Outcome Suspect charged
# Crime type
# Criminal damage and arson             3929            4696
# Drug offences                        15537            6816
# Public order offences                 5350            5852
# Theft offences                       10490           16349
# Violence and sexual offences         23817           20085
# ...

# %%
pivot2019 = pivot4.loc[slice(None),(2019)]
#pivot2019 = pivot2019/pivot2019.sum()
pivot2019 = pivot2019.div(pivot2019.sum(axis=1), axis=0)
pivot2019
# Out:
# Outcome type                  Investigation complete. No suspect identified  \
# Crime type
# Criminal damage and arson                                          0.739673
# Drug offences                                                      0.068095
# Public order offences                                              0.407226
# Theft offences                                                     0.778226
# Violence and sexual offences                                       0.233110
#
# Outcome type                  Other Outcome  Suspect charged  \
# Crime type
# Criminal damage and arson          0.040285         0.048149
# Drug offences                      0.607341         0.266437
# Public order offences              0.085224         0.093220
# Theft offences                     0.043416         0.067666
# Violence and sexual offences       0.089889         0.075804
#
# Outcome type                  Unable to prosecute suspect
# Crime type
# ...

# %%
tab2 = pd.crosstab(columns=[df['Year'],df['Crime type']],index=df['Outcome type'])
tab2
# Out:
# Year                                                               2019  \
# Crime type                                    Criminal damage and arson
# Outcome type
# Investigation complete. No suspect identified                     72141
# Other Outcome                                                      3929
# Suspect charged                                                    4696
# Unable to prosecute suspect                                       16765
#
# Year                                                         \
# Crime type                                    Drug offences
# Outcome type
# Investigation complete. No suspect identified          1742
# Other Outcome                                         15537
# Suspect charged                                        6816
# Unable to prosecute suspect                            1487
#
# Year                                                                 \
# Crime type                                    Public order offences
# ...

# %%
def pivoting_stacks(df,year):
    res = df.loc[slice(None),(year)]
    res = res.div(res.sum(axis=1), axis=0)
    return res

# %%
pivot2019 = pivoting_stacks(pivot4,2019)
pivot2020 = pivoting_stacks(pivot4,2020)
pivot2021 = pivoting_stacks(pivot4,2021)

# %%
fig, (a1,a2,a3) = plt.subplots(3,1,figsize=(10,14))
pivot2019.plot.bar(stacked=True,ax=a1,title='2019').legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
pivot2020.plot.bar(stacked=True,ax=a2,title='2020').legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
pivot2021.plot.bar(stacked=True,ax=a3,sharex=a1,rot=0,title='2021').legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
