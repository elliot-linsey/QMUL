# %%
import pandas as pd 
import glob
import os
import shutil
import re

# %%
src_folder = r"D:\EOY Datasets\Non-Covid\North"

# %%
os.listdir(src_folder)
# Out:
# ['2017-01-cleveland-outcomes.csv',
#  '2017-01-cleveland-stop-and-search.csv',
#  '2017-01-cleveland-street.csv',
#  '2017-01-cumbria-outcomes.csv',
#  '2017-01-cumbria-stop-and-search.csv',
#  '2017-01-cumbria-street.csv',
#  '2017-01-durham-outcomes.csv',
#  '2017-01-durham-stop-and-search.csv',
#  '2017-01-durham-street.csv',
#  '2017-01-north-yorkshire-outcomes.csv',
#  '2017-01-north-yorkshire-stop-and-search.csv',
#  '2017-01-north-yorkshire-street.csv',
#  '2017-01-northumbria-outcomes.csv',
#  '2017-01-northumbria-stop-and-search.csv',
#  '2017-01-northumbria-street.csv',
#  '2017-02-cleveland-outcomes.csv',
#  '2017-02-cleveland-stop-and-search.csv',
#  '2017-02-cleveland-street.csv',
#  '2017-02-cumbria-outcomes.csv',
#  '2017-02-cumbria-stop-and-search.csv',
#  '2017-02-cumbria-street.csv',
#  '2017-02-durham-outcomes.csv',
#  '2017-02-durham-stop-and-search.csv',
#  '2017-02-durham-street.csv',
#  '2017-02-north-yorkshire-outcomes.csv',
#  '2017-02-north-yorkshire-stop-and-search.csv',
#  '2017-02-north-yorkshire-street.csv',
#  '2017-02-northumbria-outcomes.csv',
#  '2017-02-northumbria-stop-and-search.csv',
#  '2017-02-northumbria-street.csv',
#  '2017-03-cleveland-outcomes.csv',
#  '2017-03-cleveland-stop-and-search.csv',
#  '2017-03-cleveland-street.csv',
#  '2017-03-cumbria-outcomes.csv',
#  '2017-03-cumbria-stop-and-search.csv',
#  '2017-03-cumbria-street.csv',
#  '2017-03-durham-outcomes.csv',
#  '2017-03-durham-stop-and-search.csv',
#  '2017-03-durham-street.csv',
#  '2017-03-north-yorkshire-outcomes.csv',
#  '2017-03-north-yorkshire-stop-and-search.csv',
#  '2017-03-north-yorkshire-street.csv',
#  '2017-03-northumbria-outcomes.csv',
#  '2017-03-northumbria-stop-and-search.csv',
#  '2017-03-northumbria-street.csv',
#  '2017-04-cleveland-outcomes.csv',
#  '2017-04-cleveland-stop-and-search.csv',
#  '2017-04-cleveland-street.csv',
#  '2017-04-cumbria-outcomes.csv',
#  '2017-04-cumbria-stop-and-search.csv',
#  '2017-04-cumbria-street.csv',
#  '2017-04-durham-outcomes.csv',
#  '2017-04-durham-stop-and-search.csv',
#  '2017-04-durham-street.csv',
#  '2017-04-north-yorkshire-outcomes.csv',
#  '2017-04-north-yorkshire-stop-and-search.csv',
#  '2017-04-north-yorkshire-street.csv',
#  '2017-04-northumbria-outcomes.csv',
#  '2017-04-northumbria-stop-and-search.csv',
#  '2017-04-northumbria-street.csv',
#  '2017-05-cleveland-outcomes.csv',
#  '2017-05-cleveland-stop-and-search.csv',
#  '2017-05-cleveland-street.csv',
#  '2017-05-cumbria-outcomes.csv',
#  '2017-05-cumbria-stop-and-search.csv',
#  '2017-05-cumbria-street.csv',
#  '2017-05-durham-outcomes.csv',
#  '2017-05-durham-stop-and-search.csv',
#  '2017-05-durham-street.csv',
#  '2017-05-north-yorkshire-outcomes.csv',
#  '2017-05-north-yorkshire-stop-and-search.csv',
#  '2017-05-north-yorkshire-street.csv',
#  '2017-05-northumbria-outcomes.csv',
#  '2017-05-northumbria-stop-and-search.csv',
#  '2017-05-northumbria-street.csv',
#  '2017-06-cleveland-outcomes.csv',
#  '2017-06-cleveland-stop-and-search.csv',
#  '2017-06-cleveland-street.csv',
#  '2017-06-cumbria-outcomes.csv',
#  '2017-06-cumbria-stop-and-search.csv',
#  '2017-06-cumbria-street.csv',
#  '2017-06-durham-outcomes.csv',
#  '2017-06-durham-stop-and-search.csv',
#  '2017-06-durham-street.csv',
#  '2017-06-north-yorkshire-outcomes.csv',
#  '2017-06-north-yorkshire-stop-and-search.csv',
#  '2017-06-north-yorkshire-street.csv',
#  '2017-06-northumbria-outcomes.csv',
#  '2017-06-northumbria-stop-and-search.csv',
#  '2017-06-northumbria-street.csv',
#  '2017-07-cleveland-outcomes.csv',
#  '2017-07-cleveland-stop-and-search.csv',
#  '2017-07-cleveland-street.csv',
#  '2017-07-cumbria-outcomes.csv',
#  '2017-07-cumbria-stop-and-search.csv',
#  '2017-07-cumbria-street.csv',
#  '2017-07-durham-outcomes.csv',
#  '2017-07-durham-stop-and-search.csv',
#  '2017-07-durham-street.csv',
#  '2017-07-north-yorkshire-outcomes.csv',
#  '2017-07-north-yorkshire-stop-and-search.csv',
#  '2017-07-north-yorkshire-street.csv',
#  '2017-07-northumbria-outcomes.csv',
#  '2017-07-northumbria-stop-and-search.csv',
#  '2017-07-northumbria-street.csv',
#  '2017-08-cleveland-outcomes.csv',
#  '2017-08-cleveland-stop-and-search.csv',
#  '2017-08-cleveland-street.csv',
#  '2017-08-cumbria-outcomes.csv',
#  '2017-08-cumbria-stop-and-search.csv',
#  '2017-08-cumbria-street.csv',
#  '2017-08-durham-outcomes.csv',
#  '2017-08-durham-stop-and-search.csv',
#  '2017-08-durham-street.csv',
#  '2017-08-north-yorkshire-outcomes.csv',
#  '2017-08-north-yorkshire-stop-and-search.csv',
#  '2017-08-north-yorkshire-street.csv',
#  '2017-08-northumbria-outcomes.csv',
#  '2017-08-northumbria-stop-and-search.csv',
#  '2017-08-northumbria-street.csv',
#  '2017-09-cleveland-outcomes.csv',
#  '2017-09-cleveland-stop-and-search.csv',
#  '2017-09-cleveland-street.csv',
#  '2017-09-cumbria-outcomes.csv',
#  '2017-09-cumbria-stop-and-search.csv',
#  '2017-09-cumbria-street.csv',
#  '2017-09-durham-outcomes.csv',
#  '2017-09-durham-stop-and-search.csv',
#  '2017-09-durham-street.csv',
#  '2017-09-north-yorkshire-outcomes.csv',
#  '2017-09-north-yorkshire-stop-and-search.csv',
#  '2017-09-north-yorkshire-street.csv',
#  '2017-09-northumbria-outcomes.csv',
#  '2017-09-northumbria-stop-and-search.csv',
#  '2017-09-northumbria-street.csv',
#  '2017-10-cleveland-outcomes.csv',
#  '2017-10-cleveland-stop-and-search.csv',
#  '2017-10-cleveland-street.csv',
#  '2017-10-cumbria-outcomes.csv',
#  '2017-10-cumbria-stop-and-search.csv',
#  '2017-10-cumbria-street.csv',
#  '2017-10-durham-outcomes.csv',
#  '2017-10-durham-stop-and-search.csv',
#  '2017-10-durham-street.csv',
#  '2017-10-north-yorkshire-outcomes.csv',
#  '2017-10-north-yorkshire-stop-and-search.csv',
#  '2017-10-north-yorkshire-street.csv',
#  '2017-10-northumbria-outcomes.csv',
#  '2017-10-northumbria-stop-and-search.csv',
#  '2017-10-northumbria-street.csv',
#  '2017-11-cleveland-outcomes.csv',
#  '2017-11-cleveland-stop-and-search.csv',
#  '2017-11-cleveland-street.csv',
#  '2017-11-cumbria-outcomes.csv',
#  '2017-11-cumbria-stop-and-search.csv',
#  '2017-11-cumbria-street.csv',
#  '2017-11-durham-outcomes.csv',
#  '2017-11-durham-stop-and-search.csv',
#  '2017-11-durham-street.csv',
#  '2017-11-north-yorkshire-outcomes.csv',
#  '2017-11-north-yorkshire-stop-and-search.csv',
#  '2017-11-north-yorkshire-street.csv',
#  '2017-11-northumbria-outcomes.csv',
#  '2017-11-northumbria-stop-and-search.csv',
#  '2017-11-northumbria-street.csv',
#  '2017-12-cleveland-outcomes.csv',
#  '2017-12-cleveland-stop-and-search.csv',
#  '2017-12-cleveland-street.csv',
#  '2017-12-cumbria-outcomes.csv',
#  '2017-12-cumbria-stop-and-search.csv',
#  '2017-12-cumbria-street.csv',
#  '2017-12-durham-outcomes.csv',
#  '2017-12-durham-stop-and-search.csv',
#  '2017-12-durham-street.csv',
#  '2017-12-north-yorkshire-outcomes.csv',
#  '2017-12-north-yorkshire-stop-and-search.csv',
#  '2017-12-north-yorkshire-street.csv',
#  '2017-12-northumbria-outcomes.csv',
#  '2017-12-northumbria-stop-and-search.csv',
#  '2017-12-northumbria-street.csv',
#  '2018-01-cleveland-outcomes.csv',
#  '2018-01-cleveland-stop-and-search.csv',
#  '2018-01-cleveland-street.csv',
#  '2018-01-cumbria-outcomes.csv',
#  '2018-01-cumbria-stop-and-search.csv',
#  '2018-01-cumbria-street.csv',
#  '2018-01-durham-outcomes.csv',
#  '2018-01-durham-stop-and-search.csv',
#  '2018-01-durham-street.csv',
#  '2018-01-north-yorkshire-outcomes.csv',
#  '2018-01-north-yorkshire-stop-and-search.csv',
#  '2018-01-north-yorkshire-street.csv',
#  '2018-01-northumbria-outcomes.csv',
#  '2018-01-northumbria-stop-and-search.csv',
#  '2018-01-northumbria-street.csv',
#  '2018-02-cleveland-outcomes.csv',
#  '2018-02-cleveland-stop-and-search.csv',
#  '2018-02-cleveland-street.csv',
#  '2018-02-cumbria-outcomes.csv',
#  '2018-02-cumbria-stop-and-search.csv',
#  '2018-02-cumbria-street.csv',
#  '2018-02-durham-outcomes.csv',
#  '2018-02-durham-stop-and-search.csv',
#  '2018-02-durham-street.csv',
#  '2018-02-north-yorkshire-outcomes.csv',
#  '2018-02-north-yorkshire-stop-and-search.csv',
#  '2018-02-north-yorkshire-street.csv',
#  '2018-02-northumbria-outcomes.csv',
#  '2018-02-northumbria-stop-and-search.csv',
#  '2018-02-northumbria-street.csv',
#  '2018-03-cleveland-outcomes.csv',
#  '2018-03-cleveland-stop-and-search.csv',
#  '2018-03-cleveland-street.csv',
#  '2018-03-cumbria-outcomes.csv',
#  '2018-03-cumbria-stop-and-search.csv',
#  '2018-03-cumbria-street.csv',
#  '2018-03-durham-outcomes.csv',
#  '2018-03-durham-stop-and-search.csv',
#  '2018-03-durham-street.csv',
#  '2018-03-north-yorkshire-outcomes.csv',
#  '2018-03-north-yorkshire-stop-and-search.csv',
#  '2018-03-north-yorkshire-street.csv',
#  '2018-03-northumbria-outcomes.csv',
#  '2018-03-northumbria-stop-and-search.csv',
#  '2018-03-northumbria-street.csv',
#  '2018-04-cleveland-outcomes.csv',
#  '2018-04-cleveland-stop-and-search.csv',
#  '2018-04-cleveland-street.csv',
#  '2018-04-cumbria-outcomes.csv',
#  '2018-04-cumbria-stop-and-search.csv',
#  '2018-04-cumbria-street.csv',
#  '2018-04-durham-outcomes.csv',
#  '2018-04-durham-stop-and-search.csv',
#  '2018-04-durham-street.csv',
#  '2018-04-north-yorkshire-outcomes.csv',
#  '2018-04-north-yorkshire-stop-and-search.csv',
#  '2018-04-north-yorkshire-street.csv',
#  '2018-04-northumbria-outcomes.csv',
#  '2018-04-northumbria-stop-and-search.csv',
#  '2018-04-northumbria-street.csv',
#  '2018-05-cleveland-outcomes.csv',
#  '2018-05-cleveland-stop-and-search.csv',
#  '2018-05-cleveland-street.csv',
#  '2018-05-cumbria-outcomes.csv',
#  '2018-05-cumbria-stop-and-search.csv',
#  '2018-05-cumbria-street.csv',
#  '2018-05-durham-outcomes.csv',
#  '2018-05-durham-stop-and-search.csv',
#  '2018-05-durham-street.csv',
#  '2018-05-north-yorkshire-outcomes.csv',
#  '2018-05-north-yorkshire-stop-and-search.csv',
#  '2018-05-north-yorkshire-street.csv',
#  '2018-05-northumbria-outcomes.csv',
#  '2018-05-northumbria-stop-and-search.csv',
#  '2018-05-northumbria-street.csv',
#  '2018-06-cleveland-outcomes.csv',
#  '2018-06-cleveland-stop-and-search.csv',
#  '2018-06-cleveland-street.csv',
#  '2018-06-cumbria-outcomes.csv',
#  '2018-06-cumbria-stop-and-search.csv',
#  '2018-06-cumbria-street.csv',
#  '2018-06-durham-outcomes.csv',
#  '2018-06-durham-stop-and-search.csv',
#  '2018-06-durham-street.csv',
#  '2018-06-north-yorkshire-outcomes.csv',
#  '2018-06-north-yorkshire-stop-and-search.csv',
#  '2018-06-north-yorkshire-street.csv',
#  '2018-06-northumbria-outcomes.csv',
#  '2018-06-northumbria-stop-and-search.csv',
#  '2018-06-northumbria-street.csv',
#  '2018-07-cleveland-outcomes.csv',
#  '2018-07-cleveland-stop-and-search.csv',
#  '2018-07-cleveland-street.csv',
#  '2018-07-cumbria-outcomes.csv',
#  '2018-07-cumbria-stop-and-search.csv',
#  '2018-07-cumbria-street.csv',
#  '2018-07-durham-outcomes.csv',
#  '2018-07-durham-stop-and-search.csv',
#  '2018-07-durham-street.csv',
#  '2018-07-north-yorkshire-outcomes.csv',
#  '2018-07-north-yorkshire-stop-and-search.csv',
#  '2018-07-north-yorkshire-street.csv',
#  '2018-07-northumbria-outcomes.csv',
#  '2018-07-northumbria-stop-and-search.csv',
#  '2018-07-northumbria-street.csv',
#  '2018-08-cleveland-outcomes.csv',
#  '2018-08-cleveland-stop-and-search.csv',
#  '2018-08-cleveland-street.csv',
#  '2018-08-cumbria-outcomes.csv',
#  '2018-08-cumbria-stop-and-search.csv',
#  '2018-08-cumbria-street.csv',
#  '2018-08-durham-outcomes.csv',
#  '2018-08-durham-stop-and-search.csv',
#  '2018-08-durham-street.csv',
#  '2018-08-north-yorkshire-outcomes.csv',
#  '2018-08-north-yorkshire-stop-and-search.csv',
#  '2018-08-north-yorkshire-street.csv',
#  '2018-08-northumbria-outcomes.csv',
#  '2018-08-northumbria-stop-and-search.csv',
#  '2018-08-northumbria-street.csv',
#  '2018-09-cleveland-outcomes.csv',
#  '2018-09-cleveland-stop-and-search.csv',
#  '2018-09-cleveland-street.csv',
#  '2018-09-cumbria-outcomes.csv',
#  '2018-09-cumbria-stop-and-search.csv',
#  '2018-09-cumbria-street.csv',
#  '2018-09-durham-outcomes.csv',
#  '2018-09-durham-stop-and-search.csv',
#  '2018-09-durham-street.csv',
#  '2018-09-north-yorkshire-outcomes.csv',
#  '2018-09-north-yorkshire-stop-and-search.csv',
#  '2018-09-north-yorkshire-street.csv',
#  '2018-09-northumbria-outcomes.csv',
#  '2018-09-northumbria-stop-and-search.csv',
#  '2018-09-northumbria-street.csv',
#  '2018-10-cleveland-outcomes.csv',
#  '2018-10-cleveland-stop-and-search.csv',
#  '2018-10-cleveland-street.csv',
#  '2018-10-cumbria-outcomes.csv',
#  '2018-10-cumbria-stop-and-search.csv',
#  '2018-10-cumbria-street.csv',
#  '2018-10-durham-outcomes.csv',
#  '2018-10-durham-stop-and-search.csv',
#  '2018-10-durham-street.csv',
#  '2018-10-north-yorkshire-outcomes.csv',
#  '2018-10-north-yorkshire-stop-and-search.csv',
#  '2018-10-north-yorkshire-street.csv',
#  '2018-10-northumbria-outcomes.csv',
#  '2018-10-northumbria-stop-and-search.csv',
#  '2018-10-northumbria-street.csv',
#  '2018-11-cleveland-outcomes.csv',
#  '2018-11-cleveland-stop-and-search.csv',
#  '2018-11-cleveland-street.csv',
#  '2018-11-cumbria-outcomes.csv',
#  '2018-11-cumbria-stop-and-search.csv',
#  '2018-11-cumbria-street.csv',
#  '2018-11-durham-outcomes.csv',
#  '2018-11-durham-stop-and-search.csv',
#  '2018-11-durham-street.csv',
#  '2018-11-north-yorkshire-outcomes.csv',
#  '2018-11-north-yorkshire-stop-and-search.csv',
#  '2018-11-north-yorkshire-street.csv',
#  '2018-11-northumbria-outcomes.csv',
#  '2018-11-northumbria-stop-and-search.csv',
#  '2018-11-northumbria-street.csv',
#  '2018-12-cleveland-outcomes.csv',
#  '2018-12-cleveland-stop-and-search.csv',
#  '2018-12-cleveland-street.csv',
#  '2018-12-cumbria-outcomes.csv',
#  '2018-12-cumbria-stop-and-search.csv',
#  '2018-12-cumbria-street.csv',
#  '2018-12-durham-outcomes.csv',
#  '2018-12-durham-stop-and-search.csv',
#  '2018-12-durham-street.csv',
#  '2018-12-north-yorkshire-outcomes.csv',
#  '2018-12-north-yorkshire-stop-and-search.csv',
#  '2018-12-north-yorkshire-street.csv',
#  '2018-12-northumbria-outcomes.csv',
#  '2018-12-northumbria-stop-and-search.csv',
#  '2018-12-northumbria-street.csv',
#  '2019-01-cleveland-outcomes.csv',
#  '2019-01-cleveland-stop-and-search.csv',
#  '2019-01-cleveland-street.csv',
#  '2019-01-cumbria-outcomes.csv',
#  '2019-01-cumbria-stop-and-search.csv',
#  '2019-01-cumbria-street.csv',
#  '2019-01-durham-outcomes.csv',
#  '2019-01-durham-stop-and-search.csv',
#  '2019-01-durham-street.csv',
#  '2019-01-north-yorkshire-outcomes.csv',
#  '2019-01-north-yorkshire-stop-and-search.csv',
#  '2019-01-north-yorkshire-street.csv',
#  '2019-01-northumbria-outcomes.csv',
#  '2019-01-northumbria-stop-and-search.csv',
#  '2019-01-northumbria-street.csv',
#  '2019-02-cleveland-outcomes.csv',
#  '2019-02-cleveland-stop-and-search.csv',
#  '2019-02-cleveland-street.csv',
#  '2019-02-cumbria-outcomes.csv',
#  '2019-02-cumbria-stop-and-search.csv',
#  '2019-02-cumbria-street.csv',
#  '2019-02-durham-outcomes.csv',
#  '2019-02-durham-stop-and-search.csv',
#  '2019-02-durham-street.csv',
#  '2019-02-north-yorkshire-outcomes.csv',
#  '2019-02-north-yorkshire-stop-and-search.csv',
#  '2019-02-north-yorkshire-street.csv',
#  '2019-02-northumbria-outcomes.csv',
#  '2019-02-northumbria-stop-and-search.csv',
#  '2019-02-northumbria-street.csv',
#  '2019-03-cleveland-outcomes.csv',
#  '2019-03-cleveland-stop-and-search.csv',
#  '2019-03-cleveland-street.csv',
#  '2019-03-cumbria-outcomes.csv',
#  '2019-03-cumbria-stop-and-search.csv',
#  '2019-03-cumbria-street.csv',
#  '2019-03-durham-outcomes.csv',
#  '2019-03-durham-stop-and-search.csv',
#  '2019-03-durham-street.csv',
#  '2019-03-north-yorkshire-outcomes.csv',
#  '2019-03-north-yorkshire-stop-and-search.csv',
#  '2019-03-north-yorkshire-street.csv',
#  '2019-03-northumbria-outcomes.csv',
#  '2019-03-northumbria-stop-and-search.csv',
#  '2019-03-northumbria-street.csv',
#  '2019-04-cleveland-outcomes.csv',
#  '2019-04-cleveland-stop-and-search.csv',
#  '2019-04-cleveland-street.csv',
#  '2019-04-cumbria-outcomes.csv',
#  '2019-04-cumbria-stop-and-search.csv',
#  '2019-04-cumbria-street.csv',
#  '2019-04-durham-outcomes.csv',
#  '2019-04-durham-stop-and-search.csv',
#  '2019-04-durham-street.csv',
#  '2019-04-north-yorkshire-outcomes.csv',
#  '2019-04-north-yorkshire-stop-and-search.csv',
#  '2019-04-north-yorkshire-street.csv',
#  '2019-04-northumbria-outcomes.csv',
#  '2019-04-northumbria-stop-and-search.csv',
#  '2019-04-northumbria-street.csv',
#  '2019-05-cleveland-outcomes.csv',
#  '2019-05-cleveland-stop-and-search.csv',
#  '2019-05-cleveland-street.csv',
#  '2019-05-cumbria-outcomes.csv',
#  '2019-05-cumbria-stop-and-search.csv',
#  '2019-05-cumbria-street.csv',
#  '2019-05-durham-outcomes.csv',
#  '2019-05-durham-stop-and-search.csv',
#  '2019-05-durham-street.csv',
#  '2019-05-north-yorkshire-outcomes.csv',
#  '2019-05-north-yorkshire-stop-and-search.csv',
#  '2019-05-north-yorkshire-street.csv',
#  '2019-05-northumbria-outcomes.csv',
#  '2019-05-northumbria-stop-and-search.csv',
#  '2019-05-northumbria-street.csv',
#  '2019-06-cleveland-outcomes.csv',
#  '2019-06-cleveland-stop-and-search.csv',
#  '2019-06-cleveland-street.csv',
#  '2019-06-cumbria-outcomes.csv',
#  '2019-06-cumbria-stop-and-search.csv',
#  '2019-06-cumbria-street.csv',
#  '2019-06-durham-outcomes.csv',
#  '2019-06-durham-stop-and-search.csv',
#  '2019-06-durham-street.csv',
#  '2019-06-north-yorkshire-outcomes.csv',
#  '2019-06-north-yorkshire-stop-and-search.csv',
#  '2019-06-north-yorkshire-street.csv',
#  '2019-06-northumbria-outcomes.csv',
#  '2019-06-northumbria-stop-and-search.csv',
#  '2019-06-northumbria-street.csv',
#  '2019-07-cleveland-outcomes.csv',
#  '2019-07-cleveland-stop-and-search.csv',
#  '2019-07-cleveland-street.csv',
#  '2019-07-cumbria-outcomes.csv',
#  '2019-07-cumbria-stop-and-search.csv',
#  '2019-07-cumbria-street.csv',
#  '2019-07-durham-outcomes.csv',
#  '2019-07-durham-stop-and-search.csv',
#  '2019-07-durham-street.csv',
#  '2019-07-north-yorkshire-outcomes.csv',
#  '2019-07-north-yorkshire-stop-and-search.csv',
#  '2019-07-north-yorkshire-street.csv',
#  '2019-07-northumbria-outcomes.csv',
#  '2019-07-northumbria-stop-and-search.csv',
#  '2019-07-northumbria-street.csv',
#  '2019-08-cleveland-outcomes.csv',
#  '2019-08-cleveland-stop-and-search.csv',
#  '2019-08-cleveland-street.csv',
#  '2019-08-cumbria-outcomes.csv',
#  '2019-08-cumbria-stop-and-search.csv',
#  '2019-08-cumbria-street.csv',
#  '2019-08-durham-outcomes.csv',
#  '2019-08-durham-stop-and-search.csv',
#  '2019-08-durham-street.csv',
#  '2019-08-north-yorkshire-outcomes.csv',
#  '2019-08-north-yorkshire-stop-and-search.csv',
#  '2019-08-north-yorkshire-street.csv',
#  '2019-08-northumbria-outcomes.csv',
#  '2019-08-northumbria-stop-and-search.csv',
#  '2019-08-northumbria-street.csv',
#  '2019-09-cleveland-outcomes.csv',
#  '2019-09-cleveland-stop-and-search.csv',
#  '2019-09-cleveland-street.csv',
#  '2019-09-cumbria-outcomes.csv',
#  '2019-09-cumbria-stop-and-search.csv',
#  '2019-09-cumbria-street.csv',
#  '2019-09-durham-outcomes.csv',
#  '2019-09-durham-stop-and-search.csv',
#  '2019-09-durham-street.csv',
#  '2019-09-north-yorkshire-outcomes.csv',
#  '2019-09-north-yorkshire-stop-and-search.csv',
#  '2019-09-north-yorkshire-street.csv',
#  '2019-09-northumbria-outcomes.csv',
#  '2019-09-northumbria-stop-and-search.csv',
#  '2019-09-northumbria-street.csv',
#  '2019-10-cleveland-outcomes.csv',
#  '2019-10-cleveland-stop-and-search.csv',
#  '2019-10-cleveland-street.csv',
#  '2019-10-cumbria-outcomes.csv',
#  '2019-10-cumbria-stop-and-search.csv',
#  '2019-10-cumbria-street.csv',
#  '2019-10-durham-outcomes.csv',
#  '2019-10-durham-stop-and-search.csv',
#  '2019-10-durham-street.csv',
#  '2019-10-north-yorkshire-outcomes.csv',
#  '2019-10-north-yorkshire-stop-and-search.csv',
#  '2019-10-north-yorkshire-street.csv',
#  '2019-10-northumbria-outcomes.csv',
#  '2019-10-northumbria-stop-and-search.csv',
#  '2019-10-northumbria-street.csv',
#  '2019-11-cleveland-outcomes.csv',
#  '2019-11-cleveland-stop-and-search.csv',
#  '2019-11-cleveland-street.csv',
#  '2019-11-cumbria-outcomes.csv',
#  '2019-11-cumbria-stop-and-search.csv',
#  '2019-11-cumbria-street.csv',
#  '2019-11-durham-outcomes.csv',
#  '2019-11-durham-stop-and-search.csv',
#  '2019-11-durham-street.csv',
#  '2019-11-north-yorkshire-outcomes.csv',
#  '2019-11-north-yorkshire-stop-and-search.csv',
#  '2019-11-north-yorkshire-street.csv',
#  '2019-11-northumbria-outcomes.csv',
#  '2019-11-northumbria-stop-and-search.csv',
#  '2019-11-northumbria-street.csv',
#  '2019-12-cleveland-outcomes.csv',
#  '2019-12-cleveland-stop-and-search.csv',
#  '2019-12-cleveland-street.csv',
#  '2019-12-cumbria-outcomes.csv',
#  '2019-12-cumbria-stop-and-search.csv',
#  '2019-12-cumbria-street.csv',
#  '2019-12-durham-outcomes.csv',
#  '2019-12-durham-stop-and-search.csv',
#  '2019-12-durham-street.csv',
#  '2019-12-north-yorkshire-outcomes.csv',
#  '2019-12-north-yorkshire-stop-and-search.csv',
#  '2019-12-north-yorkshire-street.csv',
#  '2019-12-northumbria-outcomes.csv',
#  '2019-12-northumbria-stop-and-search.csv',
#  '2019-12-northumbria-street.csv']

# %%
street = "street"
outcomes = "outcomes"

# %%
dataframes = []

# %%
for file in os.listdir(src_folder):
    if re.search(outcomes,file):
        dataframes.append(pd.read_csv(src_folder+'\\'+file))
        print('Moved:', file)
    else:
        pass
# Out:
# Moved: 2017-01-cleveland-outcomes.csv
# Moved: 2017-01-cumbria-outcomes.csv
# Moved: 2017-01-durham-outcomes.csv
# Moved: 2017-01-north-yorkshire-outcomes.csv
# Moved: 2017-01-northumbria-outcomes.csv
# Moved: 2017-02-cleveland-outcomes.csv
# Moved: 2017-02-cumbria-outcomes.csv
# Moved: 2017-02-durham-outcomes.csv
# Moved: 2017-02-north-yorkshire-outcomes.csv
# Moved: 2017-02-northumbria-outcomes.csv
# Moved: 2017-03-cleveland-outcomes.csv
# Moved: 2017-03-cumbria-outcomes.csv
# Moved: 2017-03-durham-outcomes.csv
# Moved: 2017-03-north-yorkshire-outcomes.csv
# Moved: 2017-03-northumbria-outcomes.csv
# Moved: 2017-04-cleveland-outcomes.csv
# Moved: 2017-04-cumbria-outcomes.csv
# Moved: 2017-04-durham-outcomes.csv
# Moved: 2017-04-north-yorkshire-outcomes.csv
# Moved: 2017-04-northumbria-outcomes.csv
# Moved: 2017-05-cleveland-outcomes.csv
# Moved: 2017-05-cumbria-outcomes.csv
# Moved: 2017-05-durham-outcomes.csv
# Moved: 2017-05-north-yorkshire-outcomes.csv
# Moved: 2017-05-northumbria-outcomes.csv
# Moved: 2017-06-cleveland-outcomes.csv
# Moved: 2017-06-cumbria-outcomes.csv
# Moved: 2017-06-durham-outcomes.csv
# Moved: 2017-06-north-yorkshire-outcomes.csv
# Moved: 2017-06-northumbria-outcomes.csv
# Moved: 2017-07-cleveland-outcomes.csv
# Moved: 2017-07-cumbria-outcomes.csv
# Moved: 2017-07-durham-outcomes.csv
# Moved: 2017-07-north-yorkshire-outcomes.csv
# Moved: 2017-07-northumbria-outcomes.csv
# Moved: 2017-08-cleveland-outcomes.csv
# Moved: 2017-08-cumbria-outcomes.csv
# Moved: 2017-08-durham-outcomes.csv
# Moved: 2017-08-north-yorkshire-outcomes.csv
# Moved: 2017-08-northumbria-outcomes.csv
# Moved: 2017-09-cleveland-outcomes.csv
# Moved: 2017-09-cumbria-outcomes.csv
# Moved: 2017-09-durham-outcomes.csv
# Moved: 2017-09-north-yorkshire-outcomes.csv
# Moved: 2017-09-northumbria-outcomes.csv
# Moved: 2017-10-cleveland-outcomes.csv
# Moved: 2017-10-cumbria-outcomes.csv
# Moved: 2017-10-durham-outcomes.csv
# Moved: 2017-10-north-yorkshire-outcomes.csv
# Moved: 2017-10-northumbria-outcomes.csv
# Moved: 2017-11-cleveland-outcomes.csv
# Moved: 2017-11-cumbria-outcomes.csv
# Moved: 2017-11-durham-outcomes.csv
# Moved: 2017-11-north-yorkshire-outcomes.csv
# Moved: 2017-11-northumbria-outcomes.csv
# Moved: 2017-12-cleveland-outcomes.csv
# Moved: 2017-12-cumbria-outcomes.csv
# Moved: 2017-12-durham-outcomes.csv
# Moved: 2017-12-north-yorkshire-outcomes.csv
# Moved: 2017-12-northumbria-outcomes.csv
# Moved: 2018-01-cleveland-outcomes.csv
# Moved: 2018-01-cumbria-outcomes.csv
# Moved: 2018-01-durham-outcomes.csv
# Moved: 2018-01-north-yorkshire-outcomes.csv
# Moved: 2018-01-northumbria-outcomes.csv
# Moved: 2018-02-cleveland-outcomes.csv
# Moved: 2018-02-cumbria-outcomes.csv
# Moved: 2018-02-durham-outcomes.csv
# Moved: 2018-02-north-yorkshire-outcomes.csv
# Moved: 2018-02-northumbria-outcomes.csv
# Moved: 2018-03-cleveland-outcomes.csv
# Moved: 2018-03-cumbria-outcomes.csv
# Moved: 2018-03-durham-outcomes.csv
# Moved: 2018-03-north-yorkshire-outcomes.csv
# Moved: 2018-03-northumbria-outcomes.csv
# Moved: 2018-04-cleveland-outcomes.csv
# Moved: 2018-04-cumbria-outcomes.csv
# Moved: 2018-04-durham-outcomes.csv
# Moved: 2018-04-north-yorkshire-outcomes.csv
# Moved: 2018-04-northumbria-outcomes.csv
# Moved: 2018-05-cleveland-outcomes.csv
# Moved: 2018-05-cumbria-outcomes.csv
# Moved: 2018-05-durham-outcomes.csv
# Moved: 2018-05-north-yorkshire-outcomes.csv
# Moved: 2018-05-northumbria-outcomes.csv
# Moved: 2018-06-cleveland-outcomes.csv
# Moved: 2018-06-cumbria-outcomes.csv
# Moved: 2018-06-durham-outcomes.csv
# Moved: 2018-06-north-yorkshire-outcomes.csv
# Moved: 2018-06-northumbria-outcomes.csv
# Moved: 2018-07-cleveland-outcomes.csv
# Moved: 2018-07-cumbria-outcomes.csv
# Moved: 2018-07-durham-outcomes.csv
# Moved: 2018-07-north-yorkshire-outcomes.csv
# Moved: 2018-07-northumbria-outcomes.csv
# Moved: 2018-08-cleveland-outcomes.csv
# Moved: 2018-08-cumbria-outcomes.csv
# Moved: 2018-08-durham-outcomes.csv
# Moved: 2018-08-north-yorkshire-outcomes.csv
# Moved: 2018-08-northumbria-outcomes.csv
# Moved: 2018-09-cleveland-outcomes.csv
# Moved: 2018-09-cumbria-outcomes.csv
# Moved: 2018-09-durham-outcomes.csv
# Moved: 2018-09-north-yorkshire-outcomes.csv
# Moved: 2018-09-northumbria-outcomes.csv
# Moved: 2018-10-cleveland-outcomes.csv
# Moved: 2018-10-cumbria-outcomes.csv
# Moved: 2018-10-durham-outcomes.csv
# Moved: 2018-10-north-yorkshire-outcomes.csv
# Moved: 2018-10-northumbria-outcomes.csv
# Moved: 2018-11-cleveland-outcomes.csv
# Moved: 2018-11-cumbria-outcomes.csv
# Moved: 2018-11-durham-outcomes.csv
# Moved: 2018-11-north-yorkshire-outcomes.csv
# Moved: 2018-11-northumbria-outcomes.csv
# Moved: 2018-12-cleveland-outcomes.csv
# Moved: 2018-12-cumbria-outcomes.csv
# Moved: 2018-12-durham-outcomes.csv
# Moved: 2018-12-north-yorkshire-outcomes.csv
# Moved: 2018-12-northumbria-outcomes.csv
# Moved: 2019-01-cleveland-outcomes.csv
# Moved: 2019-01-cumbria-outcomes.csv
# Moved: 2019-01-durham-outcomes.csv
# Moved: 2019-01-north-yorkshire-outcomes.csv
# Moved: 2019-01-northumbria-outcomes.csv
# Moved: 2019-02-cleveland-outcomes.csv
# Moved: 2019-02-cumbria-outcomes.csv
# Moved: 2019-02-durham-outcomes.csv
# Moved: 2019-02-north-yorkshire-outcomes.csv
# Moved: 2019-02-northumbria-outcomes.csv
# Moved: 2019-03-cleveland-outcomes.csv
# Moved: 2019-03-cumbria-outcomes.csv
# Moved: 2019-03-durham-outcomes.csv
# Moved: 2019-03-north-yorkshire-outcomes.csv
# Moved: 2019-03-northumbria-outcomes.csv
# Moved: 2019-04-cleveland-outcomes.csv
# Moved: 2019-04-cumbria-outcomes.csv
# Moved: 2019-04-durham-outcomes.csv
# Moved: 2019-04-north-yorkshire-outcomes.csv
# Moved: 2019-04-northumbria-outcomes.csv
# Moved: 2019-05-cleveland-outcomes.csv
# Moved: 2019-05-cumbria-outcomes.csv
# Moved: 2019-05-durham-outcomes.csv
# Moved: 2019-05-north-yorkshire-outcomes.csv
# Moved: 2019-05-northumbria-outcomes.csv
# Moved: 2019-06-cleveland-outcomes.csv
# Moved: 2019-06-cumbria-outcomes.csv
# Moved: 2019-06-durham-outcomes.csv
# Moved: 2019-06-north-yorkshire-outcomes.csv
# Moved: 2019-06-northumbria-outcomes.csv
# Moved: 2019-07-cleveland-outcomes.csv
# Moved: 2019-07-cumbria-outcomes.csv
# Moved: 2019-07-durham-outcomes.csv
# Moved: 2019-07-north-yorkshire-outcomes.csv
# Moved: 2019-07-northumbria-outcomes.csv
# Moved: 2019-08-cleveland-outcomes.csv
# Moved: 2019-08-cumbria-outcomes.csv
# Moved: 2019-08-durham-outcomes.csv
# Moved: 2019-08-north-yorkshire-outcomes.csv
# Moved: 2019-08-northumbria-outcomes.csv
# Moved: 2019-09-cleveland-outcomes.csv
# Moved: 2019-09-cumbria-outcomes.csv
# Moved: 2019-09-durham-outcomes.csv
# Moved: 2019-09-north-yorkshire-outcomes.csv
# Moved: 2019-09-northumbria-outcomes.csv
# Moved: 2019-10-cleveland-outcomes.csv
# Moved: 2019-10-cumbria-outcomes.csv
# Moved: 2019-10-durham-outcomes.csv
# Moved: 2019-10-north-yorkshire-outcomes.csv
# Moved: 2019-10-northumbria-outcomes.csv
# Moved: 2019-11-cleveland-outcomes.csv
# Moved: 2019-11-cumbria-outcomes.csv
# Moved: 2019-11-durham-outcomes.csv
# Moved: 2019-11-north-yorkshire-outcomes.csv
# Moved: 2019-11-northumbria-outcomes.csv
# Moved: 2019-12-cleveland-outcomes.csv
# Moved: 2019-12-cumbria-outcomes.csv
# Moved: 2019-12-durham-outcomes.csv
# Moved: 2019-12-north-yorkshire-outcomes.csv
# Moved: 2019-12-northumbria-outcomes.csv

# %%
#dataframes

# %%
full = pd.concat(dataframes)
full
# Out:
#                                                Crime ID    Month  \
# 0     1c37322a4c51a90d619f26e07d489d68f0a911489e9d1a...  2017-01
# 1     69b968bb24e079e9aa0c749f2cac5ceffe9b8da5458138...  2017-01
# 2     ac3c5996f795c01b3ee5b075f01c5fdd1cafad426fb30a...  2017-01
# 3     5092b9f81d12fce075dfd11c637e0aecb288d5c798fe31...  2017-01
# 4     a160ba0d2c85a99788baa55e2e76f1d35241429c9526fd...  2017-01
# ...                                                 ...      ...
# 8465  19805e84352492a21af690bdc13728f488636a7d2036c5...  2019-12
# 8466  0016ddd9f73b579aba6dfedb64d0a28532d81760c5aa57...  2019-12
# 8467  5f16df70420e06bece0404ee50bbcd716c89d3f3091357...  2019-12
# 8468  e9461cd634ecb595e2f7e52c980e174d9e246008ba2d31...  2019-12
# 8469  4ece86daad246e73c37d5418ce9547299c940a88b66733...  2019-12
#
#              Reported by        Falls within  Longitude   Latitude  \
# 0       Cleveland Police    Cleveland Police  -1.230171  54.570781
# 1       Cleveland Police    Cleveland Police  -1.061138  54.617795
# 2       Cleveland Police    Cleveland Police  -1.212715  54.689117
# 3       Cleveland Police    Cleveland Police  -1.216896  54.578200
# 4       Cleveland Police    Cleveland Police  -1.321779  54.558261
# ...                  ...                 ...        ...        ...
# 8465  Northumbria Police  Northumbria Police  -1.434622  55.018192
# 8466  Northumbria Police  Northumbria Police  -1.557276  54.980445
# 8467  Northumbria Police  Northumbria Police  -1.524083  55.112947
# 8468  Northumbria Police  Northumbria Police  -1.439565  55.013623
# 8469  Northumbria Police  Northumbria Police  -1.463508  55.002947
#
#                            Location  LSOA code                  LSOA name  \
# 0         On or near THISTLE STREET  E01012068         Middlesbrough 001A
# 1     On or near GRAFFENBERG STREET  E01012102  Redcar and Cleveland 001C
# 2          On or near Victoria Park  E01011974            Hartlepool 005B
# 3      On or near Riverside Stadium  E01033468         Middlesbrough 001G
# 4           On or near GROVE STREET  E01012262      Stockton-on-Tees 014A
# ...                             ...        ...                        ...
# 8465    On or near KING EDWARD ROAD  E01008558        North Tyneside 016A
# 8466         On or near SCROGG ROAD  E01008391   Newcastle upon Tyne 026E
# 8467          On or near EAST DRIVE  E01027430        Northumberland 024E
# 8468       On or near COBURG STREET  E01008559        North Tyneside 017C
# 8469         On or near AVON AVENUE  E01008485        North Tyneside 023D
#
#                                        Outcome type
# 0           Suspect charged as part of another case
# 1           Suspect charged as part of another case
# 2                          Offender given a caution
# 3                          Offender given a caution
# 4                          Offender given a caution
# ...                                             ...
# 8465  Investigation complete; no suspect identified
# 8466  Investigation complete; no suspect identified
# 8467                                Suspect charged
# 8468  Investigation complete; no suspect identified
# 8469                                Suspect charged
#
# [955823 rows x 10 columns]

# %%
full.to_csv('North_outcomes.csv')
