# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('table7.csv')
df
# Out:
#         Unnamed: 0  Police_Force_Name  Year  Quarter  \
# 0                0  Avon and Somerset  2020        1
# 1                1  Avon and Somerset  2020        1
# 2                2  Avon and Somerset  2020        1
# 3                3  Avon and Somerset  2020        1
# 4                4  Avon and Somerset  2020        1
# ...            ...                ...   ...      ...
# 112781      112781          Wiltshire  2021        1
# 112782      112782          Wiltshire  2021        1
# 112783      112783          Wiltshire  2021        1
# 112784      112784          Wiltshire  2021        1
# 112785      112785          Wiltshire  2021        1
#
#                              Detailed_Offence_Description  \
# 0                                                Homicide
# 1                   Assault without injury on a constable
# 2                                  Assault without injury
# 3       Racially or religiously aggravated assault wit...
# 4                                          Modern slavery
# ...                                                   ...
# 112781  Racially or religiously aggravated public fear...
# 112782  Racially or religiously aggravated public fear...
# 112783  Racially or religiously aggravated public fear...
# 112784  Racially or religiously aggravated public fear...
# 112785  Racially or religiously aggravated public fear...
#
#                       Offence_Group         Offence_Subgroup  \
# 0       Violence against the person                 Homicide
# 1       Violence against the person  Violence without injury
# 2       Violence against the person  Violence without injury
# 3       Violence against the person  Violence without injury
# 4       Violence against the person  Violence without injury
# ...                             ...                      ...
# 112781        Public order offences    Public order offences
# 112782        Public order offences    Public order offences
# 112783        Public order offences    Public order offences
# 112784        Public order offences    Public order offences
# 112785        Public order offences    Public order offences
#
#         Number_of_Arrests  Arrests_Ranked Level_of_Lockdown
# 0                       2  (-0.001. 20.0]              High
# 1                       8  (-0.001. 20.0]              High
# 2                      89   (80.0. 100.0]              High
# 3                       1  (-0.001. 20.0]              High
# 4                       2  (-0.001. 20.0]              High
# ...                   ...             ...               ...
# 112781                  8  (-0.001. 20.0]            Medium
# 112782                 15  (-0.001. 20.0]            Medium
# 112783                  7  (-0.001. 20.0]            Medium
# 112784                 11  (-0.001. 20.0]            Medium
# 112785                  1  (-0.001. 20.0]            Medium
#
# [112786 rows x 10 columns]

# %%
df2 = df.sample(frac=0.1)
df2
# Out:
#         Unnamed: 0   Police_Force_Name  Year  Quarter  \
# 6780          6780  Devon and Cornwall  2020        1
# 109856      109856       Thames Valley  2021        1
# 70218        70218          Humberside  2021        3
# 111182      111182       West Midlands  2021        1
# 106236      106236         South Wales  2021        1
# ...            ...                 ...   ...      ...
# 78495        78495     South Yorkshire  2021        3
# 1773          1773              Surrey  2020        1
# 98449        98449                Kent  2021        1
# 95209        95209  Greater Manchester  2021        1
# 24790        24790       Thames Valley  2020        1
#
#                              Detailed_Offence_Description  \
# 6780                    Cruelty to children/young persons
# 109856                                      Other forgery
# 70218                       Criminal damage to a dwelling
# 111182                        Possession of other weapons
# 106236                                Assault with injury
# ...                                                   ...
# 78495                              Exposure and voyeurism
# 1773                             Malicious Communications
# 98449                          Making off without payment
# 95209                                Burglary Residential
# 24790   Theft in a dwelling other than from an automat...
#
#                                Offence_Group                Offence_Subgroup  \
# 6780             Violence against the person         Violence without injury
# 109856  Miscellaneous crimes against society            Miscellaneous crimes
# 70218              Criminal damage and arson                 Criminal damage
# 111182        Possession of weapons offences  Possession of weapons offences
# 106236           Violence against the person            Violence with injury
# ...                                      ...                             ...
# 78495                        Sexual offences           Other sexual offences
# 1773             Violence against the person         Stalking and harassment
# 98449                         Theft offences            Other theft offences
# 95209                         Theft offences               Domestic burglary
# 24790                         Theft offences            Other theft offences
#
#         Number_of_Arrests  Arrests_Ranked Level_of_Lockdown
# 6780                    6  (-0.001. 20.0]              High
# 109856                  8  (-0.001. 20.0]            Medium
# 70218                 156  (140.0. 160.0]               Low
# 111182                  2  (-0.001. 20.0]            Medium
# 106236                 13  (-0.001. 20.0]            Medium
# ...                   ...             ...               ...
# 78495                   4  (-0.001. 20.0]               Low
# 1773                    7  (-0.001. 20.0]              High
# 98449                   2  (-0.001. 20.0]            Medium
# 95209                  66    (60.0. 80.0]            Medium
# 24790                 121  (120.0. 140.0]              High
#
# [11279 rows x 10 columns]

# %%
#df2.to_csv('tablesample.csv')

# %%
df3 = df.copy()
df3.Police_Force_Name.unique()
# Out:
# array(['Avon and Somerset', 'Bedfordshire', 'British Transport Police',
#        'Cambridgeshire', 'Cheshire', 'Cleveland', 'Cumbria', 'Derbyshire',
#        'Devon and Cornwall', 'Dorset', 'Durham', 'Dyfed-Powys', 'Essex',
#        'Gloucestershire', 'Gwent', 'Hampshire', 'Hertfordshire',
#        'Humberside', 'Kent', 'Lancashire', 'Leicestershire',
#        'Lincolnshire', 'London. City of', 'Merseyside',
#        'Metropolitan Police', 'Norfolk', 'North Wales', 'North Yorkshire',
#        'Northamptonshire', 'Northumbria', 'Nottinghamshire',
#        'South Wales', 'South Yorkshire', 'Staffordshire', 'Suffolk',
#        'Surrey', 'Sussex', 'Thames Valley', 'Warwickshire', 'West Mercia',
#        'West Midlands', 'West Yorkshire', 'Wiltshire',
#        'Greater Manchester'], dtype=object)

# %%
df3.drop(labels=df3.columns[[0]],axis=1,inplace=True)
df3['Region'] = df3.Police_Force_Name.apply(lambda x: 'South East' if x in ['Essex','Kent','London. City of','Metropolitan Police','Hertfordshire',
                                                                           'Bedfordshire','Surrey','Hampshire','Thames Valley','Sussex'] else 'South West' if (x in ['Devon and Cornwall',
                                                                           'Dorset','Avon and Somerset','Wiltshire','Gloucestershire','Gwent','South Wales',
                                                                           'Dyfed-Powys','West Mercia','North Wales']) else 'West Midlands' if (x in ['Warwickshire','West Midlands',
                                                                            'Staffordshire','Derbyshire','Cheshire','Greater Manchester','Merseyside','Lancashire']) else 'East Midlands' 
                                                                            if (x in ['Suffolk','Cambridgeshire','Norfolk','Northamptonshire','Leicestershire','Lincolnshire','Nottinghamshire',
                                                                                    'South Yorkshire','Humberside','West Yorkshire']) else 'North' if (x in ['North Yorkshire','Durham',
                                                                                    'Northumbria','Cumbria','Cleveland']) else 'British Transport Police' if (x == 'British Transport Police') else 'butts')
df3
# Out:
#         Police_Force_Name  Year  Quarter  \
# 0       Avon and Somerset  2020        1
# 1       Avon and Somerset  2020        1
# 2       Avon and Somerset  2020        1
# 3       Avon and Somerset  2020        1
# 4       Avon and Somerset  2020        1
# ...                   ...   ...      ...
# 112781          Wiltshire  2021        1
# 112782          Wiltshire  2021        1
# 112783          Wiltshire  2021        1
# 112784          Wiltshire  2021        1
# 112785          Wiltshire  2021        1
#
#                              Detailed_Offence_Description  \
# 0                                                Homicide
# 1                   Assault without injury on a constable
# 2                                  Assault without injury
# 3       Racially or religiously aggravated assault wit...
# 4                                          Modern slavery
# ...                                                   ...
# 112781  Racially or religiously aggravated public fear...
# 112782  Racially or religiously aggravated public fear...
# 112783  Racially or religiously aggravated public fear...
# 112784  Racially or religiously aggravated public fear...
# 112785  Racially or religiously aggravated public fear...
#
#                       Offence_Group         Offence_Subgroup  \
# 0       Violence against the person                 Homicide
# 1       Violence against the person  Violence without injury
# 2       Violence against the person  Violence without injury
# 3       Violence against the person  Violence without injury
# 4       Violence against the person  Violence without injury
# ...                             ...                      ...
# 112781        Public order offences    Public order offences
# 112782        Public order offences    Public order offences
# 112783        Public order offences    Public order offences
# 112784        Public order offences    Public order offences
# 112785        Public order offences    Public order offences
#
#         Number_of_Arrests  Arrests_Ranked Level_of_Lockdown      Region
# 0                       2  (-0.001. 20.0]              High  South West
# 1                       8  (-0.001. 20.0]              High  South West
# 2                      89   (80.0. 100.0]              High  South West
# 3                       1  (-0.001. 20.0]              High  South West
# 4                       2  (-0.001. 20.0]              High  South West
# ...                   ...             ...               ...         ...
# 112781                  8  (-0.001. 20.0]            Medium  South West
# 112782                 15  (-0.001. 20.0]            Medium  South West
# 112783                  7  (-0.001. 20.0]            Medium  South West
# 112784                 11  (-0.001. 20.0]            Medium  South West
# 112785                  1  (-0.001. 20.0]            Medium  South West
#
# [112786 rows x 10 columns]

# %%
df3.Region.value_counts()
# Out:
# East Midlands               27420
# South East                  26319
# South West                  23826
# West Midlands               21680
# North                       12202
# British Transport Police     1339
# Name: Region, dtype: int64

# %%
df3.to_csv('tablewithregions')
