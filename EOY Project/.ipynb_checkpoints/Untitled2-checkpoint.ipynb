# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tablewithregions.csv')
df
# Out:
#         Unnamed: 0  Police_Force_Name  Year  Quarter  \
# 0                0  Avon and Somerset  2020        1
# 1                1  Avon and Somerset  2020        1
# 2                2  Avon and Somerset  2020        1
# 3                3  Avon and Somerset  2020        1
# 4                4  Avon and Somerset  2020        1
# ...            ...                ...   ...      ...
# 112781      112781          Wiltshire  2021        1
# 112782      112782          Wiltshire  2021        1
# 112783      112783          Wiltshire  2021        1
# 112784      112784          Wiltshire  2021        1
# 112785      112785          Wiltshire  2021        1
#
#                              Detailed_Offence_Description  \
# 0                                                Homicide
# 1                   Assault without injury on a constable
# 2                                  Assault without injury
# 3       Racially or religiously aggravated assault wit...
# ...

# %%
df2 = df[df.Offence_Subgroup == 'Homicide']
df2
# Out:
#         Unnamed: 0         Police_Force_Name  Year  Quarter  \
# 0                0         Avon and Somerset  2020        1
# 109            109  British Transport Police  2020        1
# 148            148            Cambridgeshire  2020        1
# 282            282                Derbyshire  2020        1
# 566            566           Gloucestershire  2020        1
# ...            ...                       ...   ...      ...
# 106354      106354           South Yorkshire  2021        1
# 108769      108769                    Sussex  2021        1
# 109415      109415             Thames Valley  2021        1
# 110552      110552               West Mercia  2021        1
# 111137      111137             West Midlands  2021        1
#
#        Detailed_Offence_Description                Offence_Group  \
# 0                          Homicide  Violence against the person
# 109                        Homicide  Violence against the person
# ...

# %%
#df2.to_csv('Murders.csv')

# %%
df2.Region.unique()
# Out:
# array(['South West', 'British Transport Police', 'East Midlands',
#        'West Midlands', 'South East', 'North'], dtype=object)
