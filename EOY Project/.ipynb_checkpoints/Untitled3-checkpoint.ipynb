# %%
#!pip install matplotlib --force-reinstall --user

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('tablewithregions.csv')
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#         Police_Force_Name  Year  Quarter  \
# 0       Avon and Somerset  2020        1
# 1       Avon and Somerset  2020        1
# 2       Avon and Somerset  2020        1
# 3       Avon and Somerset  2020        1
# 4       Avon and Somerset  2020        1
# ...                   ...   ...      ...
# 112781          Wiltshire  2021        1
# 112782          Wiltshire  2021        1
# 112783          Wiltshire  2021        1
# 112784          Wiltshire  2021        1
# 112785          Wiltshire  2021        1
#
#                              Detailed_Offence_Description  \
# 0                                                Homicide
# 1                   Assault without injury on a constable
# 2                                  Assault without injury
# 3       Racially or religiously aggravated assault wit...
# 4                                          Modern slavery
# ...                                                   ...
# 112781  Racially or religiously aggravated public fear...
# 112782  Racially or religiously aggravated public fear...
# 112783  Racially or religiously aggravated public fear...
# 112784  Racially or religiously aggravated public fear...
# 112785  Racially or religiously aggravated public fear...
#
#                       Offence_Group         Offence_Subgroup  \
# 0       Violence against the person                 Homicide
# 1       Violence against the person  Violence without injury
# 2       Violence against the person  Violence without injury
# 3       Violence against the person  Violence without injury
# 4       Violence against the person  Violence without injury
# ...                             ...                      ...
# 112781        Public order offences    Public order offences
# 112782        Public order offences    Public order offences
# 112783        Public order offences    Public order offences
# 112784        Public order offences    Public order offences
# 112785        Public order offences    Public order offences
#
#         Number_of_Arrests  Arrests_Ranked Level_of_Lockdown      Region
# 0                       2  (-0.001. 20.0]              High  South West
# 1                       8  (-0.001. 20.0]              High  South West
# 2                      89   (80.0. 100.0]              High  South West
# 3                       1  (-0.001. 20.0]              High  South West
# 4                       2  (-0.001. 20.0]              High  South West
# ...                   ...             ...               ...         ...
# 112781                  8  (-0.001. 20.0]            Medium  South West
# 112782                 15  (-0.001. 20.0]            Medium  South West
# 112783                  7  (-0.001. 20.0]            Medium  South West
# 112784                 11  (-0.001. 20.0]            Medium  South West
# 112785                  1  (-0.001. 20.0]            Medium  South West
#
# [112786 rows x 10 columns]

# %%
df['one'] = pd.cut(df.Number_of_Arrests,bins=np.arange(0,220,20),include_lowest=True)
df.one.value_counts()
# Out:
# (-0.001, 20.0]    88035
# (20.0, 40.0]       8468
# (40.0, 60.0]       3969
# (60.0, 80.0]       2336
# (80.0, 100.0]      1547
# (100.0, 120.0]     1136
# (120.0, 140.0]      841
# (140.0, 160.0]      680
# (160.0, 180.0]      528
# (180.0, 200.0]      438
# Name: one, dtype: int64

# %%
df['two'] = pd.cut(df.Number_of_Arrests,bins=np.arange(200,2100,100),include_lowest=False)
df.two.value_counts()
# Out:
# (200, 300]      1484
# (300, 400]       869
# (400, 500]       552
# (500, 600]       388
# (600, 700]       260
# (700, 800]       196
# (800, 900]       154
# (900, 1000]      137
# (1000, 1100]     115
# (1100, 1200]      95
# (1200, 1300]      85
# (1300, 1400]      56
# (1400, 1500]      46
# (1600, 1700]      41
# (1500, 1600]      40
# (1700, 1800]      33
# (1800, 1900]      33
# (1900, 2000]      13
# Name: two, dtype: int64

# %%
df['three'] = df.Number_of_Arrests.apply(lambda x: 'Over 2000' if x > 2000 else 'nan')
#df.three.value_counts()
df[df.three == 'Over 2000']
# Out:
#                Police_Force_Name  Year  Quarter  \
# 2264           Avon and Somerset  2020        1
# 3639    British Transport Police  2020        1
# 3688    British Transport Police  2020        1
# 4504                    Cheshire  2020        1
# 9040                       Essex  2020        1
# ...                          ...   ...      ...
# 111584             West Midlands  2021        1
# 111640             West Midlands  2021        1
# 111671            West Yorkshire  2021        1
# 112276            West Yorkshire  2021        1
# 112362            West Yorkshire  2021        1
#
#           Detailed_Offence_Description                Offence_Group  \
# 2264            Assault without injury  Violence against the person
# 3639             Theft from the person               Theft offences
# 3688                       Other theft               Theft offences
# 4504            Assault without injury  Violence against the person
# 9040            Assault without injury  Violence against the person
# ...                                ...                          ...
# 111584        Malicious Communications  Violence against the person
# 111640  Public fear. alarm or distress        Public order offences
# 111671          Assault without injury  Violence against the person
# 112276        Malicious Communications  Violence against the person
# 112362  Public fear. alarm or distress        Public order offences
#
#                Offence_Subgroup  Number_of_Arrests Arrests_Ranked  \
# 2264    Violence without injury               2054      Over 2000
# 3639      Theft from the person               2971      Over 2000
# 3688       Other theft offences               2223      Over 2000
# 4504    Violence without injury               2004      Over 2000
# 9040    Violence without injury               2908      Over 2000
# ...                         ...                ...            ...
# 111584  Stalking and harassment               2156      Over 2000
# 111640    Public order offences               3005      Over 2000
# 111671  Violence without injury               3094      Over 2000
# 112276  Stalking and harassment               2139      Over 2000
# 112362    Public order offences               2067      Over 2000
#
#        Level_of_Lockdown                    Region  one  two      three
# 2264                High                South West  NaN  NaN  Over 2000
# 3639                High  British Transport Police  NaN  NaN  Over 2000
# 3688                High  British Transport Police  NaN  NaN  Over 2000
# 4504                High             West Midlands  NaN  NaN  Over 2000
# 9040                High                South East  NaN  NaN  Over 2000
# ...                  ...                       ...  ...  ...        ...
# 111584            Medium             West Midlands  NaN  NaN  Over 2000
# 111640            Medium             West Midlands  NaN  NaN  Over 2000
# 111671            Medium             East Midlands  NaN  NaN  Over 2000
# 112276            Medium             East Midlands  NaN  NaN  Over 2000
# 112362            Medium             East Midlands  NaN  NaN  Over 2000
#
# [211 rows x 13 columns]

# %%
df.one, df.two, df.three = df.one.astype('str'),df.two.astype('str'),df.three.astype('str')

# %%
df['test'] = df.one + df.two + df.three
df
# Out:
#         Police_Force_Name  Year  Quarter  \
# 0       Avon and Somerset  2020        1
# 1       Avon and Somerset  2020        1
# 2       Avon and Somerset  2020        1
# 3       Avon and Somerset  2020        1
# 4       Avon and Somerset  2020        1
# ...                   ...   ...      ...
# 112781          Wiltshire  2021        1
# 112782          Wiltshire  2021        1
# 112783          Wiltshire  2021        1
# 112784          Wiltshire  2021        1
# 112785          Wiltshire  2021        1
#
#                              Detailed_Offence_Description  \
# 0                                                Homicide
# 1                   Assault without injury on a constable
# 2                                  Assault without injury
# 3       Racially or religiously aggravated assault wit...
# 4                                          Modern slavery
# ...                                                   ...
# 112781  Racially or religiously aggravated public fear...
# 112782  Racially or religiously aggravated public fear...
# 112783  Racially or religiously aggravated public fear...
# 112784  Racially or religiously aggravated public fear...
# 112785  Racially or religiously aggravated public fear...
#
#                       Offence_Group         Offence_Subgroup  \
# 0       Violence against the person                 Homicide
# 1       Violence against the person  Violence without injury
# 2       Violence against the person  Violence without injury
# 3       Violence against the person  Violence without injury
# 4       Violence against the person  Violence without injury
# ...                             ...                      ...
# 112781        Public order offences    Public order offences
# 112782        Public order offences    Public order offences
# 112783        Public order offences    Public order offences
# 112784        Public order offences    Public order offences
# 112785        Public order offences    Public order offences
#
#         Number_of_Arrests  Arrests_Ranked Level_of_Lockdown      Region  \
# 0                       2  (-0.001. 20.0]              High  South West
# 1                       8  (-0.001. 20.0]              High  South West
# 2                      89   (80.0. 100.0]              High  South West
# 3                       1  (-0.001. 20.0]              High  South West
# 4                       2  (-0.001. 20.0]              High  South West
# ...                   ...             ...               ...         ...
# 112781                  8  (-0.001. 20.0]            Medium  South West
# 112782                 15  (-0.001. 20.0]            Medium  South West
# 112783                  7  (-0.001. 20.0]            Medium  South West
# 112784                 11  (-0.001. 20.0]            Medium  South West
# 112785                  1  (-0.001. 20.0]            Medium  South West
#
#                    one  two three                  test
# 0       (-0.001, 20.0]  nan   nan  (-0.001, 20.0]nannan
# 1       (-0.001, 20.0]  nan   nan  (-0.001, 20.0]nannan
# 2        (80.0, 100.0]  nan   nan   (80.0, 100.0]nannan
# 3       (-0.001, 20.0]  nan   nan  (-0.001, 20.0]nannan
# 4       (-0.001, 20.0]  nan   nan  (-0.001, 20.0]nannan
# ...                ...  ...   ...                   ...
# 112781  (-0.001, 20.0]  nan   nan  (-0.001, 20.0]nannan
# 112782  (-0.001, 20.0]  nan   nan  (-0.001, 20.0]nannan
# 112783  (-0.001, 20.0]  nan   nan  (-0.001, 20.0]nannan
# 112784  (-0.001, 20.0]  nan   nan  (-0.001, 20.0]nannan
# 112785  (-0.001, 20.0]  nan   nan  (-0.001, 20.0]nannan
#
# [112786 rows x 14 columns]

# %%
df.test = df.test.astype('str').str.replace(',','.',regex=True)
df.test = df.test.str.replace('nan','',regex=True)

# %%
df.test.value_counts()
# Out:
# (-0.001. 20.0]    88035
# (20.0. 40.0]       8468
# (40.0. 60.0]       3969
# (60.0. 80.0]       2336
# (80.0. 100.0]      1547
# (200. 300]         1484
# (100.0. 120.0]     1136
# (300. 400]          869
# (120.0. 140.0]      841
# (140.0. 160.0]      680
# (400. 500]          552
# (160.0. 180.0]      528
# (180.0. 200.0]      438
# (500. 600]          388
# (600. 700]          260
# Over 2000           211
# (700. 800]          196
# (800. 900]          154
# (900. 1000]         137
# (1000. 1100]        115
# (1100. 1200]         95
# (1200. 1300]         85
# (1300. 1400]         56
# (1400. 1500]         46
# (1600. 1700]         41
# (1500. 1600]         40
# (1800. 1900]         33
# (1700. 1800]         33
# (1900. 2000]         13
# Name: test, dtype: int64

# %%
df.drop(columns=['one','two','three','Arrests_Ranked'],axis=1,inplace=True)
df.rename(columns={'test':'Arrests_Ranked'},inplace=True)
df
# Out:
#         Police_Force_Name  Year  Quarter  \
# 0       Avon and Somerset  2020        1
# 1       Avon and Somerset  2020        1
# 2       Avon and Somerset  2020        1
# 3       Avon and Somerset  2020        1
# 4       Avon and Somerset  2020        1
# ...                   ...   ...      ...
# 112781          Wiltshire  2021        1
# 112782          Wiltshire  2021        1
# 112783          Wiltshire  2021        1
# 112784          Wiltshire  2021        1
# 112785          Wiltshire  2021        1
#
#                              Detailed_Offence_Description  \
# 0                                                Homicide
# 1                   Assault without injury on a constable
# 2                                  Assault without injury
# 3       Racially or religiously aggravated assault wit...
# 4                                          Modern slavery
# ...                                                   ...
# 112781  Racially or religiously aggravated public fear...
# 112782  Racially or religiously aggravated public fear...
# 112783  Racially or religiously aggravated public fear...
# 112784  Racially or religiously aggravated public fear...
# 112785  Racially or religiously aggravated public fear...
#
#                       Offence_Group         Offence_Subgroup  \
# 0       Violence against the person                 Homicide
# 1       Violence against the person  Violence without injury
# 2       Violence against the person  Violence without injury
# 3       Violence against the person  Violence without injury
# 4       Violence against the person  Violence without injury
# ...                             ...                      ...
# 112781        Public order offences    Public order offences
# 112782        Public order offences    Public order offences
# 112783        Public order offences    Public order offences
# 112784        Public order offences    Public order offences
# 112785        Public order offences    Public order offences
#
#         Number_of_Arrests Level_of_Lockdown      Region  Arrests_Ranked
# 0                       2              High  South West  (-0.001. 20.0]
# 1                       8              High  South West  (-0.001. 20.0]
# 2                      89              High  South West   (80.0. 100.0]
# 3                       1              High  South West  (-0.001. 20.0]
# 4                       2              High  South West  (-0.001. 20.0]
# ...                   ...               ...         ...             ...
# 112781                  8            Medium  South West  (-0.001. 20.0]
# 112782                 15            Medium  South West  (-0.001. 20.0]
# 112783                  7            Medium  South West  (-0.001. 20.0]
# 112784                 11            Medium  South West  (-0.001. 20.0]
# 112785                  1            Medium  South West  (-0.001. 20.0]
#
# [112786 rows x 10 columns]

# %%
#df.Arrests_Ranked.value_counts()

# %%
df = df[df.Offence_Group != 'Possession of weapons offences'].copy()

# %%
df.Offence_Group.value_counts()
# Out:
# Violence against the person             26772
# Theft offences                          25044
# Sexual offences                         18214
# Miscellaneous crimes against society    11723
# Criminal damage and arson               10926
# Public order offences                    6827
# Drug offences                            5895
# Robbery                                  2043
# Name: Offence_Group, dtype: int64

# %%
df['Offence_Group2'] = df.Offence_Group.apply(lambda x: 'Theft offences' if  x == 'Robbery' else ('Public order offences' if x == 'Miscellaneous crimes against society' else x))

# %%
df.drop(columns=['Offence_Group'],axis=1,inplace=True)
df.rename(columns={'Offence_Group2':'Offence_Group'},inplace=True)

# %%
df.Offence_Group.value_counts()
# Out:
# Theft offences                 27087
# Violence against the person    26772
# Public order offences          18550
# Sexual offences                18214
# Criminal damage and arson      10926
# Drug offences                   5895
# Name: Offence_Group, dtype: int64

# %%
df.drop(columns=['Detailed_Offence_Description','Offence_Subgroup',],axis=1,inplace=True)
df
# Out:
#         Police_Force_Name  Year  Quarter  Number_of_Arrests Level_of_Lockdown  \
# 0       Avon and Somerset  2020        1                  2              High
# 1       Avon and Somerset  2020        1                  8              High
# 2       Avon and Somerset  2020        1                 89              High
# 3       Avon and Somerset  2020        1                  1              High
# 4       Avon and Somerset  2020        1                  2              High
# ...                   ...   ...      ...                ...               ...
# 112781          Wiltshire  2021        1                  8            Medium
# 112782          Wiltshire  2021        1                 15            Medium
# 112783          Wiltshire  2021        1                  7            Medium
# 112784          Wiltshire  2021        1                 11            Medium
# 112785          Wiltshire  2021        1                  1            Medium
#
#             Region  Arrests_Ranked                Offence_Group
# 0       South West  (-0.001. 20.0]  Violence against the person
# 1       South West  (-0.001. 20.0]  Violence against the person
# 2       South West   (80.0. 100.0]  Violence against the person
# 3       South West  (-0.001. 20.0]  Violence against the person
# 4       South West  (-0.001. 20.0]  Violence against the person
# ...            ...             ...                          ...
# 112781  South West  (-0.001. 20.0]        Public order offences
# 112782  South West  (-0.001. 20.0]        Public order offences
# 112783  South West  (-0.001. 20.0]        Public order offences
# 112784  South West  (-0.001. 20.0]        Public order offences
# 112785  South West  (-0.001. 20.0]        Public order offences
#
# [107444 rows x 8 columns]

# %%
df = df[['Police_Force_Name','Year','Quarter','Offence_Group','Number_of_Arrests','Arrests_Ranked','Region','Level_of_Lockdown']].copy()
df
# Out:
#         Police_Force_Name  Year  Quarter                Offence_Group  \
# 0       Avon and Somerset  2020        1  Violence against the person
# 1       Avon and Somerset  2020        1  Violence against the person
# 2       Avon and Somerset  2020        1  Violence against the person
# 3       Avon and Somerset  2020        1  Violence against the person
# 4       Avon and Somerset  2020        1  Violence against the person
# ...                   ...   ...      ...                          ...
# 112781          Wiltshire  2021        1        Public order offences
# 112782          Wiltshire  2021        1        Public order offences
# 112783          Wiltshire  2021        1        Public order offences
# 112784          Wiltshire  2021        1        Public order offences
# 112785          Wiltshire  2021        1        Public order offences
#
#         Number_of_Arrests  Arrests_Ranked      Region Level_of_Lockdown
# 0                       2  (-0.001. 20.0]  South West              High
# 1                       8  (-0.001. 20.0]  South West              High
# 2                      89   (80.0. 100.0]  South West              High
# 3                       1  (-0.001. 20.0]  South West              High
# 4                       2  (-0.001. 20.0]  South West              High
# ...                   ...             ...         ...               ...
# 112781                  8  (-0.001. 20.0]  South West            Medium
# 112782                 15  (-0.001. 20.0]  South West            Medium
# 112783                  7  (-0.001. 20.0]  South West            Medium
# 112784                 11  (-0.001. 20.0]  South West            Medium
# 112785                  1  (-0.001. 20.0]  South West            Medium
#
# [107444 rows x 8 columns]

# %%
#df.to_csv('UK_Lockdown_Crime.csv')

# %%
sns.barplot(data=df,x='Year',y='Number_of_Arrests',hue='Offence_Group',estimator=sum)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Number_of_Arrests'>
