# %%
import numpy as np

# %%
data = np.array([5,7,4,6,8,15,17,14,15,16,25,27,24,26,28])

# %%
k = 3
clusters = np.random.choice(len(data),replace=False,size=3)
print(clusters)
# Out:
# [3 5 7]

# %%
dist1 = []
dist2 = []
dist3 = []

for i in range(len(data)):
    dist1.append(abs(data[clusters[0]] - data[i]))
    dist2.append(abs(data[clusters[1]] - data[i]))
    dist3.append(abs(data[clusters[2]] - data[i]))  


print(dist1)
print(dist2)
print(dist3)
# Out:
# [1, 1, 2, 0, 2, 9, 11, 8, 9, 10, 19, 21, 18, 20, 22]
# [10, 8, 11, 9, 7, 0, 2, 1, 0, 1, 10, 12, 9, 11, 13]
# [9, 7, 10, 8, 6, 1, 3, 0, 1, 2, 11, 13, 10, 12, 14]

# %%
cluster_values1 = []
cluster_values2 = []
cluster_values3 = []

for i in range(len(dist1)):
    if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
        cluster_values1.append(data[i])
        
for i in range(len(dist1)):
    if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
        cluster_values2.append(data[i])
        
for i in range(len(dist1)):
    if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
        cluster_values3.append(data[i])
    
    
print(cluster_values1)
print(cluster_values2)
print(cluster_values3)
# Out:
# [5, 7, 4, 6, 8]
# [15, 17, 15, 16, 25, 27, 24, 26, 28]
# [14]

# %%
clust_mean1 = np.mean(cluster_values1)
clust_mean2 = np.mean(cluster_values2)
clust_mean3 = np.mean(cluster_values3)

print(clust_mean1)
print(clust_mean2)
print(clust_mean3)

clust_var1 = np.var(cluster_values1)
clust_var2 = np.var(cluster_values2)
clust_var3 = np.var(cluster_values3)

print(clust_var1)
print(clust_var1)
print(clust_var1)

total_var = clust_var1 + clust_var2 + clust_var3
print(total_var)
# Out:
# 6.0
# 21.444444444444443
# 14.0
# 2.0
# 2.0
# 2.0
# 29.358024691358025

# %%
def k_means(data):

    k = 3
    #Choosing random numbers from data array
    clusters = np.random.choice(len(data),replace=False,size=k)
    print(clusters)
    
    #determining the distance of each data point from the chosen
    #random data points
    dist1 = []
    dist2 = []
    dist3 = []
    for i in range(len(data)):
        dist1.append(abs(data[clusters[0]] - data[i]))
        dist2.append(abs(data[clusters[1]] - data[i]))
        dist3.append(abs(data[clusters[2]] - data[i]))  


    #print(dist1)
    #print(dist2)
    #print(dist3)
    
    #appending all the smallest distances to the corresponding
    #random data point
    cluster_values1 = []
    cluster_values2 = []
    cluster_values3 = []

    for i in range(len(dist1)):
        if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
            cluster_values1.append(data[i])

    for i in range(len(dist1)):
        if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
            cluster_values2.append(data[i])

    for i in range(len(dist1)):
        if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
            cluster_values3.append(data[i])


    #print(cluster_values1)
    #print(cluster_values2)
    #print(cluster_values3)
    
    #taking the means of each cluster
    clust_mean1 = np.mean(cluster_values1)
    clust_mean2 = np.mean(cluster_values2)
    clust_mean3 = np.mean(cluster_values3)

    #print(clust_mean1)
    #print(clust_mean2)
    #print(clust_mean3)
    
    #taking the variance of each cluster
    clust_var1 = np.var(cluster_values1)
    clust_var2 = np.var(cluster_values2)
    clust_var3 = np.var(cluster_values3)

    #print(clust_var1)
    #print(clust_var1)
    #print(clust_var1)
    
    #summing the variances, the smaller the variance the more clustered the data
    total_var = clust_var1 + clust_var2 + clust_var3
    #print(total_var)
    
    #returning the total variance along with the corresponding random points initially chosen
    #ie the chosen centres of the cluster
    return "total var = " + str(total_var), 'clusters = ' + str((data[clusters[0]], data[clusters[1]], data[clusters[2]]))

# %%
#running it 10 times and adding the values to a dictionary 
cluster_total = {}
for i in range(1,11):
    cluster_total[i] = k_means(data)

print(cluster_total)
#Smallest variance appears to be 5.04
# Out:
# [9 2 0]
# [14  8  4]
# [ 2  3 12]
# [ 6 10 11]
# [ 0  7 12]
# [3 0 4]
# [ 7  9 10]
# [ 1  3 14]
# [ 1  8 14]
# [ 3  2 13]
# {1: ('total var = 30.860000000000003', 'clusters = (16, 4, 5)'), 2: ('total var = 5.04', 'clusters = (28, 15, 8)'), 3: ('total var = 29.605867346938773', 'clusters = (4, 6, 24)'), 4: ('total var = 24.11', 'clusters = (17, 25, 27)'), 5: ('total var = 5.04', 'clusters = (5, 14, 24)'), 6: ('total var = 40.49793388429751', 'clusters = (6, 5, 8)'), 7: ('total var = 12.805555555555557', 'clusters = (14, 16, 25)'), 8: ('total var = 16.217687074829932', 'clusters = (7, 6, 28)'), 9: ('total var = 5.04', 'clusters = (7, 15, 28)'), 10: ('total var = 28.055555555555557', 'clusters = (6, 4, 26)')}

# %%
print(x,y,z)

def c_means(data,x,y,z):
    variances = []
    if len(variances) == 10:
        return variances
    else:
        
        dist1 = []
        dist2 = []
        dist3 = []
        for i in range(len(data)):
            dist1.append(abs(x - data[i]))
            dist2.append(abs(y - data[i]))
            dist3.append(abs(z - data[i]))
        print('initial cluster means ' + str((x,y,z)))
        print('cluster mean 1 distances ',dist1)
        print('cluster mean 2 distances ',dist2)
        print('cluster mean 3 distances ',dist3)
        cluster_values1 = []
        cluster_values2 = []
        cluster_values3 = []
        for i in range(len(dist1)):
            if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
                cluster_values1.append(data[i])

        for i in range(len(dist1)):
            if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
                cluster_values2.append(data[i])

        for i in range(len(dist1)):
            if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
                cluster_values3.append(data[i])

        clust_mean1 = np.mean(cluster_values1)
        clust_mean2 = np.mean(cluster_values2)
        clust_mean3 = np.mean(cluster_values3)
        print('second cluster means ' + str((clust_mean1,clust_mean2,clust_mean3)))
        clust_var1 = np.var(cluster_values1)
        clust_var2 = np.var(cluster_values2)
        clust_var3 = np.var(cluster_values3)

        total_var = clust_var1 + clust_var2 + clust_var3
        print('second total var' + str(total_var))
    return variances.append(c_means(data, clust_mean1,clust_mean2,clust_mean3))
    
    

def k_means(data):
    variances = []
    k = 3
    #Choosing random numbers from data array
    x,y,z = np.random.choice(len(data),size=3, replace=False)
    #clusters = np.random.choice(len(data),replace=False,size=k)
    #print(clusters)
    
    #determining the distance of each data point from the chosen
    #random data points
    dist1 = []
    dist2 = []
    dist3 = []
    for i in range(len(data)):
        dist1.append(abs(data[x] - data[i]))
        dist2.append(abs(data[y] - data[i]))
        dist3.append(abs(data[z] - data[i]))  


    #print(dist1)
    #print(dist2)
    #print(dist3)
    
    #appending all the smallest distances to the corresponding
    #random data point
    cluster_values1 = []
    cluster_values2 = []
    cluster_values3 = []

    for i in range(len(dist1)):
        if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
            cluster_values1.append(data[i])

    for i in range(len(dist1)):
        if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
            cluster_values2.append(data[i])

    for i in range(len(dist1)):
        if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
            cluster_values3.append(data[i])


    #print(cluster_values1)
    #print(cluster_values2)
    #print(cluster_values3)
    
    #taking the means of each cluster
    clust_mean1 = np.mean(cluster_values1)
    clust_mean2 = np.mean(cluster_values2)
    clust_mean3 = np.mean(cluster_values3)

    #print(clust_mean1)
    #print(clust_mean2)
    #print(clust_mean3)
    
    #taking the variance of each cluster
    clust_var1 = np.var(cluster_values1)
    clust_var2 = np.var(cluster_values2)
    clust_var3 = np.var(cluster_values3)

    #print(clust_var1)
    #print(clust_var1)
    #print(clust_var1)
    
    #summing the variances, the smaller the variance the more clustered the data
    total_var = clust_var1 + clust_var2 + clust_var3
    print('Initial variance ' + str(total_var))
    
    
    return c_means(data, clust_mean1, clust_mean2, clust_mean3)
    
    
    #returning the total variance along with the corresponding random points initially chosen
    #ie the chosen centres of the cluster
    #variances.append(total_var)
    #while len(variances) < 10:
        #k_means(data,x=clust_mean1,y=clust_mean2,z=clust_mean3)
    #return total_var, variances
# Out:
# 0 7 3

# %%
#running it 10 times and adding the values to a dictionary 
cluster_total = {}
for i in range(1,11):
    cluster_total[i] = k_means(data)

print(cluster_total)
#Smallest variance appears to be 5.04
# Out:
# Initial variance 21.918367346938773
# initial cluster means (6.0, 14.0, 23.285714285714285)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [9.0, 7.0, 10.0, 8.0, 6.0, 1.0, 3.0, 0.0, 1.0, 2.0, 11.0, 13.0, 10.0, 12.0, 14.0]
# cluster mean 3 distances  [18.285714285714285, 16.285714285714285, 19.285714285714285, 17.285714285714285, 15.285714285714285, 8.285714285714285, 6.285714285714285, 9.285714285714285, 8.285714285714285, 7.285714285714285, 1.7142857142857153, 3.7142857142857153, 0.7142857142857153, 2.7142857142857153, 4.714285714285715]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# ...
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# second cluster means (6.0, 15.4, 26.0)
# second total var5.04
# initial cluster means (6.0, 15.4, 26.0)
# cluster mean 1 distances  [1.0, 1.0, 2.0, 0.0, 2.0, 9.0, 11.0, 8.0, 9.0, 10.0, 19.0, 21.0, 18.0, 20.0, 22.0]
# cluster mean 2 distances  [10.4, 8.4, 11.4, 9.4, 7.4, 0.40000000000000036, 1.5999999999999996, 1.4000000000000004, 0.40000000000000036, 0.5999999999999996, 9.6, 11.6, 8.6, 10.6, 12.6]
# cluster mean 3 distances  [21.0, 19.0, 22.0, 20.0, 18.0, 11.0, 9.0, 12.0, 11.0, 10.0, 1.0, 1.0, 2.0, 0.0, 2.0]
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1324/1230030505.py in <module>
#       2 cluster_total = {}
#       3 for i in range(1,11):
# ----> 4     cluster_total[i] = k_means(data)
#       5
#       6 print(cluster_total)
#
# ~\AppData\Local\Temp/ipykernel_1324/1221180737.py in k_means(data)
#     116
#     117
# --> 118     return c_means(data, clust_mean1, clust_mean2, clust_mean3)
#     119
#     120
#
# ~\AppData\Local\Temp/ipykernel_1324/1221180737.py in c_means(data, x, y, z)
#      43         total_var = clust_var1 + clust_var2 + clust_var3
#      44         print('second total var' + str(total_var))
# ---> 45     return variances.append(c_means(data, clust_mean1,clust_mean2,clust_mean3))
#      46
#      47
#
# ... last 1 frames repeated, from the frame below ...
#
# ~\AppData\Local\Temp/ipykernel_1324/1221180737.py in c_means(data, x, y, z)
#      43         total_var = clust_var1 + clust_var2 + clust_var3
#      44         print('second total var' + str(total_var))
# ---> 45     return variances.append(c_means(data, clust_mean1,clust_mean2,clust_mean3))
#      46
#      47
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
print(k_means(data))

# %%
lst = []
def recursion(n):
    if len(lst) == 10:
        return lst
    else:
        lst.append(n)
        return lst
    
    
    

print(recursion(12))
