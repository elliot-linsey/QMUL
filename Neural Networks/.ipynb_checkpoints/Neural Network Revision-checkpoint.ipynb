# %%
import torch
import my_utils as mu
import pandas as pd
import torch.utils.data as data
from torch import nn

# %%
df = pd.read_csv('Fish.csv')
df = df.drop(columns='Species',axis=1)
df
# Out:
#      Weight  Length1  Length2  Length3   Height   Width
# 0     242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...      ...      ...      ...      ...     ...
# 154    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
df_zscore = (df - df.mean())/df.std()
df_zscore
# Out:
#        Weight   Length1   Length2   Length3    Height     Width
# 0   -0.436692 -0.304825 -0.281414 -0.105686  0.594700 -0.235784
# 1   -0.302606 -0.224797 -0.197430 -0.002329  0.818674 -0.066369
# 2   -0.162933 -0.234801 -0.178767 -0.010942  0.794830  0.165271
# 3   -0.098683  0.005285  0.054522  0.195772  0.877001  0.022550
# 4    0.088479  0.025292  0.054522  0.238837  0.810275  0.425028
# ..        ...       ...       ...       ...       ...       ...
# 154 -1.078631 -1.475242 -1.513179 -1.535458 -1.605287 -1.793735
# 155 -1.075279 -1.455235 -1.494516 -1.526845 -1.526056 -1.867646
# 156 -1.078631 -1.415221 -1.438527 -1.501006 -1.561752 -1.875476
# 157 -1.057680 -1.305181 -1.317216 -1.380422 -1.422748 -1.394163
# 158 -1.057121 -1.245160 -1.251896 -1.294292 -1.408890 -1.505683
#
# [159 rows x 6 columns]

# %%
feats = torch.tensor(df_zscore.iloc[::,-2:].values).to(dtype=torch.float32)
labs = torch.tensor(df_zscore.iloc[::,0].values).to(dtype=torch.float32)
feats
# Out:
# tensor([[ 0.5947, -0.2358],
#         [ 0.8187, -0.0664],
#         [ 0.7948,  0.1653],
#         [ 0.8770,  0.0225],
#         [ 0.8103,  0.4250],
#         [ 1.0805,  0.3025],
#         [ 1.2152,  0.5107],
#         [ 0.8630,  0.1617],
#         [ 1.1744,  0.2529],
#         [ 1.2262,  0.3215],
#         [ 1.2346,  0.4074],
#         [ 1.2599,  0.2356],
#         [ 1.1171, -0.0294],
#         [ 1.1530,  0.3887],
#         [ 1.3960,  0.4469],
#         [ 1.5088,  0.6896],
#         [ 1.3740,  0.5148],
#         [ 1.3921,  0.4627],
#         [ 1.5543,  0.4249],
#         [ 1.2838,  0.7771],
#         [ 1.4366,  0.6834],
#         [ 1.6384,  0.5653],
#         [ 1.5286,  0.5117],
#         [ 1.5159,  1.0162],
#         [ 1.6960,  0.6949],
#         [ 1.7239,  0.9703],
#         [ 1.7243,  0.9921],
#         [ 1.7605,  0.8506],
#         [ 1.8475,  1.0564],
#         [ 2.3298,  1.2964],
#         [ 2.1151,  1.1204],
#         [ 2.1261,  1.1119],
#         [ 2.2825,  1.3834],
#         [ 2.2548,  1.3820],
#         [ 2.0187,  1.1585],
#         [-1.1254, -1.2751],
#         [-0.8569, -0.9466],
#         [-0.7922, -0.8975],
#         [-0.7826, -0.7373],
#         [-0.6428, -0.5002],
#         [-0.5823, -0.6323],
#         [-0.6540, -0.6061],
#         [-0.6664, -0.6663],
#         [-0.7388, -0.3933],
#         [-0.5453, -0.5159],
#         [-0.4521, -0.3542],
#         [-0.5648, -0.6481],
#         [-0.5998, -0.3663],
#         [-0.3352, -0.3454],
#         [-0.4796, -0.4664],
#         [-0.3673, -0.1722],
#         [-0.4396, -0.3034],
#         [-0.0220,  0.0470],
#         [-0.0940,  0.2112],
#         [ 0.1199,  0.5561],
#         [-0.1378, -0.1008],
#         [-0.1926, -0.1002],
#         [-0.0450,  0.1567],
#         [ 0.4137,  1.2721],
#         [ 0.6510,  1.2790],
#         [ 0.7893,  1.2502],
#         [-0.4954, -1.2403],
#         [-0.5585, -1.2476],
#         [-0.3653, -1.0348],
#         [-0.1350, -0.8894],
#         [-0.0182, -0.6672],
#         [-0.1011, -0.6662],
#         [ 0.0992, -0.5974],
#         [ 0.1786, -0.7476],
#         [ 0.3208, -0.4472],
#         [ 0.4939, -0.1622],
#         [ 0.5592, -0.1088],
#         [-1.6002, -1.7852],
#         [-1.2699, -1.4345],
#         [-1.2008, -1.1778],
#         [-1.0216, -1.0594],
#         [-1.0226, -0.8755],
#         [-0.8746, -0.6501],
#         [-0.8800, -0.7676],
#         [-0.7781, -0.8111],
#         [-0.8944, -0.8190],
#         [-0.9073, -0.9761],
#         [-0.7649, -0.5116],
#         [-0.7124, -0.6584],
#         [-0.7649, -0.4449],
#         [-0.6036, -0.5241],
#         [-0.6675, -0.5991],
#         [-0.7771, -0.5294],
#         [-0.6675, -0.5294],
#         [-0.7223, -0.5294],
#         [-0.8046, -0.2506],
#         [-0.7267, -0.4707],
#         [-0.5084, -0.4707],
#         [-0.7041, -0.4671],
#         [-0.8755, -0.4695],
#         [-0.6290, -0.4108],
#         [-0.3915, -0.4120],
#         [-0.6057, -0.3515],
#         [-0.5220, -0.1493],
#         [-0.5906, -0.4354],
#         [-0.5623, -0.1059],
#         [-0.4207, -0.1622],
#         [-0.1512,  0.4270],
#         [-0.4208, -0.0489],
#         [-0.4478, -0.0489],
#         [-0.3939,  0.0882],
#         [-0.2684, -0.1265],
#         [-0.3233,  0.1293],
#         [-0.3162,  0.2101],
#         [ 0.2471,  0.9494],
#         [ 0.2999,  1.1686],
#         [ 0.5873,  2.0039],
#         [ 0.4456,  1.4512],
#         [ 0.3822,  1.3782],
#         [ 0.4349,  1.0957],
#         [ 0.3735,  1.1562],
#         [ 0.5052,  1.8246],
#         [ 0.5052,  0.9405],
#         [ 0.8073,  1.7404],
#         [ 0.6900,  1.5950],
#         [ 0.6437,  1.6654],
#         [ 0.7955,  1.8062],
#         [ 0.5049,  1.3124],
#         [ 0.8934,  1.4539],
#         [ 0.6910,  1.6964],
#         [ 0.8263,  1.7790],
#         [ 0.8476,  2.2093],
#         [ 0.8207,  1.8853],
#         [-0.7939, -0.6180],
#         [-0.7613, -0.1539],
#         [-0.7080, -0.0196],
#         [-0.6259, -0.2359],
#         [-0.3922,  0.0943],
#         [-0.6008, -0.2613],
#         [-0.3945, -0.0563],
#         [-0.5007,  0.0246],
#         [-0.2765,  0.4224],
#         [-0.4692,  0.2838],
#         [-0.2751,  0.2684],
#         [-0.3012,  0.5686],
#         [-0.0105,  1.0403],
#         [ 0.4002,  1.5230],
#         [ 0.1468,  1.0241],
#         [ 0.1468,  1.0241],
#         [ 0.4295,  1.8166],
#         [-1.6873, -1.9990],
#         [-1.6329, -1.9323],
#         [-1.6897, -1.9392],
#         [-1.5806, -1.8018],
#         [-1.6070, -1.8628],
#         [-1.6315, -1.8580],
#         [-1.5765, -1.8589],
#         [-1.5765, -1.9288],
#         [-1.5787, -1.9392],
#         [-1.6053, -1.7937],
#         [-1.5261, -1.8676],
#         [-1.5618, -1.8755],
#         [-1.4227, -1.3942],
#         [-1.4089, -1.5057]])

# %%
dataset = data.TensorDataset(feats,labs)
train_iter, test_iter = data.random_split(dataset,[109,50],generator=torch.Generator().manual_seed(42))
batch_size = 10
train_iter,test_iter = data.DataLoader(train_iter,batch_size),data.DataLoader(test_iter,batch_size)
data_iter = data.DataLoader(dataset,batch_size)
print(dataset[0])
# Out:
# (tensor([ 0.5947, -0.2358]), tensor(-0.4367))

# %%
next(iter(data_iter))
# Out:
# [tensor([[ 0.5947, -0.2358],
#          [ 0.8187, -0.0664],
#          [ 0.7948,  0.1653],
#          [ 0.8770,  0.0225],
#          [ 0.8103,  0.4250],
#          [ 1.0805,  0.3025],
#          [ 1.2152,  0.5107],
#          [ 0.8630,  0.1617],
#          [ 1.1744,  0.2529],
#          [ 1.2262,  0.3215]]),
#  tensor([-0.4367, -0.3026, -0.1629, -0.0987,  0.0885,  0.1443,  0.2840, -0.0233,
#           0.1443,  0.2840])]

# %%
num_inputs,num_outputs = 2,1
net = nn.Linear(num_inputs,num_outputs)

# %%
def init_weights(m):
    if isinstance(m, nn.Linear): # by checking the type we can init different layers in different ways
        torch.nn.init.normal_(m.weight, std=0.01)
        torch.nn.init.zeros_(m.bias)

# %%
net.apply(init_weights)
# Out:
# Linear(in_features=2, out_features=1, bias=True)

# %%
optimizer = torch.optim.SGD(net.parameters(),lr=0.1)
loss = nn.MSELoss()
num_epochs=30

# %%
X,y = next(iter(data_iter))
X.shape
y.shape
# Out:
# torch.Size([10])

# %%
# X,y = next(iter(data_iter))
# net(X.float()).view(-1)

# %%
for epoch in range(num_epochs):
    for X,y in data_iter:
        y_hat = net(X)
        #print(y_hat.reshape(-1).shape)
        #print(y_hat)
        l = loss(y_hat.reshape(-1),y)
        #print(y_hat.view(-1).shape)
        optimizer.zero_grad()
        l.backward()
        optimizer.step()
    #print(feats.shape)
    l = loss(net(feats).reshape(-1),labs)
    print(f'epoch {epoch+1},loss {l:f}')
# Out:
# epoch 1,loss 0.476142
# epoch 2,loss 0.389937
# epoch 3,loss 0.361006
# epoch 4,loss 0.350736
# epoch 5,loss 0.346769
# epoch 6,loss 0.345091
# epoch 7,loss 0.344320
# epoch 8,loss 0.343943
# epoch 9,loss 0.343750
# epoch 10,loss 0.343649
# epoch 11,loss 0.343595
# epoch 12,loss 0.343566
# epoch 13,loss 0.343550
# epoch 14,loss 0.343541
# epoch 15,loss 0.343537
# epoch 16,loss 0.343534
# epoch 17,loss 0.343533
# epoch 18,loss 0.343532
# epoch 19,loss 0.343532
# epoch 20,loss 0.343531
# epoch 21,loss 0.343531
# epoch 22,loss 0.343531
# epoch 23,loss 0.343531
# epoch 24,loss 0.343531
# epoch 25,loss 0.343531
# epoch 26,loss 0.343531
# epoch 27,loss 0.343531
# epoch 28,loss 0.343531
# epoch 29,loss 0.343531
# epoch 30,loss 0.343531

# %%
w=net.weight.data
w
# Out:
# tensor([[-0.0975,  0.7707]])
