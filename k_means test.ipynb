# %%
import numpy as np

# %%
data = np.array([5,7,6,3,4,7,6,5,7,8,23,42,12,53,25,43,34,23,64,32,12,15,2,34,4,6,8,15,17,14,15,16,25,27,24,26,28])

# %%
def k_means(data):

    k = 3
    #Choosing random numbers from data array
    clusters = np.random.choice(data,replace=False,size=k)
    #print(clusters)
    
    centroid1 = clusters[0]
    centroid2 = clusters[1]
    centroid3 = clusters[2]
    #print(centroid1)
    #determining the distance of each data point from the chosen
    #random data points
    dist1 = []
    dist2 = []
    dist3 = []
    for i in range(len(data)):
        dist1.append(abs(centroid1 - data[i]))
        dist2.append(abs(centroid2 - data[i]))
        dist3.append(abs(centroid3 - data[i]))  


    #print(dist1)
    #print(dist2)
    #print(dist3)
    
    #appending all the smallest distances to the corresponding
    #random data point
    cluster_values1 = []
    cluster_values2 = []
    cluster_values3 = []

    for i in range(len(dist1)):
        if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
            cluster_values1.append(data[i])

    for i in range(len(dist1)):
        if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
            cluster_values2.append(data[i])

    for i in range(len(dist1)):
        if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
            cluster_values3.append(data[i])


    #print(cluster_values1)
    #print(cluster_values2)
    #print(cluster_values3)
    
    #taking the means of each cluster
    clust_mean1 = np.mean(cluster_values1)
    clust_mean2 = np.mean(cluster_values2)
    clust_mean3 = np.mean(cluster_values3)

    print(clust_mean1)
    #print(clust_mean2)
    #print(clust_mean3)
    
    centroid1 = clust_mean1
    centroid2 = clust_mean2
    centroid3 = clust_mean3
    #print(centroid1)
    #determining the distance of each data point from the chosen
    #random data points
    dist1 = []
    dist2 = []
    dist3 = []
    for i in range(len(data)):
        dist1.append(abs(centroid1 - data[i]))
        dist2.append(abs(centroid2 - data[i]))
        dist3.append(abs(centroid3 - data[i]))  


    #print(dist1)
    #print(dist2)
    #print(dist3)
    
    #appending all the smallest distances to the corresponding
    #random data point
    cluster_values1 = []
    cluster_values2 = []
    cluster_values3 = []

    for i in range(len(dist1)):
        if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
            cluster_values1.append(data[i])

    for i in range(len(dist1)):
        if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
            cluster_values2.append(data[i])

    for i in range(len(dist1)):
        if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
            cluster_values3.append(data[i])


    #print(cluster_values1)
    #print(cluster_values2)
    #print(cluster_values3)
    
    #taking the means of each cluster
    clust_mean1 = np.mean(cluster_values1)
    clust_mean2 = np.mean(cluster_values2)
    clust_mean3 = np.mean(cluster_values3)

    print(clust_mean1)
    #print(clust_mean2)
    #print(clust_mean3)
    
    centroid1 = clust_mean1
    centroid2 = clust_mean2
    centroid3 = clust_mean3
    #print(centroid1)
    #determining the distance of each data point from the chosen
    #random data points
    dist1 = []
    dist2 = []
    dist3 = []
    for i in range(len(data)):
        dist1.append(abs(centroid1 - data[i]))
        dist2.append(abs(centroid2 - data[i]))
        dist3.append(abs(centroid3 - data[i]))  


    #print(dist1)
    #print(dist2)
    #print(dist3)
    
    #appending all the smallest distances to the corresponding
    #random data point
    cluster_values1 = []
    cluster_values2 = []
    cluster_values3 = []

    for i in range(len(dist1)):
        if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
            cluster_values1.append(data[i])

    for i in range(len(dist1)):
        if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
            cluster_values2.append(data[i])

    for i in range(len(dist1)):
        if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
            cluster_values3.append(data[i])


    #print(cluster_values1)
    #print(cluster_values2)
    #print(cluster_values3)
    
    #taking the means of each cluster
    clust_mean1 = np.mean(cluster_values1)
    clust_mean2 = np.mean(cluster_values2)
    clust_mean3 = np.mean(cluster_values3)

    print(clust_mean1)
    #summing the variances, the smaller the variance the more clustered the data
    centroid1 = clust_mean1
    centroid2 = clust_mean2
    centroid3 = clust_mean3
    #print(centroid1)
    #determining the distance of each data point from the chosen
    #random data points
    dist1 = []
    dist2 = []
    dist3 = []
    for i in range(len(data)):
        dist1.append(abs(centroid1 - data[i]))
        dist2.append(abs(centroid2 - data[i]))
        dist3.append(abs(centroid3 - data[i]))  


    #print(dist1)
    #print(dist2)
    #print(dist3)
    
    #appending all the smallest distances to the corresponding
    #random data point
    cluster_values1 = []
    cluster_values2 = []
    cluster_values3 = []

    for i in range(len(dist1)):
        if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
            cluster_values1.append(data[i])

    for i in range(len(dist1)):
        if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
            cluster_values2.append(data[i])

    for i in range(len(dist1)):
        if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
            cluster_values3.append(data[i])


    #print(cluster_values1)
    #print(cluster_values2)
    #print(cluster_values3)
    
    #taking the means of each cluster
    clust_mean1 = np.mean(cluster_values1)
    clust_mean2 = np.mean(cluster_values2)
    clust_mean3 = np.mean(cluster_values3)

    print(clust_mean1)
    #print(total_var)
    centroid1 = clust_mean1
    centroid2 = clust_mean2
    centroid3 = clust_mean3
    print(centroid1)
    #determining the distance of each data point from the chosen
    #random data points
    dist1 = []
    dist2 = []
    dist3 = []
    for i in range(len(data)):
        dist1.append(abs(centroid1 - data[i]))
        dist2.append(abs(centroid2 - data[i]))
        dist3.append(abs(centroid3 - data[i]))  


    #print(dist1)
    #print(dist2)
    #print(dist3)
    
    #appending all the smallest distances to the corresponding
    #random data point
    cluster_values1 = []
    cluster_values2 = []
    cluster_values3 = []

    for i in range(len(dist1)):
        if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
            cluster_values1.append(data[i])

    for i in range(len(dist1)):
        if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
            cluster_values2.append(data[i])

    for i in range(len(dist1)):
        if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
            cluster_values3.append(data[i])


    #print(cluster_values1)
    #print(cluster_values2)
    #print(cluster_values3)
    
    #taking the means of each cluster
    clust_mean1 = np.mean(cluster_values1)
    clust_mean2 = np.mean(cluster_values2)
    clust_mean3 = np.mean(cluster_values3)

    print(clust_mean1)
    
    centroid1 = clust_mean1
    centroid2 = clust_mean2
    centroid3 = clust_mean3
    print(centroid1)
    #determining the distance of each data point from the chosen
    #random data points
    dist1 = []
    dist2 = []
    dist3 = []
    for i in range(len(data)):
        dist1.append(abs(centroid1 - data[i]))
        dist2.append(abs(centroid2 - data[i]))
        dist3.append(abs(centroid3 - data[i]))  


    #print(dist1)
    #print(dist2)
    #print(dist3)
    
    #appending all the smallest distances to the corresponding
    #random data point
    cluster_values1 = []
    cluster_values2 = []
    cluster_values3 = []

    for i in range(len(dist1)):
        if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
            cluster_values1.append(data[i])

    for i in range(len(dist1)):
        if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
            cluster_values2.append(data[i])

    for i in range(len(dist1)):
        if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
            cluster_values3.append(data[i])


    #print(cluster_values1)
    #print(cluster_values2)
    #print(cluster_values3)
    
    #taking the means of each cluster
    clust_mean1 = np.mean(cluster_values1)
    clust_mean2 = np.mean(cluster_values2)
    clust_mean3 = np.mean(cluster_values3)

    print(clust_mean1)
    
    centroid1 = clust_mean1
    centroid2 = clust_mean2
    centroid3 = clust_mean3
    #print(centroid1)
    #determining the distance of each data point from the chosen
    #random data points
    dist1 = []
    dist2 = []
    dist3 = []
    for i in range(len(data)):
        dist1.append(abs(centroid1 - data[i]))
        dist2.append(abs(centroid2 - data[i]))
        dist3.append(abs(centroid3 - data[i]))  


    #print(dist1)
    #print(dist2)
    #print(dist3)
    
    #appending all the smallest distances to the corresponding
    #random data point
    cluster_values1 = []
    cluster_values2 = []
    cluster_values3 = []

    for i in range(len(dist1)):
        if dist1[i] < dist2[i] and dist1[i] < dist3[i]:
            cluster_values1.append(data[i])

    for i in range(len(dist1)):
        if dist2[i] < dist1[i] and dist2[i] < dist3[i]:
            cluster_values2.append(data[i])

    for i in range(len(dist1)):
        if dist3[i] < dist1[i] and dist3[i] < dist2[i]:
            cluster_values3.append(data[i])


    #print(cluster_values1)
    #print(cluster_values2)
    #print(cluster_values3)
    
    #taking the means of each cluster
    clust_mean1 = np.mean(cluster_values1)
    clust_mean2 = np.mean(cluster_values2)
    clust_mean3 = np.mean(cluster_values3)

    print(clust_mean1)
    
    #returning the total variance along with the corresponding random points initially chosen
    #ie the chosen centres of the cluster
    return None

# %%
print(k_means(data))
# Out:
# 6.823529411764706
# 5.571428571428571
# 5.571428571428571
# 6.375
# 6.375
# 6.375
# 6.375
# 6.823529411764706
# 6.823529411764706
# None

# %%
#cluster_total = {}
#for i in range(1,11):
    #cluster_total[i] = k_means(data)

#print(cluster_total)
