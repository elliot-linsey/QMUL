# %% [markdown]
# # ECS7024 Statistics for Artificial Intelligence and Data Science
#
#
# ## Notebook 1: Aims and Outline
# The overall aim of this notebook is to introduce the Pandas library and the dataframe. Pandas is a complex library (as are the others we will use): our aim is to master Pandas sufficiently to be able to use for practical statistical analysis on this module. You will be able to explore other features of Pandas later.
#
# The notebook is quite long and it is **not** necessary to complete everything that is included. The first 4 sections introduce features of Pandas: it is recommended that you complete these sections though not necessarily all the exercises. Section 5 combines these into a simple analysis, with a plan and most code provided: you can return to this later. Section 6 is a second analysis but much less is given: you will face similar challenges later in the module.
#
#  1. Section 1: Introducing dataframes
#       1. Importing Pandas
#       1. Loading data from a CSV file
#       1. Row and Columns
#       1. Unique values
#
#  2. Section 2: Selecting Data (Filtering)
#       1. Filtering using one condition
#       1. Filtering with multiple conditions
#       1. Understanding Other Forms of Selection
#
#  3. Section 3: Modifying Data
#       1. Setting a Value
#       1. Vectorised Expressions
#       2. Applying a Function to Cells or Rows
#       2. Adding a new Column
#
#  4. Section 4: Creating and Visualing Pivot Tables
#       1. Creating a Pivot Table
#       1. Plotting a Pivot Table
#
#  5. Section 5: Example Analysis
#       1. Selecting London Boroughs
#       1. Calculating Total Populations
#       1. Converting to Proportions (*uses dataframe apply and assign*)
#       1. Graphing the Proportions (*uses plot*)
#
#  6. Section 6: Analysis Challenge Exercises

# %% [markdown]
# ## Section 1: Introducing the Dataframe
#
# In Pandas, data is held in a Dataframe, which is like a spreadsheet or database table
#  * Each columns has a name. Each column is a 'feature' (alternatively a 'variable' or 'attribute')
#  * Each row contains data from one 'instance' (alternatively an 'observation' or 'record').
#
# In this section you will learn how to:
#
#  1. Import the Pandas library
#  1. Read a CSV file and create a dataframe
#  1. The columns and rows of a dataframe
#  1. Have a look at unique values in the columns of the dataframe
#
#
# ### Section 1.1 Import the pandas library
# Since pandas is a very large library, it is probably not a good idea to import the library without a prefix. We use Python's 'import as' so that we can have a short name as a prefix. It is common to use the `pd` prefix.
#
# You can [read more about Pandas](https://pandas.pydata.org/about/index.html). The documentation on Pandas is in two main forms:
#
# 1. [The user guide](https://pandas.pydata.org/docs/user_guide/index.html) covers topics, and is a good way to go into more depth on some topics introduced here. If you read it all, it is a the length of a textbook.
# 2. The [API reference](https://pandas.pydata.org/docs/reference/index.html) has a section on each function. The description tends to be very detailed, but may include examples. You can look up a particular function.

# %%
import pandas as pd

# %% [markdown]
# ### Section 1.2 Creating a Dataframe by Reading a CSV file
# The CSV file can be loaded from the PC you are using. Check you have downloaded it: the code assumes it is in the same directory as the notebook. The results is a **data frame**.
#
# The data is about the country of birth by London Borough, age group and sex. It is from the 2011 census, so not up to date. (See further notes on the course page).
#
# The variable `df` below holds the dataframe. Writing `df` on a line on its own causes a summary of the dataframe to be printed. Fortunatley, the system knows not to print too many lines.

# %%
df = pd.read_csv('LondonCOB.csv')
df
# Out:
#                            Area             Age      Sex  Usual Residents  \
# 0          Barking and Dagenham      Age 0 to 4  Females               10
# 1          Barking and Dagenham      Age 5 to 9  Females               17
# 2          Barking and Dagenham    Age 10 to 15  Females               45
# 3          Barking and Dagenham    Age 16 to 19  Females               30
# 4          Barking and Dagenham    Age 20 to 24  Females               67
# ...                         ...             ...      ...              ...
# 67247  Yorkshire and The Humber    Age 60 to 64    Males              135
# 67248  Yorkshire and The Humber    Age 65 to 69    Males               94
# 67249  Yorkshire and The Humber    Age 70 to 74    Males               56
# 67250  Yorkshire and The Humber    Age 75 to 79    Males               38
# 67251  Yorkshire and The Humber  Age 80 or over    Males               57
#
#         BirthCountry                     BirthRegion
# 0              Ghana                          Africa
# 1              Ghana                          Africa
# 2              Ghana                          Africa
# 3              Ghana                          Africa
# 4              Ghana                          Africa
# ...              ...                             ...
# 67247  United States  The Americas and the Caribbean
# 67248  United States  The Americas and the Caribbean
# 67249  United States  The Americas and the Caribbean
# 67250  United States  The Americas and the Caribbean
# 67251  United States  The Americas and the Caribbean
#
# [67252 rows x 6 columns]

# %% [markdown]
# This data is an example of ['narrow' or 'tall' data](https://en.wikipedia.org/wiki/Wide_and_narrow_data), with lots of rows but fewer columns. Each row holds data about one detailed catagory. However, it is not at all easy to look at data in this format.

# %% [markdown]
# ### Section 1.3 Rows and Columns
#
# A Dataframe has rows and coulmns.
#
# The **columns of the dataframe**.
#  * Each columns has a name.
#  * Each column can be called a 'variable' (preferred by statisticians) an 'attribute' (used by a programmer) or a 'feature' (used in ML).
#
# The **rows of a dataframe** are similar to an entry is a database. They can be called 'observations', instances' or 'records'.
#
# A single column can be accessed using a dot. Try this:

# %%
# Uncomment and run the following code
df.Area
# Out:
# 0            Barking and Dagenham
# 1            Barking and Dagenham
# 2            Barking and Dagenham
# 3            Barking and Dagenham
# 4            Barking and Dagenham
#                    ...
# 67247    Yorkshire and The Humber
# 67248    Yorkshire and The Humber
# 67249    Yorkshire and The Humber
# 67250    Yorkshire and The Humber
# 67251    Yorkshire and The Humber
# Name: Area, Length: 67252, dtype: object

# %% [markdown]
# Explore what type a column is by using the following code:

# %%
# Uncomments the followng code to find the type of dataframe column
type(df.Age)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Many of the functions in Pandas work on different types (this is called 'overloading' by programmers; others just call it useful). Sometimes it is helpful to look at the type of a variable to understand how a function will behave.
#
# ### Section 1.4 Unique Values of a Variable
# To start exploring the data we have loaded, we can find out how many different values there are in each column. For example, the code below shows the different age values.

# %%
# age values
df.Age.unique()
# Out:
# array(['Age 0 to 4', 'Age 5 to 9', 'Age 10 to 15', 'Age 16 to 19',
#        'Age 20 to 24', 'Age 25 to 29', 'Age 30 to 34', 'Age 35 to 39',
#        'Age 40 to 44', 'Age 45 to 49', 'Age 50 to 54', 'Age 55 to 59',
#        'Age 60 to 64', 'Age 65 to 69', 'Age 70 to 74', 'Age 75 to 79',
#        'Age 80 or over'], dtype=object)

# %% [markdown]
# **What no loops?** You might expect that we would need to loop through the code to accumulate the unique values. However, this is not the case. In fact, we will not be using the `while` keyword anywhere in this notebook. There are loops of course, but they are inside the functions we call.
#
# #### Exercise 1.1: Add Code to Show Uniques Values of the Other Features

# %%
df.Area.unique()
df.BirthCountry.unique()
df['Usual Residents'].unique()
# Out:
# array([  10,   17,   45, ...,  879, 1858,  876], dtype=int64)

# %% [markdown]
# #### Exercise 1.2: Find the answers to the following questions about the data
#
# 1. Are all countries included?
# 2. How do people from other countries appear in the data?
# 3. Are all the 'Area' value London Boroughs? (See [list on wikipedia](https://en.wikipedia.org/wiki/List_of_London_boroughs) if necessary)
# 4. Why do you suppose areas outside London are included?
# 5. It is sensible to show the unique values of 'Usual Residents' (and does it work anyway)?

# %% [markdown]
# ## Section 2: Selecting Data
#
# In this section, we learn about selecting data from the dataframe. In excel, this is described a 'filter'. The concept is the same, but this word is not used in Pandas for this function (the Pandas filter functions does something else).
#
# There are several ways to select data from a dataframe - as a result this is a complex area of Pandas. We will use the `.loc` method of the dataframe. We start by introducing the most **useful** form of this method. The final section explains some other forms of the `.loc` method call.

# %% [markdown]
# ### Section 2.1 Filtering Using One Condition
#
# The data for one Area can be selected as shown below. Here we use a condition that is true for the borough we want.

# %%
th = df.loc[(df.Area == 'Tower Hamlets')]

th
# Out:
#                 Area             Age      Sex  Usual Residents   BirthCountry  \
# 57868  Tower Hamlets      Age 0 to 4  Females                3          Ghana
# 57869  Tower Hamlets      Age 5 to 9  Females                2          Ghana
# 57870  Tower Hamlets    Age 10 to 15  Females                4          Ghana
# 57871  Tower Hamlets    Age 16 to 19  Females                5          Ghana
# 57872  Tower Hamlets    Age 20 to 24  Females               15          Ghana
# ...              ...             ...      ...              ...            ...
# 59427  Tower Hamlets    Age 60 to 64    Males               30  United States
# 59428  Tower Hamlets    Age 65 to 69    Males               10  United States
# 59429  Tower Hamlets    Age 70 to 74    Males                8  United States
# 59430  Tower Hamlets    Age 75 to 79    Males                2  United States
# 59431  Tower Hamlets  Age 80 or over    Males                2  United States
#
#                           BirthRegion
# 57868                          Africa
# 57869                          Africa
# 57870                          Africa
# 57871                          Africa
# 57872                          Africa
# ...                               ...
# 59427  The Americas and the Caribbean
# 59428  The Americas and the Caribbean
# 59429  The Americas and the Caribbean
# 59430  The Americas and the Caribbean
# 59431  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %% [markdown]
# #### Exercise 2.1 Selecting (or Filtering) Instances
# Write code to select other subsets of the data:
#
# * Choose an area of interest to you (or 'Sutton' where I live) and select the data for this area.
# * Select data for one BirthRegion or one BirthCountry

# %%
hs = df.loc[(df.Area == 'Hounslow')]
hs
ghana = df.loc[df.BirthCountry == 'Ghana']
ghana
region = df[df.BirthRegion == 'Africa']
region
# Out:
#                            Area             Age      Sex  Usual Residents  \
# 0          Barking and Dagenham      Age 0 to 4  Females               10
# 1          Barking and Dagenham      Age 5 to 9  Females               17
# 2          Barking and Dagenham    Age 10 to 15  Females               45
# 3          Barking and Dagenham    Age 16 to 19  Females               30
# 4          Barking and Dagenham    Age 20 to 24  Females               67
# ...                         ...             ...      ...              ...
# 66975  Yorkshire and The Humber    Age 60 to 64    Males              376
# 66976  Yorkshire and The Humber    Age 65 to 69    Males              219
# 66977  Yorkshire and The Humber    Age 70 to 74    Males              119
# 66978  Yorkshire and The Humber    Age 75 to 79    Males               52
# 66979  Yorkshire and The Humber  Age 80 or over    Males               67
#
#        BirthCountry BirthRegion
# 0             Ghana      Africa
# 1             Ghana      Africa
# 2             Ghana      Africa
# 3             Ghana      Africa
# 4             Ghana      Africa
# ...             ...         ...
# 66975  Other Africa      Africa
# 66976  Other Africa      Africa
# 66977  Other Africa      Africa
# 66978  Other Africa      Africa
# 66979  Other Africa      Africa
#
# [11696 rows x 6 columns]

# %% [markdown]
# ### Section 2.2 Filtering using Multiple Conditions
# It is possible to use two or more conditions, combined into a logical expression as shown below. Note that the `&` operator is used. Other logical operators (such as `||`) can also be used.

# %%
th_men = df.loc[(df.Area == 'Tower Hamlets') & (df.Sex == 'Males')]
th_men
# Out:
#                 Area             Age    Sex  Usual Residents   BirthCountry  \
# 57885  Tower Hamlets      Age 0 to 4  Males                0          Ghana
# 57886  Tower Hamlets      Age 5 to 9  Males                0          Ghana
# 57887  Tower Hamlets    Age 10 to 15  Males                6          Ghana
# 57888  Tower Hamlets    Age 16 to 19  Males                4          Ghana
# 57889  Tower Hamlets    Age 20 to 24  Males               22          Ghana
# ...              ...             ...    ...              ...            ...
# 59427  Tower Hamlets    Age 60 to 64  Males               30  United States
# 59428  Tower Hamlets    Age 65 to 69  Males               10  United States
# 59429  Tower Hamlets    Age 70 to 74  Males                8  United States
# 59430  Tower Hamlets    Age 75 to 79  Males                2  United States
# 59431  Tower Hamlets  Age 80 or over  Males                2  United States
#
#                           BirthRegion
# 57885                          Africa
# 57886                          Africa
# 57887                          Africa
# 57888                          Africa
# 57889                          Africa
# ...                               ...
# 59427  The Americas and the Caribbean
# 59428  The Americas and the Caribbean
# 59429  The Americas and the Caribbean
# 59430  The Americas and the Caribbean
# 59431  The Americas and the Caribbean
#
# [782 rows x 6 columns]

# %% [markdown]
# #### Exercise 2.2 Selecting Instances using Multiple Variables
#
# Write code for the following selections
#
#   - Select records from two or more BirthCountries. One method is to use the `|` operator to combine two conditions with 'either or'
#   - Select records from several areas. For example, use [the list on wikipedia](https://en.wikipedia.org/wiki/List_of_London_boroughs) to select boroughs controlled by the Liberal Democrat party (there are only three). Be craeful to check the naming used in the data file.

# %%
countries = df[(df.BirthCountry == 'Ghana') | (df.BirthCountry == 'United States')]
countries
libdems = df[(df.Area == 'Kingston upon Thames') | (df.Area == 'Sutton') | (df.Area == 'Richmond upon Thames')]
libdems
# Out:
#                        Area             Age      Sex  Usual Residents  \
# 35972  Kingston upon Thames      Age 0 to 4  Females                0
# 35973  Kingston upon Thames      Age 5 to 9  Females                2
# 35974  Kingston upon Thames    Age 10 to 15  Females                5
# 35975  Kingston upon Thames    Age 16 to 19  Females                4
# 35976  Kingston upon Thames    Age 20 to 24  Females               20
# ...                     ...             ...      ...              ...
# 57863                Sutton    Age 60 to 64    Males                3
# 57864                Sutton    Age 65 to 69    Males                2
# 57865                Sutton    Age 70 to 74    Males                1
# 57866                Sutton    Age 75 to 79    Males                1
# 57867                Sutton  Age 80 or over    Males                3
#
#         BirthCountry                     BirthRegion
# 35972          Ghana                          Africa
# 35973          Ghana                          Africa
# 35974          Ghana                          Africa
# 35975          Ghana                          Africa
# 35976          Ghana                          Africa
# ...              ...                             ...
# 57863  United States  The Americas and the Caribbean
# 57864  United States  The Americas and the Caribbean
# 57865  United States  The Americas and the Caribbean
# 57866  United States  The Americas and the Caribbean
# 57867  United States  The Americas and the Caribbean
#
# [4692 rows x 6 columns]

# %% [markdown]
# ### Section 2.3 Understanding Other forms of Selection (*This Section is Not Essential*)
#
# This section explains in more detail how the techniques we have used for selection above work and what other forms of selection using `.loc` are available. The general form of the `.loc` call is:
#
#      .loc[row selector, column selector]
#
# The column selector is ignored if it is omitted. The 'selectors' can be either:
#   - a value or list of values
#   - an series of true or false values, represented by an expression that is true or false.
#
# Above, we have used the second form: when we write an expression such as `df.Area == 'Tower Hamlets'`, it evaluates to a series of values, one for each row, that are either true (in rows where Area is TH) or false (in all other rows). The true rows are selected.
#
# #### Exercise 2.3 Uncomment the code in the cell below to see the type of the expression.

# %%
df.Area == 'Tower Hamlets'        # Uncomment this line to look at the value of the row selector
type(df.Area == 'Tower Hamlets')  # Uncomment this line to look at the TYPE of the row selector
# Out:
# pandas.core.series.Series

# %% [markdown]
# Where we connect several such expressions using the `&` operator (or other logical operators) it is not the standard Python operator but is overloaded for the types being used here: the arguments are of type 'Series' and the effect is to intersect the two series.

# %% [markdown]
# #### Exercise 2.4 Selection Using Values
# Here are some examples of the other form of selection. Uncomment and run these.

# %%
# Use the index value to select a row
df.loc[57885]

# Use a range of index values to select a number of rows
df.loc[0:50]

# Use the index value and a column label to select a single cell
df.loc[57885, 'BirthCountry']

# Use the index value and a list of column labels to select several cells
df.loc[57885, ['BirthCountry', 'Age']]

# Using a list of column labels together with a true or false (boolean) expression
df.loc[df['Area']=='Tower Hamlets', ['BirthCountry', 'Age']]
# Out:
#         BirthCountry             Age
# 57868          Ghana      Age 0 to 4
# 57869          Ghana      Age 5 to 9
# 57870          Ghana    Age 10 to 15
# 57871          Ghana    Age 16 to 19
# 57872          Ghana    Age 20 to 24
# ...              ...             ...
# 59427  United States    Age 60 to 64
# 59428  United States    Age 65 to 69
# 59429  United States    Age 70 to 74
# 59430  United States    Age 75 to 79
# 59431  United States  Age 80 or over
#
# [1564 rows x 2 columns]

# %% [markdown]
# To understand more about selection, you can look at the [user guide section](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html). However, it is complex! Some of the code you see will not use the `.loc` method, but you are recommended to use this.

# %% [markdown]
# **Dataframe Index**
#
# The numbers such as 57885 used in the example above are index values. A dataframe has an index: in this case the index is automatically generated (and can be ignored). In other cases the index is more useful.

# %% [markdown]
# ## Section 3: Modifying the Dataframe
#
# We first explain how (and when) to create a copy of a dataframe.
# We then consider the following types of changes to a dataframe.
#
#   - Setting a Value
#   - Renaming a Column
#   - Evaluating an Expression for all Rows
#   - Applying a Function to Cells or Rows
#   - Adding a New Column
#
# Adding new columns is often needed as part of an analysis to present the data in a new way.

# %% [markdown]
# ### Section 3.1 Copy or View
#
# The dataframes `th` and `th_men` were created above from the `df` dataframe, which was loaded from a data file. How many copies of the data do we have? The answer to this question does not matter provided we only **look at** data.
#
# In fact, so far we have only **a single** copy of the data. The two new dataframe have been created as views, without copying the data. Note that it is not easy to check this behaviour, but this is the behaviour described.
#
# Uncomment the code below to create a copy of the data. We will use this when we modify data.
#   * Copying data takes space; we should not copy data unless we need to
#   * If you change data, the changes will affect all views. Usually copy data before modifying it
#   * It is not always easy to be sure whether data has been copied

# %%
croydon = df.loc[(df.Area == 'Croydon')].copy()
croydon
# Out:
#           Area             Age      Sex  Usual Residents   BirthCountry  \
# 10948  Croydon      Age 0 to 4  Females                5          Ghana
# 10949  Croydon      Age 5 to 9  Females               22          Ghana
# 10950  Croydon    Age 10 to 15  Females               75          Ghana
# 10951  Croydon    Age 16 to 19  Females               64          Ghana
# 10952  Croydon    Age 20 to 24  Females              145          Ghana
# ...        ...             ...      ...              ...            ...
# 12507  Croydon    Age 60 to 64    Males               15  United States
# 12508  Croydon    Age 65 to 69    Males                6  United States
# 12509  Croydon    Age 70 to 74    Males                4  United States
# 12510  Croydon    Age 75 to 79    Males                7  United States
# 12511  Croydon  Age 80 or over    Males                4  United States
#
#                           BirthRegion
# 10948                          Africa
# 10949                          Africa
# 10950                          Africa
# 10951                          Africa
# 10952                          Africa
# ...                               ...
# 12507  The Americas and the Caribbean
# 12508  The Americas and the Caribbean
# 12509  The Americas and the Caribbean
# 12510  The Americas and the Caribbean
# 12511  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %% [markdown]
# #### Exercise 3.1 Comparing Copied and Original Data
# Has the data been copied? If you uncomment and run the code below, you see the exact same values but taken from the original `df`. In Section 3.3 below we will make a change to the new copy of the data and see that the original data is unchanged.

# %%
df.loc[df.Area == 'Croydon']
# Out:
#           Area             Age      Sex  Usual Residents   BirthCountry  \
# 10948  Croydon      Age 0 to 4  Females                5          Ghana
# 10949  Croydon      Age 5 to 9  Females               22          Ghana
# 10950  Croydon    Age 10 to 15  Females               75          Ghana
# 10951  Croydon    Age 16 to 19  Females               64          Ghana
# 10952  Croydon    Age 20 to 24  Females              145          Ghana
# ...        ...             ...      ...              ...            ...
# 12507  Croydon    Age 60 to 64    Males               15  United States
# 12508  Croydon    Age 65 to 69    Males                6  United States
# 12509  Croydon    Age 70 to 74    Males                4  United States
# 12510  Croydon    Age 75 to 79    Males                7  United States
# 12511  Croydon  Age 80 or over    Males                4  United States
#
#                           BirthRegion
# 10948                          Africa
# 10949                          Africa
# 10950                          Africa
# 10951                          Africa
# 10952                          Africa
# ...                               ...
# 12507  The Americas and the Caribbean
# 12508  The Americas and the Caribbean
# 12509  The Americas and the Caribbean
# 12510  The Americas and the Caribbean
# 12511  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %% [markdown]
# ### Section 3.2 Renaming a Column
#
# We discovered above that we can select a column (or variable) from the dataframe using the form `df.Area`. However, there is a limitation that when we write `df.X` then the `X` must be a valid Python identifier. One of our columns is headed `Usual Residents`; because of the space this is not a valid identifier in Python.
#
# The code below shows how to rename a column. The value of the parameter is a [Python dictionary](https://docs.python.org/3.7/tutorial/datastructures.html#dictionaries). Run this code to rename the column.

# %%
croydon = croydon.rename(columns={"Usual Residents": "Residents"})
croydon
# Out:
#           Area             Age      Sex  Residents   BirthCountry  \
# 10948  Croydon      Age 0 to 4  Females          5          Ghana
# 10949  Croydon      Age 5 to 9  Females         22          Ghana
# 10950  Croydon    Age 10 to 15  Females         75          Ghana
# 10951  Croydon    Age 16 to 19  Females         64          Ghana
# 10952  Croydon    Age 20 to 24  Females        145          Ghana
# ...        ...             ...      ...        ...            ...
# 12507  Croydon    Age 60 to 64    Males         15  United States
# 12508  Croydon    Age 65 to 69    Males          6  United States
# 12509  Croydon    Age 70 to 74    Males          4  United States
# 12510  Croydon    Age 75 to 79    Males          7  United States
# 12511  Croydon  Age 80 or over    Males          4  United States
#
#                           BirthRegion
# 10948                          Africa
# 10949                          Africa
# 10950                          Africa
# 10951                          Africa
# 10952                          Africa
# ...                               ...
# 12507  The Americas and the Caribbean
# 12508  The Americas and the Caribbean
# 12509  The Americas and the Caribbean
# 12510  The Americas and the Caribbean
# 12511  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %% [markdown]
# ### Section 3.3 Setting a Value
#
# The value of a cell in a dataframe can be updated by assigning a new value to it. Uncomment and run the code below: observe the change.

# %%
croydon.loc[10948,'Residents'] = 0
croydon
# Out:
#           Area             Age      Sex  Residents   BirthCountry  \
# 10948  Croydon      Age 0 to 4  Females          0          Ghana
# 10949  Croydon      Age 5 to 9  Females         22          Ghana
# 10950  Croydon    Age 10 to 15  Females         75          Ghana
# 10951  Croydon    Age 16 to 19  Females         64          Ghana
# 10952  Croydon    Age 20 to 24  Females        145          Ghana
# ...        ...             ...      ...        ...            ...
# 12507  Croydon    Age 60 to 64    Males         15  United States
# 12508  Croydon    Age 65 to 69    Males          6  United States
# 12509  Croydon    Age 70 to 74    Males          4  United States
# 12510  Croydon    Age 75 to 79    Males          7  United States
# 12511  Croydon  Age 80 or over    Males          4  United States
#
#                           BirthRegion
# 10948                          Africa
# 10949                          Africa
# 10950                          Africa
# 10951                          Africa
# 10952                          Africa
# ...                               ...
# 12507  The Americas and the Caribbean
# 12508  The Americas and the Caribbean
# 12509  The Americas and the Caribbean
# 12510  The Americas and the Caribbean
# 12511  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %% [markdown]
# #### Exercise 3.2 Changing Data Values
#
#   * Assign a new value to other enteries in the `croydon` dataframe.
#   * Again compare the `croydon` data frame with the same data selected from the `df` dataframe and confirm that the two are now different.

# %%
df.loc[df.Area == 'Croydon']
df.loc[10950, 'Usual Residents'] = 'This is an original change'
croydon.loc[10950, 'Residents'] = 'This is a copy change'
df.loc[df['Area'] == 'Croydon']
croydon.loc[df.Area == 'Croydon']
# Out:
#           Area             Age      Sex              Residents   BirthCountry  \
# 10948  Croydon      Age 0 to 4  Females                      0          Ghana
# 10949  Croydon      Age 5 to 9  Females                     22          Ghana
# 10950  Croydon    Age 10 to 15  Females  This is a copy change          Ghana
# 10951  Croydon    Age 16 to 19  Females                     64          Ghana
# 10952  Croydon    Age 20 to 24  Females                    145          Ghana
# ...        ...             ...      ...                    ...            ...
# 12507  Croydon    Age 60 to 64    Males                     15  United States
# 12508  Croydon    Age 65 to 69    Males                      6  United States
# 12509  Croydon    Age 70 to 74    Males                      4  United States
# 12510  Croydon    Age 75 to 79    Males                      7  United States
# 12511  Croydon  Age 80 or over    Males                      4  United States
#
#                           BirthRegion
# 10948                          Africa
# 10949                          Africa
# 10950                          Africa
# 10951                          Africa
# 10952                          Africa
# ...                               ...
# 12507  The Americas and the Caribbean
# 12508  The Americas and the Caribbean
# 12509  The Americas and the Caribbean
# 12510  The Americas and the Caribbean
# 12511  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %% [markdown]
# ### Section 3.4 Evaluating an Expression for all Rows
# It is possible to modify all (or any) of the values in a column without using a loop. In the following example, the expression `croydon.Residents * 2` is re-evaluated in every row and used to update the column. Expressions like this are described as 'vectorised' or 'elementwise'.
#
# Run the example and observe the result.

# %%
croydon.Residents = croydon.Residents * 2
croydon
# Out:
#           Area             Age      Sex  \
# 10948  Croydon      Age 0 to 4  Females
# 10949  Croydon      Age 5 to 9  Females
# 10950  Croydon    Age 10 to 15  Females
# 10951  Croydon    Age 16 to 19  Females
# 10952  Croydon    Age 20 to 24  Females
# ...        ...             ...      ...
# 12507  Croydon    Age 60 to 64    Males
# 12508  Croydon    Age 65 to 69    Males
# 12509  Croydon    Age 70 to 74    Males
# 12510  Croydon    Age 75 to 79    Males
# 12511  Croydon  Age 80 or over    Males
#
#                                         Residents   BirthCountry  \
# 10948                                           0          Ghana
# 10949                                          44          Ghana
# 10950  This is a copy changeThis is a copy change          Ghana
# 10951                                         128          Ghana
# 10952                                         290          Ghana
# ...                                           ...            ...
# 12507                                          30  United States
# 12508                                          12  United States
# 12509                                           8  United States
# 12510                                          14  United States
# 12511                                           8  United States
#
#                           BirthRegion
# 10948                          Africa
# 10949                          Africa
# 10950                          Africa
# 10951                          Africa
# 10952                          Africa
# ...                               ...
# 12507  The Americas and the Caribbean
# 12508  The Americas and the Caribbean
# 12509  The Americas and the Caribbean
# 12510  The Americas and the Caribbean
# 12511  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %% [markdown]
# The following types of expression can be applied in this way:
#    * Binary arthimetic operators `+ - * / // %` applied **element by element**
#    * Methods `.add`, `.sub`, `.mul`, `.div`, `.mod`, `.pow`, similar but with more options
#    * Methods `.sum`, `.min` and `.max` applied to the complete column (or dataframe)
#
# If you need to make a change for only some row, you can use the condition as a selector.
#
# #### Exercise 3.3 Evaluating an Expressions for all Rows
# Try the following examples to understand some of the options available.

# %%
# Applying an expression to only some rows using a (selector) condition
#croydon.loc[croydon.Age != 'Age 0 to 4', 'Residents'] * 2

# Updating row differently using a (selector) condition 
#croydon.loc[croydon.Age == 'Age 0 to 4', 'Residents'] = 5
#croydon.loc[croydon.Age != 'Age 0 to 4', 'Residents'] = croydon.Residents * 2

# Applying a function to a column to get a single value
print(croydon.loc[10948:10949, 'Residents'].sum() + croydon.loc[10951:12511, 'Residents'].sum())
croydon
# Out:
# 726596
#           Area             Age      Sex  \
# 10948  Croydon      Age 0 to 4  Females
# 10949  Croydon      Age 5 to 9  Females
# 10950  Croydon    Age 10 to 15  Females
# 10951  Croydon    Age 16 to 19  Females
# 10952  Croydon    Age 20 to 24  Females
# ...        ...             ...      ...
# 12507  Croydon    Age 60 to 64    Males
# 12508  Croydon    Age 65 to 69    Males
# 12509  Croydon    Age 70 to 74    Males
# 12510  Croydon    Age 75 to 79    Males
# 12511  Croydon  Age 80 or over    Males
#
#                                         Residents   BirthCountry  \
# 10948                                           0          Ghana
# 10949                                          44          Ghana
# 10950  This is a copy changeThis is a copy change          Ghana
# 10951                                         128          Ghana
# 10952                                         290          Ghana
# ...                                           ...            ...
# 12507                                          30  United States
# 12508                                          12  United States
# 12509                                           8  United States
# 12510                                          14  United States
# 12511                                           8  United States
#
#                           BirthRegion
# 10948                          Africa
# 10949                          Africa
# 10950                          Africa
# 10951                          Africa
# 10952                          Africa
# ...                               ...
# 12507  The Americas and the Caribbean
# 12508  The Americas and the Caribbean
# 12509  The Americas and the Caribbean
# 12510  The Americas and the Caribbean
# 12511  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %% [markdown]
# ### Section 3.4 Applying a Function to Cells or Rows
# Not all functions can be automatically vectorised. A more general approach is to use the `apply` function. It can be used to apply a function to each row.
#   *  To apply the function to each row use `axis=1`
#   *  Define the function; you can use the parameter name `row` to remind you how the function is applied
#   *  Applying the function gives a new series. We often use this to assign a new column (see next section)
#
# Uncomment and run the code to see the effect. If you are familiar with python `lambda`, you can often use it to define a function be applied (the function may only contain an expression). However, it is not necessary to use this and a separate function is easier to test.

# %%
def schoolCategory(row):
    if (row.Age == 'Age 0 to 4') : return 'PreSchool'
    if (row.Age == 'Age 5 to 9') : return 'PrimarySchool'
    if (row.Age in ['Age 10 to 15', 'Age 16 to 19']) : return 'SecondarySchool'
    return 'No School'
        
croydon['School_category'] = croydon.apply(schoolCategory, axis=1)
croydon
# Out:
#           Area             Age      Sex  \
# 10948  Croydon      Age 0 to 4  Females
# 10949  Croydon      Age 5 to 9  Females
# 10950  Croydon    Age 10 to 15  Females
# 10951  Croydon    Age 16 to 19  Females
# 10952  Croydon    Age 20 to 24  Females
# ...        ...             ...      ...
# 12507  Croydon    Age 60 to 64    Males
# 12508  Croydon    Age 65 to 69    Males
# 12509  Croydon    Age 70 to 74    Males
# 12510  Croydon    Age 75 to 79    Males
# 12511  Croydon  Age 80 or over    Males
#
#                                         Residents   BirthCountry  \
# 10948                                           0          Ghana
# 10949                                          44          Ghana
# 10950  This is a copy changeThis is a copy change          Ghana
# 10951                                         128          Ghana
# 10952                                         290          Ghana
# ...                                           ...            ...
# 12507                                          30  United States
# 12508                                          12  United States
# 12509                                           8  United States
# 12510                                          14  United States
# 12511                                           8  United States
#
#                           BirthRegion  School_category
# 10948                          Africa        PreSchool
# 10949                          Africa    PrimarySchool
# 10950                          Africa  SecondarySchool
# 10951                          Africa  SecondarySchool
# 10952                          Africa        No School
# ...                               ...              ...
# 12507  The Americas and the Caribbean        No School
# 12508  The Americas and the Caribbean        No School
# 12509  The Americas and the Caribbean        No School
# 12510  The Americas and the Caribbean        No School
# 12511  The Americas and the Caribbean        No School
#
# [1564 rows x 7 columns]

# %% [markdown]
# ### Section 3.5 Adding a New Column
# We have shown above how an existing column can be modified (using `.loc` on the left hand side of an assignment). It is often useful to add a new column: we do this using the `.assign` function. This returns a new dataframe (i.e. a copy).
#   * The argument to `apply` can be an assignments statement
#   * It is often used with `.apply`
#
# Uncomment and run the following examples. Note that a new dataframe is created: assign it to a variable if you want to use it further.

# %%
# Assign a column with a fixed value
croydon.assign(Constant = 42)

# Assign a column applying the fuunction defined above
croydon.assign(School = croydon.apply(schoolCategory, axis=1))
# Out:
#           Area             Age      Sex  \
# 10948  Croydon      Age 0 to 4  Females
# 10949  Croydon      Age 5 to 9  Females
# 10950  Croydon    Age 10 to 15  Females
# 10951  Croydon    Age 16 to 19  Females
# 10952  Croydon    Age 20 to 24  Females
# ...        ...             ...      ...
# 12507  Croydon    Age 60 to 64    Males
# 12508  Croydon    Age 65 to 69    Males
# 12509  Croydon    Age 70 to 74    Males
# 12510  Croydon    Age 75 to 79    Males
# 12511  Croydon  Age 80 or over    Males
#
#                                         Residents   BirthCountry  \
# 10948                                           0          Ghana
# 10949                                          44          Ghana
# 10950  This is a copy changeThis is a copy change          Ghana
# 10951                                         128          Ghana
# 10952                                         290          Ghana
# ...                                           ...            ...
# 12507                                          30  United States
# 12508                                          12  United States
# 12509                                           8  United States
# 12510                                          14  United States
# 12511                                           8  United States
#
#                           BirthRegion  School_category           School
# 10948                          Africa        PreSchool        PreSchool
# 10949                          Africa    PrimarySchool    PrimarySchool
# 10950                          Africa  SecondarySchool  SecondarySchool
# 10951                          Africa  SecondarySchool  SecondarySchool
# 10952                          Africa        No School        No School
# ...                               ...              ...              ...
# 12507  The Americas and the Caribbean        No School        No School
# 12508  The Americas and the Caribbean        No School        No School
# 12509  The Americas and the Caribbean        No School        No School
# 12510  The Americas and the Caribbean        No School        No School
# 12511  The Americas and the Caribbean        No School        No School
#
# [1564 rows x 8 columns]

# %%
croydon
# Out:
#           Area             Age      Sex  \
# 10948  Croydon      Age 0 to 4  Females
# 10949  Croydon      Age 5 to 9  Females
# 10950  Croydon    Age 10 to 15  Females
# 10951  Croydon    Age 16 to 19  Females
# 10952  Croydon    Age 20 to 24  Females
# ...        ...             ...      ...
# 12507  Croydon    Age 60 to 64    Males
# 12508  Croydon    Age 65 to 69    Males
# 12509  Croydon    Age 70 to 74    Males
# 12510  Croydon    Age 75 to 79    Males
# 12511  Croydon  Age 80 or over    Males
#
#                                         Residents   BirthCountry  \
# 10948                                           0          Ghana
# 10949                                          44          Ghana
# 10950  This is a copy changeThis is a copy change          Ghana
# 10951                                         128          Ghana
# 10952                                         290          Ghana
# ...                                           ...            ...
# 12507                                          30  United States
# 12508                                          12  United States
# 12509                                           8  United States
# 12510                                          14  United States
# 12511                                           8  United States
#
#                           BirthRegion  School_category
# 10948                          Africa        PreSchool
# 10949                          Africa    PrimarySchool
# 10950                          Africa  SecondarySchool
# 10951                          Africa  SecondarySchool
# 10952                          Africa        No School
# ...                               ...              ...
# 12507  The Americas and the Caribbean        No School
# 12508  The Americas and the Caribbean        No School
# 12509  The Americas and the Caribbean        No School
# 12510  The Americas and the Caribbean        No School
# 12511  The Americas and the Caribbean        No School
#
# [1564 rows x 7 columns]

# %% [markdown]
# ## Section 4 Creating and Visualising a Pivot Table
#
# ### Section 4.1 Creating a Pivot Table
#
# The Pivot table gives a summary of the data in a number of rows and columns. There are four arguments, each of which can be a variable name or a list of names:
# * **values** The values you want shown in the table
# * **index** The variables used to give the rows.
# * **columns** The variables whose values are used as columns for each value
# * **aggfunc** The function used to combine values in each entry, such as `sum`, `max`, `min`, `mean`, `var`
#
# Together, the index and column variables show how the values are analysed. Moving variables between index and columns lists changes the shape but not the contents of the table. The aggregation function (or functions, a list is possible) must apply to the type of the values variable(s). The aggregation combines values for the cases of the variables not in either the index or columns lists.
#
# #### Exercise 4.1 Pivot Tables
# The following examples show some different pivot tables:
#    * **p1** gives a breakdown number of people by sex (columns) and birth Country (rows). The ages are aggregated.
#    * **p2** has more columns, breaking down the residents by sex and age. Can you explain why no aggregation function is needed?
#    * **p3** has more rows, one for each combination of BirthRegion and Sex. The aggregation is over the countries within each region.
#
# Uncomment and try each example.

# %%
th
# Out:
#                 Area             Age      Sex  Usual Residents   BirthCountry  \
# 57868  Tower Hamlets      Age 0 to 4  Females                3          Ghana
# 57869  Tower Hamlets      Age 5 to 9  Females                2          Ghana
# 57870  Tower Hamlets    Age 10 to 15  Females                4          Ghana
# 57871  Tower Hamlets    Age 16 to 19  Females                5          Ghana
# 57872  Tower Hamlets    Age 20 to 24  Females               15          Ghana
# ...              ...             ...      ...              ...            ...
# 59427  Tower Hamlets    Age 60 to 64    Males               30  United States
# 59428  Tower Hamlets    Age 65 to 69    Males               10  United States
# 59429  Tower Hamlets    Age 70 to 74    Males                8  United States
# 59430  Tower Hamlets    Age 75 to 79    Males                2  United States
# 59431  Tower Hamlets  Age 80 or over    Males                2  United States
#
#                           BirthRegion
# 57868                          Africa
# 57869                          Africa
# 57870                          Africa
# 57871                          Africa
# 57872                          Africa
# ...                               ...
# 59427  The Americas and the Caribbean
# 59428  The Americas and the Caribbean
# 59429  The Americas and the Caribbean
# 59430  The Americas and the Caribbean
# 59431  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %%
p1 = th.pivot_table(values=['Usual Residents'], index=['BirthCountry'], columns=['Sex'], aggfunc='sum')
p2 = th.pivot_table(values=['Usual Residents'], index=['BirthCountry'], columns=['Sex','Age'])
p3 = th.pivot_table(values=['Usual Residents'], index=['BirthRegion', 'Sex'], columns=['Age'], aggfunc='sum')
p3
# Out:
#                                        Usual Residents               \
# Age                                         Age 0 to 4 Age 10 to 15
# BirthRegion                    Sex
# Africa                         Females              26          151
#                                Males                33          198
# Antarctica and Oceania         Females              14            4
#                                Males                10            4
# Europe                         Females            8875         6937
#                                Males              9319         7278
# Middle East and Asia           Females             191          554
#                                Males               202          624
# Other                          Females               0            0
#                                Males                 0            0
# The Americas and the Caribbean Females              35           63
#                                Males                45           49
#
#                                                                                \
# Age                                    Age 16 to 19 Age 20 to 24 Age 25 to 29
# BirthRegion                    Sex
# Africa                         Females          207          528          908
#                                Males            193          515          767
# Antarctica and Oceania         Females           16          216          520
#                                Males              6          121          486
# Europe                         Females         4971        11550        12627
#                                Males           4823        10858        13667
# Middle East and Asia           Females          730         3084         5083
#                                Males            854         3105         4509
# Other                          Females            0            0            0
#                                Males              0            0            0
# The Americas and the Caribbean Females           88          503          887
#                                Males             75          338          703
#
#                                                                                \
# Age                                    Age 30 to 34 Age 35 to 39 Age 40 to 44
# BirthRegion                    Sex
# Africa                         Females          871          734          619
#                                Males            925          774          671
# Antarctica and Oceania         Females          591          278          112
#                                Males            662          386          175
# Europe                         Females         8232         4525         3489
#                                Males          10106         6147         4710
# Middle East and Asia           Females         5005         3552         2273
#                                Males           5149         4253         3020
# Other                          Females            0            0            0
#                                Males              0            0            0
# The Americas and the Caribbean Females          693          415          264
#                                Males            794          475          345
#
#                                                                              \
# Age                                    Age 45 to 49 Age 5 to 9 Age 50 to 54
# BirthRegion                    Sex
# Africa                         Females          395         75          331
#                                Males            523         61          327
# Antarctica and Oceania         Females           62          3           35
#                                Males             66         10           40
# Europe                         Females         3102       7332         2535
#                                Males           3844       7371         3083
# Middle East and Asia           Females         1486        320         1253
#                                Males           1874        299         1636
# Other                          Females            0          0            0
#                                Males              0          0            0
# The Americas and the Caribbean Females          194         25          245
#                                Males            232         35          251
#
#                                                                                \
# Age                                    Age 55 to 59 Age 60 to 64 Age 65 to 69
# BirthRegion                    Sex
# Africa                         Females          232          175          127
#                                Males            233          160           95
# Antarctica and Oceania         Females           33           20            8
#                                Males             29           16           10
# Europe                         Females         2103         1783         1323
#                                Males           2512         2205         1408
# Middle East and Asia           Females         1290          914          601
#                                Males            966          338          362
# Other                          Females            0            0            0
#                                Males              0            0            0
# The Americas and the Caribbean Females          224          139          129
#                                Males            201          113           77
#
#                                                                   \
# Age                                    Age 70 to 74 Age 75 to 79
# BirthRegion                    Sex
# Africa                         Females          108           72
#                                Males             95           58
# Antarctica and Oceania         Females            5            4
#                                Males              8            6
# Europe                         Females         1112         1129
#                                Males           1022          832
# Middle East and Asia           Females          733          385
#                                Males            705          526
# Other                          Females            0            0
#                                Males              0            0
# The Americas and the Caribbean Females          116           96
#                                Males            125           96
#
#
# Age                                    Age 80 or over
# BirthRegion                    Sex
# Africa                         Females             77
#                                Males               78
# Antarctica and Oceania         Females              7
#                                Males                3
# Europe                         Females           2060
#                                Males             1155
# Middle East and Asia           Females            264
#                                Males              366
# Other                          Females              0
#                                Males                0
# The Americas and the Caribbean Females            107
#                                Males               80

# %% [markdown]
# #### Exercise 4.2 Creating a New Pivot Table.
#
# Create a pivot table showing the breakdown of (the sum of) Usual Residents by Age and BirthRegion.
#  * Which variables do choose for the index and columns?
#  * Which variables are aggregated?

# %%
th = th.rename(columns={'Usual Residents': 'Residents'})
th
# Out:
#                 Area             Age      Sex  Residents   BirthCountry  \
# 57868  Tower Hamlets      Age 0 to 4  Females          3          Ghana
# 57869  Tower Hamlets      Age 5 to 9  Females          2          Ghana
# 57870  Tower Hamlets    Age 10 to 15  Females          4          Ghana
# 57871  Tower Hamlets    Age 16 to 19  Females          5          Ghana
# 57872  Tower Hamlets    Age 20 to 24  Females         15          Ghana
# ...              ...             ...      ...        ...            ...
# 59427  Tower Hamlets    Age 60 to 64    Males         30  United States
# 59428  Tower Hamlets    Age 65 to 69    Males         10  United States
# 59429  Tower Hamlets    Age 70 to 74    Males          8  United States
# 59430  Tower Hamlets    Age 75 to 79    Males          2  United States
# 59431  Tower Hamlets  Age 80 or over    Males          2  United States
#
#                           BirthRegion
# 57868                          Africa
# 57869                          Africa
# 57870                          Africa
# 57871                          Africa
# 57872                          Africa
# ...                               ...
# 59427  The Americas and the Caribbean
# 59428  The Americas and the Caribbean
# 59429  The Americas and the Caribbean
# 59430  The Americas and the Caribbean
# 59431  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %%
p4 = th.pivot_table(values='Residents', columns='BirthRegion', index='Age', aggfunc='sum')
p4
# Out:
# BirthRegion     Africa  Antarctica and Oceania  Europe  Middle East and Asia  \
# Age
# Age 0 to 4          59                      24   18194                   393
# Age 10 to 15       349                       8   14215                  1178
# Age 16 to 19       400                      22    9794                  1584
# Age 20 to 24      1043                     337   22408                  6189
# Age 25 to 29      1675                    1006   26294                  9592
# Age 30 to 34      1796                    1253   18338                 10154
# Age 35 to 39      1508                     664   10672                  7805
# Age 40 to 44      1290                     287    8199                  5293
# Age 45 to 49       918                     128    6946                  3360
# Age 5 to 9         136                      13   14703                   619
# Age 50 to 54       658                      75    5618                  2889
# Age 55 to 59       465                      62    4615                  2256
# Age 60 to 64       335                      36    3988                  1252
# Age 65 to 69       222                      18    2731                   963
# Age 70 to 74       203                      13    2134                  1438
# Age 75 to 79       130                      10    1961                   911
# Age 80 or over     155                      10    3215                   630
#
# BirthRegion     Other  The Americas and the Caribbean
# Age
# Age 0 to 4          0                              80
# Age 10 to 15        0                             112
# Age 16 to 19        0                             163
# Age 20 to 24        0                             841
# Age 25 to 29        0                            1590
# Age 30 to 34        0                            1487
# Age 35 to 39        0                             890
# Age 40 to 44        0                             609
# Age 45 to 49        0                             426
# Age 5 to 9          0                              60
# Age 50 to 54        0                             496
# Age 55 to 59        0                             425
# Age 60 to 64        0                             252
# Age 65 to 69        0                             206
# Age 70 to 74        0                             241
# Age 75 to 79        0                             192
# Age 80 or over      0                             187

# %%
p4.loc['Age 0 to 4', 'Africa']
# Out:
# 59

# %% [markdown]
# #### Exercise 4.3 Indexing Into a Pivot Table (*optional*)
#
# The following example show a method of indexing into a pivot table to look up a value. The principles are:
#   * The pivot table can be thought of a dataframe containing dataframes
#   * Use `.loc` to remove first the index variables, by giving the values you wish to select
#   * Look at the shape of the dataframe produced and use further calls to `.loc` to access it
#
# Uncomment and try the following examples.

# %%
#p1

# %%
p2
# Out:
#                                                    Usual Residents  \
# Sex                                                        Females
# Age                                                     Age 0 to 4
# BirthCountry
# Afghanistan                                                      1
# Australia                                                       12
# Bangladesh                                                      68
# Brazil                                                           5
# Bulgaria                                                         1
# Canada                                                           3
# China                                                           11
# Cyprus                                                           0
# France                                                          22
# Germany                                                          8
# Ghana                                                            3
# Hong Kong (Special Administrative Region of China)               2
# Hungary                                                          2
# India                                                           64
# Iran                                                             0
# Iraq                                                             0
# Ireland                                                          7
# Italy                                                           12
# Jamaica                                                          2
# Kenya                                                            1
# Lithuania                                                        0
# Malaysia                                                         3
# Netherlands                                                      9
# New Zealand                                                      2
# Nigeria                                                          3
# Other                                                            0
# Other Africa                                                    10
# Other Antarctica and Oceania                                     0
# Other Europe                                                    24
# Other Middle East and Asia                                      36
# Other The Americas and the Caribbean                             2
# Pakistan                                                         2
# Philippines                                                      4
# Poland                                                           6
# Portugal                                                         4
# Romania                                                          5
# Russia                                                           1
# Somalia                                                          7
# South Africa                                                     2
# Spain (including Canary Islands)                                10
# Sri Lanka                                                        0
# Turkey                                                           2
# Uganda                                                           0
# United Kingdom                                                8762
# United States                                                   23
# Zimbabwe                                                         0
#
#                                                                               \
# Sex
# Age                                                Age 10 to 15 Age 16 to 19
# BirthCountry
# Afghanistan                                                   8            6
# Australia                                                     4            8
# Bangladesh                                                  473          472
# Brazil                                                       14           14
# Bulgaria                                                      3           24
# Canada                                                        1           12
# China                                                         8           61
# Cyprus                                                        1           14
# France                                                       16           56
# Germany                                                      19           29
# Ghana                                                         4            5
# Hong Kong (Special Administrative Region of China)            4           30
# Hungary                                                       3            2
# India                                                        16           23
# Iran                                                          0            5
# Iraq                                                          1            3
# Ireland                                                       3           14
# Italy                                                        15           19
# Jamaica                                                       7            5
# Kenya                                                         3            2
# Lithuania                                                    20           46
# Malaysia                                                      4            7
# Netherlands                                                  20           17
# New Zealand                                                   0            8
# Nigeria                                                      10           53
# Other                                                         0            0
# Other Africa                                                 39           47
# Other Antarctica and Oceania                                  0            0
# Other Europe                                                 43          109
# Other Middle East and Asia                                   24          104
# Other The Americas and the Caribbean                         24           28
# Pakistan                                                      9            7
# Philippines                                                   6            5
# Poland                                                       31           26
# Portugal                                                     16           12
# Romania                                                       3           13
# Russia                                                        4           32
# Somalia                                                      86           84
# South Africa                                                  3           10
# Spain (including Canary Islands)                              4           12
# Sri Lanka                                                     1            7
# Turkey                                                        3            9
# Uganda                                                        2            0
# United Kingdom                                             6733         4537
# United States                                                17           29
# Zimbabwe                                                      4            6
#
#                                                                               \
# Sex
# Age                                                Age 20 to 24 Age 25 to 29
# BirthCountry
# Afghanistan                                                  10           11
# Australia                                                   180          382
# Bangladesh                                                 1510         2797
# Brazil                                                       73          178
# Bulgaria                                                     77           82
# Canada                                                       64          147
# China                                                       629          705
# Cyprus                                                       41           23
# France                                                      248          386
# Germany                                                     188          231
# Ghana                                                        15           42
# Hong Kong (Special Administrative Region of China)          123          135
# Hungary                                                      50          109
# India                                                       156          533
# Iran                                                         16           48
# Iraq                                                         21           19
# Ireland                                                     118          235
# Italy                                                       229          349
# Jamaica                                                      22           24
# Kenya                                                        15           38
# Lithuania                                                   111          159
# Malaysia                                                    112          104
# Netherlands                                                  42           47
# New Zealand                                                  36          135
# Nigeria                                                      66          103
# Other                                                         0            0
# Other Africa                                                179          305
# Other Antarctica and Oceania                                  0            3
# Other Europe                                                658          823
# Other Middle East and Asia                                  416          592
# Other The Americas and the Caribbean                        113          221
# Pakistan                                                     53           73
# Philippines                                                  20           42
# Poland                                                      165          509
# Portugal                                                     50           69
# Romania                                                      69           86
# Russia                                                      128          182
# Somalia                                                     164          207
# South Africa                                                 60          164
# Spain (including Canary Islands)                            138          323
# Sri Lanka                                                    18           24
# Turkey                                                       42           73
# Uganda                                                       15           21
# United Kingdom                                             9196         8941
# United States                                               231          317
# Zimbabwe                                                     14           28
#
#                                                                               \
# Sex
# Age                                                Age 30 to 34 Age 35 to 39
# BirthCountry
# Afghanistan                                                   7            8
# Australia                                                   379          187
# Bangladesh                                                 3362         2731
# Brazil                                                      157           99
# Bulgaria                                                     70           28
# Canada                                                      125           58
# China                                                       287           86
# Cyprus                                                       12            8
# France                                                      254          128
# Germany                                                     205          126
# Ghana                                                        36           40
# Hong Kong (Special Administrative Region of China)          104           33
# Hungary                                                      78           27
# India                                                       389          122
# Iran                                                         42           17
# Iraq                                                         23            7
# Ireland                                                     210           89
# Italy                                                       223          162
# Jamaica                                                      30           25
# Kenya                                                        30           16
# Lithuania                                                   119           48
# Malaysia                                                    112           72
# Netherlands                                                  46           14
# New Zealand                                                 207           86
# Nigeria                                                      85           47
# Other                                                         0            0
# Other Africa                                                282          264
# Other Antarctica and Oceania                                  5            5
# Other Europe                                                667          343
# Other Middle East and Asia                                  536          335
# Other The Americas and the Caribbean                        196          132
# Pakistan                                                     59           51
# Philippines                                                  61           77
# Poland                                                      451          144
# Portugal                                                     81           41
# Romania                                                      81           34
# Russia                                                       99           32
# Somalia                                                     218          236
# South Africa                                                174           99
# Spain (including Canary Islands)                            211          140
# Sri Lanka                                                    23           13
# Turkey                                                      108           85
# Uganda                                                       15           10
# United Kingdom                                             5317         3076
# United States                                               185          101
# Zimbabwe                                                     31           22
#
#                                                                               \
# Sex
# Age                                                Age 40 to 44 Age 45 to 49
# BirthCountry
# Afghanistan                                                   2            2
# Australia                                                    58           42
# Bangladesh                                                 1746         1164
# Brazil                                                       57           29
# Bulgaria                                                     19           14
# Canada                                                       27           18
# China                                                        82           34
# Cyprus                                                       15           11
# France                                                       62           30
# Germany                                                      81           35
# Ghana                                                        39           45
# Hong Kong (Special Administrative Region of China)           29           22
# Hungary                                                       9            4
# India                                                        63           47
# Iran                                                         12            6
# Iraq                                                         10            6
# Ireland                                                      85           36
# Italy                                                        69           24
# Jamaica                                                      26           19
# Kenya                                                        21           15
# Lithuania                                                    43           41
# Malaysia                                                     32           19
# Netherlands                                                   7            9
# New Zealand                                                  53           20
# Nigeria                                                      71           59
# Other                                                         0            0
# Other Africa                                                211          132
# Other Antarctica and Oceania                                  1            0
# Other Europe                                                149           90
# Other Middle East and Asia                                  220          135
# Other The Americas and the Caribbean                         75           84
# Pakistan                                                     30           29
# Philippines                                                  43           17
# Poland                                                       46           21
# Portugal                                                      8           10
# Romania                                                      20            2
# Russia                                                       29           16
# Somalia                                                     201          104
# South Africa                                                 33           16
# Spain (including Canary Islands)                             43           16
# Sri Lanka                                                     4            5
# Turkey                                                       49           35
# Uganda                                                       24           14
# United Kingdom                                             2755         2708
# United States                                                79           44
# Zimbabwe                                                     19           10
#
#                                                                ...  \
# Sex                                                            ...
# Age                                                Age 5 to 9  ...
# BirthCountry                                                   ...
# Afghanistan                                                 2  ...
# Australia                                                   1  ...
# Bangladesh                                                244  ...
# Brazil                                                      7  ...
# Bulgaria                                                    2  ...
# Canada                                                      2  ...
# China                                                       7  ...
# Cyprus                                                      0  ...
# France                                                     13  ...
# Germany                                                     8  ...
# Ghana                                                       2  ...
# Hong Kong (Special Administrative Region of China)          0  ...
# Hungary                                                     2  ...
# India                                                      24  ...
# Iran                                                        0  ...
# Iraq                                                        0  ...
# Ireland                                                     5  ...
# Italy                                                      14  ...
# Jamaica                                                     2  ...
# Kenya                                                       1  ...
# Lithuania                                                  14  ...
# Malaysia                                                    8  ...
# Netherlands                                                16  ...
# New Zealand                                                 2  ...
# Nigeria                                                     6  ...
# Other                                                       0  ...
# Other Africa                                               22  ...
# Other Antarctica and Oceania                                0  ...
# Other Europe                                               43  ...
# Other Middle East and Asia                                 20  ...
# Other The Americas and the Caribbean                       10  ...
# Pakistan                                                    8  ...
# Philippines                                                 6  ...
# Poland                                                     23  ...
# Portugal                                                    9  ...
# Romania                                                     2  ...
# Russia                                                      3  ...
# Somalia                                                    40  ...
# South Africa                                                3  ...
# Spain (including Canary Islands)                            9  ...
# Sri Lanka                                                   1  ...
# Turkey                                                      3  ...
# Uganda                                                      1  ...
# United Kingdom                                           7166  ...
# United States                                               4  ...
# Zimbabwe                                                    0  ...
#
#                                                                               \
# Sex                                                       Males
# Age                                                Age 40 to 44 Age 45 to 49
# BirthCountry
# Afghanistan                                                   6            7
# Australia                                                   116           40
# Bangladesh                                                 2591         1547
# Brazil                                                       90           44
# Bulgaria                                                     14           17
# Canada                                                       42           22
# China                                                        49           40
# Cyprus                                                       11           20
# France                                                       88           36
# Germany                                                     152           51
# Ghana                                                        38           30
# Hong Kong (Special Administrative Region of China)           36           18
# Hungary                                                       8            3
# India                                                        78           59
# Iran                                                         17           13
# Iraq                                                         14            9
# Ireland                                                     101           85
# Italy                                                       121           66
# Jamaica                                                      21           14
# Kenya                                                        26           22
# Lithuania                                                    37           27
# Malaysia                                                     23           17
# Netherlands                                                  26           15
# New Zealand                                                  57           25
# Nigeria                                                      51           52
# Other                                                         0            0
# Other Africa                                                298          256
# Other Antarctica and Oceania                                  2            1
# Other Europe                                                206          123
# Other Middle East and Asia                                  135           92
# Other The Americas and the Caribbean                         90           89
# Pakistan                                                     46           48
# Philippines                                                  19           18
# Poland                                                       60           22
# Portugal                                                     45           15
# Romania                                                      20            2
# Russia                                                       37           10
# Somalia                                                     146           88
# South Africa                                                 60           39
# Spain (including Canary Islands)                             61           19
# Sri Lanka                                                     6            6
# Turkey                                                       58           48
# Uganda                                                       21           24
# United Kingdom                                             3665         3285
# United States                                               102           63
# Zimbabwe                                                     31           12
#
#                                                                             \
# Sex
# Age                                                Age 5 to 9 Age 50 to 54
# BirthCountry
# Afghanistan                                                 2            0
# Australia                                                   6           28
# Bangladesh                                                229         1354
# Brazil                                                      5           19
# Bulgaria                                                    2            6
# Canada                                                      1           23
# China                                                       5           17
# Cyprus                                                      1           25
# France                                                     12           13
# Germany                                                    15           37
# Ghana                                                       0           34
# Hong Kong (Special Administrative Region of China)          0           21
# Hungary                                                     5            3
# India                                                      20           55
# Iran                                                        1           13
# Iraq                                                        0            7
# Ireland                                                     6           88
# Italy                                                      18           12
# Jamaica                                                     1           52
# Kenya                                                       3           25
# Lithuania                                                   7           17
# Malaysia                                                    4           12
# Netherlands                                                 8            7
# New Zealand                                                 3           10
# Nigeria                                                     6           51
# Other                                                       0            0
# Other Africa                                               14          125
# Other Antarctica and Oceania                                1            2
# Other Europe                                               32           68
# Other Middle East and Asia                                 21          102
# Other The Americas and the Caribbean                        6          100
# Pakistan                                                   10           39
# Philippines                                                 1           12
# Poland                                                     21           12
# Portugal                                                   10            9
# Romania                                                     1            1
# Russia                                                      4            6
# Somalia                                                    35           57
# South Africa                                                1           13
# Spain (including Canary Islands)                            5           10
# Sri Lanka                                                   6            4
# Turkey                                                      7           40
# Uganda                                                      1           14
# United Kingdom                                           7217         2729
# United States                                              22           57
# Zimbabwe                                                    1            8
#
#                                                                               \
# Sex
# Age                                                Age 55 to 59 Age 60 to 64
# BirthCountry
# Afghanistan                                                   1            1
# Australia                                                    21           11
# Bangladesh                                                  728          168
# Brazil                                                        3            4
# Bulgaria                                                      7            3
# Canada                                                        7            6
# China                                                        17           15
# Cyprus                                                       24           17
# France                                                        6           11
# Germany                                                      12           18
# Ghana                                                        37           34
# Hong Kong (Special Administrative Region of China)           29           20
# Hungary                                                       5            0
# India                                                        48           25
# Iran                                                          8            8
# Iraq                                                          3            5
# Ireland                                                     118           87
# Italy                                                        29           13
# Jamaica                                                      56           25
# Kenya                                                         2            9
# Lithuania                                                    11            1
# Malaysia                                                      8            6
# Netherlands                                                   3            5
# New Zealand                                                   8            5
# Nigeria                                                      41           21
# Other                                                         0            0
# Other Africa                                                 80           54
# Other Antarctica and Oceania                                  0            0
# Other Europe                                                 60           61
# Other Middle East and Asia                                   88           51
# Other The Americas and the Caribbean                        103           48
# Pakistan                                                     24           23
# Philippines                                                   7           13
# Poland                                                       13            5
# Portugal                                                      4            8
# Romania                                                       2            1
# Russia                                                        5            4
# Somalia                                                      36           23
# South Africa                                                 14           12
# Spain (including Canary Islands)                              9           10
# Sri Lanka                                                     5            3
# Turkey                                                       17           15
# Uganda                                                        9            2
# United Kingdom                                             2187         1946
# United States                                                32           30
# Zimbabwe                                                     14            5
#
#                                                                               \
# Sex
# Age                                                Age 65 to 69 Age 70 to 74
# BirthCountry
# Afghanistan                                                   1            0
# Australia                                                     3            6
# Bangladesh                                                  260          625
# Brazil                                                        1            0
# Bulgaria                                                      1            0
# Canada                                                        1            3
# China                                                         5            3
# Cyprus                                                       16           26
# France                                                        5            0
# Germany                                                       6            2
# Ghana                                                        16            9
# Hong Kong (Special Administrative Region of China)            7           11
# Hungary                                                       0            1
# India                                                        29           28
# Iran                                                          2            0
# Iraq                                                          1            1
# Ireland                                                      80           95
# Italy                                                         8            9
# Jamaica                                                      11           21
# Kenya                                                         3            3
# Lithuania                                                     1            0
# Malaysia                                                      4            3
# Netherlands                                                   5            0
# New Zealand                                                   7            2
# Nigeria                                                      10           16
# Other                                                         0            0
# Other Africa                                                 28           19
# Other Antarctica and Oceania                                  0            0
# Other Europe                                                 53           29
# Other Middle East and Asia                                   36           20
# Other The Americas and the Caribbean                         54           93
# Pakistan                                                     16           11
# Philippines                                                   1            1
# Poland                                                        2            1
# Portugal                                                      4            1
# Romania                                                       0            0
# Russia                                                        2            0
# Somalia                                                      27           40
# South Africa                                                  7            5
# Spain (including Canary Islands)                              7            4
# Sri Lanka                                                     0            2
# Turkey                                                       10            4
# Uganda                                                        2            0
# United Kingdom                                             1208          850
# United States                                                10            8
# Zimbabwe                                                      2            3
#
#
# Sex
# Age                                                Age 75 to 79 Age 80 or over
# BirthCountry
# Afghanistan                                                   2              0
# Australia                                                     2              3
# Bangladesh                                                  443            299
# Brazil                                                        0              0
# Bulgaria                                                      3              1
# Canada                                                        3              1
# China                                                         6              6
# Cyprus                                                       11             14
# France                                                        1              2
# Germany                                                       0              5
# Ghana                                                         3              5
# Hong Kong (Special Administrative Region of China)           13              6
# Hungary                                                       2              0
# India                                                        27             21
# Iran                                                          1              1
# Iraq                                                          1              0
# Ireland                                                      56             38
# Italy                                                         5              4
# Jamaica                                                      30             24
# Kenya                                                         4              1
# Lithuania                                                     0              4
# Malaysia                                                      2              2
# Netherlands                                                   0              1
# New Zealand                                                   3              0
# Nigeria                                                       6              4
# Other                                                         0              0
# Other Africa                                                 13             22
# Other Antarctica and Oceania                                  1              0
# Other Europe                                                 28             31
# Other Middle East and Asia                                   15             19
# Other The Americas and the Caribbean                         61             53
# Pakistan                                                     11             10
# Philippines                                                   3              2
# Poland                                                        0             16
# Portugal                                                      0              0
# Romania                                                       1              1
# Russia                                                        0              0
# Somalia                                                      28             41
# South Africa                                                  3              5
# Spain (including Canary Islands)                              1              1
# Sri Lanka                                                     2              0
# Turkey                                                        5              2
# Uganda                                                        1              0
# United Kingdom                                              719           1035
# United States                                                 2              2
# Zimbabwe                                                      0              0
#
# [46 rows x 34 columns]

# %%
#p3

# %%
p1.loc['Turkey','Usual Residents'].loc['Males']
p2.loc['Turkey','Usual Residents'].loc['Males','Age 0 to 4']
p3.loc['Africa','Males'].loc['Usual Residents','Age 80 or over']
# Out:
# 78

# %%
p4.loc['Age 0 to 4', 'Africa']
# Out:
# 59

# %% [markdown]
# ### Section 4.2 Sorting the Pivot Table
#
# We can sort the pivot table using one of the columns.
#
# #### Exercise 4.4 Sorting Pivots
# Try the following example and then sort the other ones you have created.

# %%
p1=p1.sort_values(by=('Usual Residents', 'Males'),ascending=0)
p1.head()
# Out:
#                            Usual Residents
# Sex                                Females  Males
# BirthCountry
# United Kingdom                       69673  74989
# Bangladesh                           18872  20005
# Other Europe                          3231   3282
# Other Middle East and Asia            2769   2421
# India                                 1658   2231

# %% [markdown]
# ### Section 4.3 Plotting Data
#
# Data can be plotted (i.e. shown on a graph). This uses the matplotlib library, which is also very complex. However, Pandas provides a plot function so that we do not have to use matplotlib explicitly (*at least at first*).
#
# Plot function arguments include:
# * `kind`: different kinds of plot e.g. 'bar', 'barh' or 'pie'
# * `figsize`: written as (width, height)
# * `stacked`: true or false
# * `logy`: show log of the data
# * `subplots`: see example below
# * `title`: plot title
#
# [The Pandas guide on visualisation is useful](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline   
   # this directive ensure plots are displayed

p1.plot(kind="bar",figsize=(15,20), logy=True) # this creates a plot; look carefully at the vertical axis
plt.show()

# %% [markdown]
# #### Exercise 4.5 Plotting
# The following plots show more features. Try out these examples and also apply them to the other pivot tables you have created.

# %%
#p1.plot(kind="pie",figsize=(20,20), subplots=True) 
#p1.plot(kind='bar', stacked=True, figsize=(15,10))
p1.plot(kind='bar', subplots=True, figsize=(15,20))
plt.show()

# %% [markdown]
# ## Section 5: Analysis Example
# This section combines the techniques introduced above in an example analysis. We wish to compare the composition of the population by sex and region of birth in different boroughs in London. We do this in the following steps:
#   1. select the data for the London boroughs
#   1. calculate the total population in each borough using a pivot table
#   1. add a column showing the proportion of the population of the borough coming from each region
#   1. create a pivot table aggregating these proportions for all the values of each region, within each borough
#   1. sort this pivot table using values for one borough
#   1. plot the data
#
# Review and run the code. The statements that generate output have been commented out.
#
# ### Section 5.1: Selecting Data for London Boroughs
#
# Not all the areas are London Boroughs. We want to discard the rows that are not for London Boroughs. However, this achieved by selecting the data we want rather than deleting the data we do not want. The following steps are needed:
#
# 1. We define a function that returns true if an area is a London Borough.
# 1. We `apply` this function to the `Area` column.

# %%
def isLondon(area):
  l = area in {'Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 
               'Bromley', 'Camden', 'City of London,Westminster', 'Croydon',
               'Ealing', 'Enfield', 'Greenwich', 'Hackney', 'Hammersmith and Fulham',
               'Haringey', 'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
               'Kensington and Chelsea', 'Kingston upon Thames', 'Lambeth', 
               'Lewisham', 'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 
               'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth' }
  return l

# test cases for isLondon
print(isLondon('Sutton'))
#isLondon('Wales')

df_London = df.loc[df['Area'].apply(isLondon) == True].copy()
df_London.loc[10950, 'Usual Residents'] = 75
df_London[df_London['Area'] == 'Croydon']
# Out:
# True
#           Area             Age      Sex Usual Residents   BirthCountry  \
# 10948  Croydon      Age 0 to 4  Females               5          Ghana
# 10949  Croydon      Age 5 to 9  Females              22          Ghana
# 10950  Croydon    Age 10 to 15  Females              75          Ghana
# 10951  Croydon    Age 16 to 19  Females              64          Ghana
# 10952  Croydon    Age 20 to 24  Females             145          Ghana
# ...        ...             ...      ...             ...            ...
# 12507  Croydon    Age 60 to 64    Males              15  United States
# 12508  Croydon    Age 65 to 69    Males               6  United States
# 12509  Croydon    Age 70 to 74    Males               4  United States
# 12510  Croydon    Age 75 to 79    Males               7  United States
# 12511  Croydon  Age 80 or over    Males               4  United States
#
#                           BirthRegion
# 10948                          Africa
# 10949                          Africa
# 10950                          Africa
# 10951                          Africa
# 10952                          Africa
# ...                               ...
# 12507  The Americas and the Caribbean
# 12508  The Americas and the Caribbean
# 12509  The Americas and the Caribbean
# 12510  The Americas and the Caribbean
# 12511  The Americas and the Caribbean
#
# [1564 rows x 6 columns]

# %% [markdown]
# ### Section 5.2: Calculating Total Population for Each Borough
#
# A problem with our approach so far is that we looked at absolute numbers of people. But this cannot be used to compare the populations structure in different boroughs as they vary in overall size.
#
# We can calculate the totals using a pivot table.

# %%
totals = df_London.pivot_table(values='Usual Residents', index=['Area'], aggfunc='sum')
totals = totals.sort_values(by=('Area'),ascending=0)
totals
# Out:
#                             Usual Residents
# Area
# Wandsworth                           306995
# Waltham Forest                       258249
# Tower Hamlets                        254096
# Sutton                               190146
# Southwark                            288283
# Richmond upon Thames                 186990
# Redbridge                            278970
# Newham                               307984
# Merton                               199693
# Lewisham                             275885
# Lambeth                              303086
# Kingston upon Thames                 160060
# Kensington and Chelsea               158649
# Islington                            206125
# Hounslow                             253957
# Hillingdon                           273936
# Havering                             237232
# Harrow                               239056
# Haringey                             254926
# Hammersmith and Fulham               182493
# Hackney                              246270
# Greenwich                            254557
# Enfield                              312466
# Ealing                               338449
# Croydon                              363378
# City of London,Westminster           226771
# Camden                               220338
# Bromley                              309392
# Brent                                311215
# Bexley                               231997
# Barnet                               356386
# Barking and Dagenham                 185911

# %% [markdown]
# **Challenge** Plot these populations in sorted order

# %% [markdown]
# We can use the totals dataframe to access the total for one Borough. The following code shows how:

# %%
totals.loc['Redbridge', 'Usual Residents']
# Out:
# 278970

# %% [markdown]
# ### Section 5.3: Adding a Population Proportion Column
#
# We will add a new column to the London dataframe with the population proportion. The steps are:
#
# 1. Define a new function to do the calculation
# 1. Apply it to every row

# %%
def calcProportion(row):
    #print(row)
    total = totals.loc[row.Area, 'Usual Residents']
    return row.loc['Usual Residents'] / total

df_London2 = df_London.assign(Proportion = df_London.apply(calcProportion, axis=1)) 
df_London2
# Out:
#                        Area             Age      Sex Usual Residents  \
# 0      Barking and Dagenham      Age 0 to 4  Females              10
# 1      Barking and Dagenham      Age 5 to 9  Females              17
# 2      Barking and Dagenham    Age 10 to 15  Females              45
# 3      Barking and Dagenham    Age 16 to 19  Females              30
# 4      Barking and Dagenham    Age 20 to 24  Females              67
# ...                     ...             ...      ...             ...
# 64119            Wandsworth    Age 60 to 64    Males              38
# 64120            Wandsworth    Age 65 to 69    Males              20
# 64121            Wandsworth    Age 70 to 74    Males              13
# 64122            Wandsworth    Age 75 to 79    Males               7
# 64123            Wandsworth  Age 80 or over    Males              12
#
#         BirthCountry                     BirthRegion  Proportion
# 0              Ghana                          Africa    0.000054
# 1              Ghana                          Africa    0.000091
# 2              Ghana                          Africa    0.000242
# 3              Ghana                          Africa    0.000161
# 4              Ghana                          Africa    0.000360
# ...              ...                             ...         ...
# 64119  United States  The Americas and the Caribbean    0.000124
# 64120  United States  The Americas and the Caribbean    0.000065
# 64121  United States  The Americas and the Caribbean    0.000042
# 64122  United States  The Americas and the Caribbean    0.000023
# 64123  United States  The Americas and the Caribbean    0.000039
#
# [50048 rows x 7 columns]

# %% [markdown]
# ### Section 5.4 Pivot and Plot Population Proportions

# %% [markdown]
# We can use the new column is a pivot table

# %%
analysis = df_London2.pivot_table(values='Proportion', index='Area', columns=['BirthRegion'], aggfunc='sum')
analysis
# Out:
# BirthRegion                   Africa  Antarctica and Oceania    Europe  \
# Area
# Barking and Dagenham        0.108902                0.001081  0.783676
# Barnet                      0.076106                0.005096  0.754250
# Bexley                      0.052186                0.001603  0.900214
# Brent                       0.110981                0.008358  0.603657
# Bromley                     0.033411                0.004431  0.908795
# Camden                      0.060335                0.023777  0.735080
# City of London,Westminster  0.066904                0.027252  0.666377
# Croydon                     0.080762                0.002810  0.775193
# Ealing                      0.073893                0.010977  0.673998
# Enfield                     0.083961                0.002279  0.822390
# Greenwich                   0.106133                0.005759  0.779209
# Hackney                     0.087327                0.013713  0.763430
# Hammersmith and Fulham      0.069427                0.038489  0.744001
# Haringey                    0.084836                0.010093  0.779014
# Harrow                      0.116701                0.003066  0.655131
# Havering                    0.026687                0.001530  0.936155
# Hillingdon                  0.062883                0.002920  0.776010
# Hounslow                    0.074394                0.007623  0.682576
# Islington                   0.060056                0.020623  0.801494
# Kensington and Chelsea      0.059963                0.022118  0.704536
# Kingston upon Thames        0.041728                0.007154  0.810971
# Lambeth                     0.095280                0.020615  0.752582
# Lewisham                    0.091622                0.007652  0.769473
# Merton                      0.085506                0.011738  0.743782
# Newham                      0.106944                0.002409  0.587527
# Redbridge                   0.065183                0.002405  0.707402
# Richmond upon Thames        0.035237                0.017760  0.857313
# Southwark                   0.128551                0.013379  0.723307
# Sutton                      0.042715                0.003482  0.863642
# Tower Hamlets               0.044637                0.015608  0.684879
# Waltham Forest              0.074881                0.003950  0.765765
# Wandsworth                  0.070568                0.030339  0.775146
#
# BirthRegion                 Middle East and Asia     Other  \
# Area
# Barking and Dagenham                    0.090161  0.000000
# Barnet                                  0.142104  0.000003
# Bexley                                  0.037104  0.000000
# Brent                                   0.218894  0.000000
# Bromley                                 0.036982  0.000006
# Camden                                  0.122770  0.000018
# City of London,Westminster              0.165092  0.000009
# Croydon                                 0.095895  0.000006
# Ealing                                  0.209786  0.000009
# Enfield                                 0.059101  0.000000
# Greenwich                               0.083345  0.000004
# Hackney                                 0.065660  0.000004
# Hammersmith and Fulham                  0.089154  0.000000
# Haringey                                0.063940  0.000000
# Harrow                                  0.205487  0.000008
# Havering                                0.027829  0.000000
# Hillingdon                              0.143607  0.000007
# Hounslow                                0.217013  0.000000
# Islington                               0.064437  0.000000
# Kensington and Chelsea                  0.122554  0.000000
# Kingston upon Thames                    0.121536  0.000006
# Lambeth                                 0.047983  0.000000
# Lewisham                                0.064328  0.000000
# Merton                                  0.121081  0.000000
# Newham                                  0.268274  0.000003
# Redbridge                               0.205205  0.000011
# Richmond upon Thames                    0.060083  0.000000
# Southwark                               0.067958  0.000000
# Sutton                                  0.075779  0.000005
# Tower Hamlets                           0.222381  0.000000
# Waltham Forest                          0.112670  0.000000
# Wandsworth                              0.075311  0.000000
#
# BirthRegion                 The Americas and the Caribbean
# Area
# Barking and Dagenham                              0.016180
# Barnet                                            0.022442
# Bexley                                            0.008892
# Brent                                             0.058111
# Bromley                                           0.016374
# Camden                                            0.058020
# City of London,Westminster                        0.074366
# Croydon                                           0.045336
# Ealing                                            0.031337
# Enfield                                           0.032269
# Greenwich                                         0.025550
# Hackney                                           0.069866
# Hammersmith and Fulham                            0.058928
# Haringey                                          0.062116
# Harrow                                            0.019606
# Havering                                          0.007798
# Hillingdon                                        0.014573
# Hounslow                                          0.018393
# Islington                                         0.053390
# Kensington and Chelsea                            0.090829
# Kingston upon Thames                              0.018606
# Lambeth                                           0.083541
# Lewisham                                          0.066926
# Merton                                            0.037893
# Newham                                            0.034843
# Redbridge                                         0.019794
# Richmond upon Thames                              0.029606
# Southwark                                         0.066806
# Sutton                                            0.014378
# Tower Hamlets                                     0.032496
# Waltham Forest                                    0.042734
# Wandsworth                                        0.048636

# %% [markdown]
# Then we can plot a figure comparing the region of birth in different Boroughs. We use a stacked bar chart.

# %%
analysis.sort_values(by=['Europe']).sort_values(by=['Sutton'],axis=1, ascending=False).plot(
    kind='bar', stacked=True, figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Area'>

# %% [markdown]
# ## Section 6: Analysis Challenge Exercises
#
# Try some further analyses. For example:
#
# 1. Look at the age structure of different Boroughs. Use the Borough totals to normalise the counts in each Borough (this is done above). Then add up the values with the same age band, eliminating the other values: use a pivot.
#
# 1. Change this around, to ask where do people of a certain age live? Now we want to normalise data (i.e. calculate proportions) using totals based on age group.
#
# 1. Add a column distinguishing inner and outer London Boroughs. [They are listed here](https://www.londoncouncils.gov.uk/node/1938) but watch out for different spelling. Compare the age distribution in inner and outer London.
#
# To tackle any of these challenges you need to work in stages:
#    * Start by making a plan. The biggest problem is to get started, so the plan need not be complete at first.
#    * Test each step as you go along. If you get an error that you do not understand, try breaking the statement in to simpler parts.
#    * Write as you work, explaining what you are doing. Code that is explained is much more likely to work correctly!

# %%
df
# Out:
#                            Area             Age      Sex Usual Residents  \
# 0          Barking and Dagenham      Age 0 to 4  Females              10
# 1          Barking and Dagenham      Age 5 to 9  Females              17
# 2          Barking and Dagenham    Age 10 to 15  Females              45
# 3          Barking and Dagenham    Age 16 to 19  Females              30
# 4          Barking and Dagenham    Age 20 to 24  Females              67
# ...                         ...             ...      ...             ...
# 67247  Yorkshire and The Humber    Age 60 to 64    Males             135
# 67248  Yorkshire and The Humber    Age 65 to 69    Males              94
# 67249  Yorkshire and The Humber    Age 70 to 74    Males              56
# 67250  Yorkshire and The Humber    Age 75 to 79    Males              38
# 67251  Yorkshire and The Humber  Age 80 or over    Males              57
#
#         BirthCountry                     BirthRegion
# 0              Ghana                          Africa
# 1              Ghana                          Africa
# 2              Ghana                          Africa
# 3              Ghana                          Africa
# 4              Ghana                          Africa
# ...              ...                             ...
# 67247  United States  The Americas and the Caribbean
# 67248  United States  The Americas and the Caribbean
# 67249  United States  The Americas and the Caribbean
# 67250  United States  The Americas and the Caribbean
# 67251  United States  The Americas and the Caribbean
#
# [67252 rows x 6 columns]

# %%
totals
# Out:
#                             Usual Residents
# Area
# Wandsworth                           306995
# Waltham Forest                       258249
# Tower Hamlets                        254096
# Sutton                               190146
# Southwark                            288283
# Richmond upon Thames                 186990
# Redbridge                            278970
# Newham                               307984
# Merton                               199693
# Lewisham                             275885
# Lambeth                              303086
# Kingston upon Thames                 160060
# Kensington and Chelsea               158649
# Islington                            206125
# Hounslow                             253957
# Hillingdon                           273936
# Havering                             237232
# Harrow                               239056
# Haringey                             254926
# Hammersmith and Fulham               182493
# Hackney                              246270
# Greenwich                            254557
# Enfield                              312466
# Ealing                               338449
# Croydon                              363378
# City of London,Westminster           226771
# Camden                               220338
# Bromley                              309392
# Brent                                311215
# Bexley                               231997
# Barnet                               356386
# Barking and Dagenham                 185911

# %%
print(totals.loc['Wandsworth'.Area, 'Usual Residents'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-378-cecfb7e04bfe> in <module>
# ----> 1 print(totals.loc['Wandsworth'.Area, 'Usual Residents'])
#
# AttributeError: 'str' object has no attribute 'Area'

# %%
df_ages = df.copy()
def calcProportion(row):
    #print(row)
    total = totals.loc[row.Area, 'Usual Residents']
    return row.loc['Usual Residents'] / total


df_ages2 = df_ages.assign(Proportion = df_ages.apply(calcProportion, axis=1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-376-de5981941cfe> in <module>
#       6
#       7
# ----> 8 df_ages2 = df_ages.assign(Proportion = df_ages.apply(calcProportion, axis=1))
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7763             kwds=kwds,
#    7764         )
# -> 7765         return op.get_result()
#    7766
#    7767     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~\miniconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ~\miniconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# ~\miniconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-376-de5981941cfe> in calcProportion(row)
#       3     #print(row)
#       4     total = totals.loc[row.Area, 'Usual Residents']
# ----> 5     return row.loc['Usual Residents'] / total
#       6
#       7
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df = pd.read_csv('LondonCOB.csv')
df = df.rename(columns={'Usual Residents': 'Residents'})

# %%
grouped = df.groupby('Area')['Residents'].sum()
grouped
# Out:
# Area
# Barking and Dagenham            185911
# Barnet                          356386
# Bexley                          231997
# Brent                           311215
# Bromley                         309392
# Camden                          220338
# City of London,Westminster      226771
# Croydon                         363378
# Ealing                          338449
# East Midlands                  4533222
# East of England                5846965
# Enfield                         312466
# England and Wales             56075912
# Greenwich                       254557
# Hackney                         246270
# Hammersmith and Fulham          182493
# Haringey                        254926
# Harrow                          239056
# Havering                        237232
# Hillingdon                      273936
# Hounslow                        253957
# Islington                       206125
# Kensington and Chelsea          158649
# Kingston upon Thames            160060
# Lambeth                         303086
# Lewisham                        275885
# London                         8173941
# Merton                          199693
# Newham                          307984
# North East                     2596886
# North West                     7052177
# Redbridge                       278970
# Richmond upon Thames            186990
# South East                     8634750
# South West                     5288935
# Southwark                       288283
# Sutton                          190146
# Tower Hamlets                   254096
# Wales                          3063456
# Waltham Forest                  258249
# Wandsworth                      306995
# West Midlands                  5601847
# Yorkshire and The Humber       5283733
# Name: Residents, dtype: int64

# %%
df_ages = df.copy()

def calcProportion(row):
    #print(row)
    total = totals.loc[row.Area, 'Usual Residents']
    return row.loc['Residents'] / total


df_ages2 = df_ages.assign(Proportion = df_ages.apply(calcProportion, axis=1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'East Midlands'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-404-ae9c55bb4924> in <module>
#       7
#       8
# ----> 9 df_ages2 = df_ages.assign(Proportion = df_ages.apply(calcProportion, axis=1))
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7763             kwds=kwds,
#    7764         )
# -> 7765         return op.get_result()
#    7766
#    7767     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~\miniconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# ~\miniconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# ~\miniconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-404-ae9c55bb4924> in calcProportion(row)
#       3 def calcProportion(row):
#       4     #print(row)
# ----> 5     total = totals.loc[row.Area, 'Usual Residents']
#       6     return row.loc['Residents'] / total
#       7
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     886                     # AttributeError for IntervalTree get_value
#     887                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 888             return self._getitem_tuple(key)
#     889         else:
#     890             # we by definition only have the 0th axis
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1057     def _getitem_tuple(self, tup: Tuple):
#    1058         with suppress(IndexingError):
# -> 1059             return self._getitem_lowerdim(tup)
#    1060
#    1061         # no multi-index, so validate all of the indexers
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     804                 # We don't need to check for tuples here because those are
#     805                 #  caught by the _is_nested_tuple_indexer check above.
# --> 806                 section = self._getitem_axis(key, axis=i)
#     807
#     808                 # We should never have a scalar section here, because
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1121         # fall thru to straight lookup
#    1122         self._validate_key(key, axis)
# -> 1123         return self._get_label(key, axis=axis)
#    1124
#    1125     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1070     def _get_label(self, label, axis: int):
#    1071         # GH#5667 this will fail if the label is not present in the axis.
# -> 1072         return self.obj.xs(label, axis=axis)
#    1073
#    1074     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3734                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3735         else:
# -> 3736             loc = index.get_loc(key)
#    3737
#    3738             if isinstance(loc, np.ndarray):
#
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'East Midlands'
